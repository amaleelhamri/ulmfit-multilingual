# %%
"""
Train a classifier on top of a language model trained with `pretrain_lm.py`.
Optionally fine-tune LM before.
"""
import numpy as np
import pickle

import torch
import torch.nn.functional as F
from fastai.text import TextLMDataBunch, TextClasDataBunch, language_model_learner, text_classifier_learner, LanguageLearner
from fastai import fit_one_cycle
from fastai_contrib.utils import PAD, UNK, read_clas_data, PAD_TOKEN_ID, DATASETS, TRN, VAL, TST, ensure_paths_exists, get_sentencepiece
from fastai.text.transform import Vocab
from fastai.metrics import accuracy, accuracy_thresh, fbeta

import fire
from collections import Counter
from pathlib import Path

import pandas as pd
import csv
from functools import partial
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import mlflow
import glob
import shutil
import dask.dataframe as dd
import dask_ml as dm
from matplotlib import pyplot as plt
import itertools

# %%
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 青空文庫の著作切れ作品の作者を当てる
#
# - 作品著作権フラグのない作品のうち11176件を形態素解析した結果が公開されている。新仮名データをダウンロードした。
# - http://aozora-word.hahasoha.net/index.html
# - この中から以下の著者のデータをダウンロードして、どの著者のデータか予測するモデルを作る(multi class)
#     - akutagawa
#     - mori
#     - natsume
#     - sakaguchi
#     - yoshikawa

# %% [markdown]
# ## copy data

# %%
# !ls ../aozora_classification/aozora_data/
# Out:
# akutagawa  log	mori  natsume  sakaguchi  yoshikawa

# %%
# !head -50 ../aozora_classification/aozora_data/natsume/csv/bocchan.csv
# Out:
# "","auth","piece","line"
# "0","natsume","bocchan.txt","坊っちゃん"
# "1","natsume","bocchan.txt","夏目漱石"
# "2","natsume","bocchan.txt",""
# "3","natsume","bocchan.txt","-------------------------------------------------------"
# "4","natsume","bocchan.txt","【テキスト中に現れる記号について】"
# "5","natsume","bocchan.txt",""
# "6","natsume","bocchan.txt","《》：ルビ"
# "7","natsume","bocchan.txt","（例）坊っちゃん"
# "8","natsume","bocchan.txt",""
# "9","natsume","bocchan.txt","｜：ルビの付く文字列の始まりを特定する記号"
# "10","natsume","bocchan.txt","（例）夕方｜折戸の"
# "11","natsume","bocchan.txt",""
# "12","natsume","bocchan.txt","：入力者注主に外字の説明や、傍点の位置の指定"
# "13","natsume","bocchan.txt","（例）おくれんかな"
# "14","natsume","bocchan.txt","-------------------------------------------------------"
# "15","natsume","bocchan.txt",""
# "16","natsume","bocchan.txt","一"
# "17","natsume","bocchan.txt",""
# "18","natsume","bocchan.txt","親譲りの無鉄砲で小供の時から損ばかりしている。"
# "19","natsume","bocchan.txt","小学校に居る時分学校の二階から飛び降りて一週間ほど腰を抜かした事がある。"
# "20","natsume","bocchan.txt","なぜそんな無闇をしたと聞く人があるかも知れぬ。"
# "21","natsume","bocchan.txt","別段深い理由でもない。"
# "22","natsume","bocchan.txt","新築の二階から首を出していたら、同級生の一人が冗談に、いくら威張っても、そこから飛び降りる事は出来まい。"
# "23","natsume","bocchan.txt","弱虫やーい。"
# "24","natsume","bocchan.txt","と囃したからである。"
# "25","natsume","bocchan.txt","小使に負ぶさって帰って来た時、おやじが大きな眼をして二階ぐらいから飛び降りて腰を抜かす奴があるかと云ったから、この次は抜かさずに飛んで見せますと答えた。"
# "26","natsume","bocchan.txt",""
# "27","natsume","bocchan.txt","親類のものから西洋製のナイフを貰って奇麗な刃を日に翳して、友達に見せていたら、一人が光る事は光るが切れそうもないと云った。"
# "28","natsume","bocchan.txt","切れぬ事があるか、何でも切ってみせると受け合った。"
# "29","natsume","bocchan.txt","そんなら君の指を切ってみろと注文したから、何だ指ぐらいこの通りだと右の手の親指の甲をはすに切り込んだ。"
# "30","natsume","bocchan.txt","幸ナイフが小さいのと、親指の骨が堅かったので、今だに親指は手に付いている。"
# "31","natsume","bocchan.txt","しかし創痕は死ぬまで消えぬ。"
# "32","natsume","bocchan.txt",""
# "33","natsume","bocchan.txt","庭を東へ二十歩に行き尽すと、南上がりにいささかばかりの菜園があって、真中に栗の木が一本立っている。"
# "34","natsume","bocchan.txt","これは命より大事な栗だ。"
# "35","natsume","bocchan.txt","実の熟する時分は起き抜けに背戸を出て落ちた奴を拾ってきて、学校で食う。"
# "36","natsume","bocchan.txt","菜園の西側が山城屋という質屋の庭続きで、この質屋に勘太郎という十三四の倅が居た。"
# "37","natsume","bocchan.txt","勘太郎は無論弱虫である。"
# "38","natsume","bocchan.txt","弱虫の癖に四つ目垣を乗りこえて、栗を盗みにくる。"
# "39","natsume","bocchan.txt","ある日の夕方｜折戸の蔭に隠れて、とうとう勘太郎を捕まえてやった。"
# "40","natsume","bocchan.txt","その時勘太郎は逃げ路を失って、一生懸命に飛びかかってきた。"
# "41","natsume","bocchan.txt","向うは二つばかり年上である。"
# "42","natsume","bocchan.txt","弱虫だが力は強い。"
# "43","natsume","bocchan.txt","鉢の開いた頭を、こっちの胸へ宛ててぐいぐい押した拍子に、勘太郎の頭がすべって、おれの袷の袖の中にはいった。"
# "44","natsume","bocchan.txt","邪魔になって手が使えぬから、無暗に手を振ったら、袖の中にある勘太郎の頭が、右左へぐらぐら靡いた。"
# "45","natsume","bocchan.txt","しまいに苦しがって袖の中から、おれの二の腕へ食い付いた。"
# "46","natsume","bocchan.txt","痛かったから勘太郎を垣根へ押しつけておいて、足搦をかけて向うへ倒してやった。"
# "47","natsume","bocchan.txt","山城屋の地面は菜園より六尺がた低い。"
# "48","natsume","bocchan.txt","勘太郎は四つ目垣を半分｜崩して、自分の領分へ真逆様に落ちて、ぐうと云った。"

# %%
# !mkdir -p data/Aozora/csv

# %%
csvs = glob.glob("../aozora_classification/aozora_data/*/csv/*.csv", recursive=True)

# %%
csvs
# Out:
# ['../aozora_classification/aozora_data/mori/csv/bungeino_shugi.csv',
#  "../aozora_classification/aozora_data/mori/csv/hon'yakuni_tsuite.csv",
#  "../aozora_classification/aozora_data/mori/csv/sekaiman'yu.csv",
#  '../aozora_classification/aozora_data/mori/csv/vater_sergius.csv',
#  '../aozora_classification/aozora_data/mori/csv/gengono_kigen_fuki.csv',
#  '../aozora_classification/aozora_data/mori/csv/fumizukai.csv',
#  '../aozora_classification/aozora_data/mori/csv/ogai_gyoshitowa_darezo.csv',
#  '../aozora_classification/aozora_data/mori/csv/konton.csv',
#  '../aozora_classification/aozora_data/mori/csv/tsuina.csv',
#  '../aozora_classification/aozora_data/mori/csv/izawa_ranken.csv',
#  '../aozora_classification/aozora_data/mori/csv/faust.csv',
#  '../aozora_classification/aozora_data/mori/csv/saigono_ikku.csv',
#  '../aozora_classification/aozora_data/mori/csv/warai.csv',
#  '../aozora_classification/aozora_data/mori/csv/saru.csv',
#  '../aozora_classification/aozora_data/mori/csv/gyogenki.csv',
#  '../aozora_classification/aozora_data/mori/csv/sanshodayu.csv',
#  '../aozora_classification/aozora_data/mori/csv/tsuri.csv',
#  '../aozora_classification/aozora_data/mori/csv/utakatano_ki.csv',
#  '../aozora_classification/aozora_data/mori/csv/abe_ichizoku.csv',
#  '../aozora_classification/aozora_data/mori/csv/toryu_hikakugengogaku.csv',
#  '../aozora_classification/aozora_data/mori/csv/hanako.csv',
#  '../aozora_classification/aozora_data/mori/csv/gan.csv',
#  '../aozora_classification/aozora_data/mori/csv/juamino_tegami.csv',
#  '../aozora_classification/aozora_data/mori/csv/sokkyo_shijin.csv',
#  '../aozora_classification/aozora_data/mori/csv/jusanji.csv',
#  '../aozora_classification/aozora_data/mori/csv/bara.csv',
#  '../aozora_classification/aozora_data/mori/csv/nakajikiri.csv',
#  '../aozora_classification/aozora_data/mori/csv/furui_techokara.csv',
#  '../aozora_classification/aozora_data/mori/csv/maihime.csv',
#  '../aozora_classification/aozora_data/mori/csv/ama.csv',
#  '../aozora_classification/aozora_data/mori/csv/munaguruma.csv',
#  '../aozora_classification/aozora_data/mori/csv/shi.csv',
#  '../aozora_classification/aozora_data/mori/csv/sei_nikolaus_no_yo.csv',
#  '../aozora_classification/aozora_data/mori/csv/kanzan_jittoku.csv',
#  '../aozora_classification/aozora_data/mori/csv/zainin.csv',
#  '../aozora_classification/aozora_data/mori/csv/gyunabe.csv',
#  '../aozora_classification/aozora_data/mori/csv/kanazukai_iken.csv',
#  '../aozora_classification/aozora_data/mori/csv/takasebune_engi.csv',
#  '../aozora_classification/aozora_data/mori/csv/michino_ki.csv',
#  '../aozora_classification/aozora_data/mori/csv/shigaramisoshino_sanboronbun.csv',
#  '../aozora_classification/aozora_data/mori/csv/robinson_crusoe_jo.csv',
#  '../aozora_classification/aozora_data/mori/csv/inaka.csv',
#  '../aozora_classification/aozora_data/mori/csv/hashino_shita.csv',
#  '../aozora_classification/aozora_data/mori/csv/sahashi_jingoro.csv',
#  '../aozora_classification/aozora_data/mori/csv/inu.csv',
#  '../aozora_classification/aozora_data/mori/csv/satoimono_me.csv',
#  '../aozora_classification/aozora_data/mori/csv/takasebune.csv',
#  '../aozora_classification/aozora_data/mori/csv/yume.csv',
#  '../aozora_classification/aozora_data/mori/csv/dokushin.csv',
#  '../aozora_classification/aozora_data/mori/csv/moso.csv',
#  '../aozora_classification/aozora_data/mori/csv/onnano_ketto.csv',
#  '../aozora_classification/aozora_data/mori/csv/karafuto_datsugokuki.csv',
#  '../aozora_classification/aozora_data/mori/csv/futarino_tomo.csv',
#  '../aozora_classification/aozora_data/mori/csv/kazuisuchika.csv',
#  '../aozora_classification/aozora_data/mori/csv/sakaijiken.csv',
#  '../aozora_classification/aozora_data/mori/csv/fushinchu.csv',
#  '../aozora_classification/aozora_data/mori/csv/gojiingahara.csv',
#  '../aozora_classification/aozora_data/mori/csv/shinju.csv',
#  '../aozora_classification/aozora_data/mori/csv/shibue_chusai.csv',
#  '../aozora_classification/aozora_data/mori/csv/hitoributai.csv',
#  '../aozora_classification/aozora_data/mori/csv/itabasami.csv',
#  '../aozora_classification/aozora_data/mori/csv/teikensensei.csv',
#  '../aozora_classification/aozora_data/mori/csv/somechigae.csv',
#  '../aozora_classification/aozora_data/mori/csv/yokyo.csv',
#  '../aozora_classification/aozora_data/mori/csv/kanzanjittoku_engi_shinji.csv',
#  '../aozora_classification/aozora_data/mori/csv/kanzan_jittoku_engi.csv',
#  '../aozora_classification/aozora_data/mori/csv/sakazuki.csv',
#  '../aozora_classification/aozora_data/mori/csv/tsuge_shirozaemon.csv',
#  '../aozora_classification/aozora_data/mori/csv/kuriyama_daizen.csv',
#  '../aozora_classification/aozora_data/mori/csv/rojin.csv',
#  '../aozora_classification/aozora_data/mori/csv/xanthis.csv',
#  '../aozora_classification/aozora_data/mori/csv/yakuhon_faust.csv',
#  '../aozora_classification/aozora_data/mori/csv/eri.csv',
#  '../aozora_classification/aozora_data/mori/csv/tsujibasha.csv',
#  '../aozora_classification/aozora_data/mori/csv/kano_yoni.csv',
#  '../aozora_classification/aozora_data/mori/csv/bokasen.csv',
#  '../aozora_classification/aozora_data/mori/csv/yuigon_sanshu.csv',
#  "../aozora_classification/aozora_data/mori/csv/byoin'yokocho.csv",
#  '../aozora_classification/aozora_data/mori/csv/yoshihisa_shinno_nenpu.csv',
#  '../aozora_classification/aozora_data/mori/csv/gorotsukino_shoten.csv',
#  '../aozora_classification/aozora_data/mori/csv/wani.csv',
#  '../aozora_classification/aozora_data/mori/csv/saiki_koi.csv',
#  '../aozora_classification/aozora_data/mori/csv/hyakumonogatari.csv',
#  '../aozora_classification/aozora_data/mori/csv/asobi.csv',
#  '../aozora_classification/aozora_data/mori/csv/hebi.csv',
#  '../aozora_classification/aozora_data/mori/csv/shinyaku_genji_jyo_mori.csv',
#  '../aozora_classification/aozora_data/mori/csv/resignation_no_setsu.csv',
#  '../aozora_classification/aozora_data/mori/csv/fukushindan.csv',
#  '../aozora_classification/aozora_data/mori/csv/hannichi.csv',
#  '../aozora_classification/aozora_data/mori/csv/chinmokuno_to.csv',
#  '../aozora_classification/aozora_data/mori/csv/kakeochi.csv',
#  '../aozora_classification/aozora_data/mori/csv/chijinto_shito.csv',
#  '../aozora_classification/aozora_data/mori/csv/sentsuamani.csv',
#  '../aozora_classification/aozora_data/mori/csv/haikuto_yumono.csv',
#  '../aozora_classification/aozora_data/mori/csv/uzushio.csv',
#  '../aozora_classification/aozora_data/mori/csv/shiro.csv',
#  '../aozora_classification/aozora_data/mori/csv/hasegawa_tatsunosuke.csv',
#  '../aozora_classification/aozora_data/mori/csv/saishuno_gogo.csv',
#  '../aozora_classification/aozora_data/mori/csv/rekishi_sonomama.csv',
#  '../aozora_classification/aozora_data/mori/csv/saffron.csv',
#  '../aozora_classification/aozora_data/mori/csv/kajo_chahan.csv',
#  '../aozora_classification/aozora_data/mori/csv/kodama.csv',
#  '../aozora_classification/aozora_data/mori/csv/okitsu_yagoemonno_isho.csv',
#  '../aozora_classification/aozora_data/mori/csv/florus.csv',
#  '../aozora_classification/aozora_data/mori/csv/jiisan_baasan.csv',
#  '../aozora_classification/aozora_data/mori/csv/fukushu.csv',
#  '../aozora_classification/aozora_data/mori/csv/nezumizaka.csv',
#  '../aozora_classification/aozora_data/mori/csv/yasui_fujin.csv',
#  '../aozora_classification/aozora_data/mori/csv/natsume_soseki_ron.csv',
#  '../aozora_classification/aozora_data/mori/csv/kanzanjittoku_shinji.csv',
#  '../aozora_classification/aozora_data/mori/csv/okitsu_yagoemon_shoko.csv',
#  '../aozora_classification/aozora_data/mori/csv/oshio_heihachiro.csv',
#  '../aozora_classification/aozora_data/mori/csv/andreas_thameyers.csv',
#  '../aozora_classification/aozora_data/mori/csv/karasu.csv',
#  '../aozora_classification/aozora_data/mori/csv/fukasetsu.csv',
#  '../aozora_classification/aozora_data/mori/csv/suginohara_shina.csv',
#  '../aozora_classification/aozora_data/mori/csv/niwatori.csv',
#  '../aozora_classification/aozora_data/mori/csv/shokudo.csv',
#  '../aozora_classification/aozora_data/mori/csv/seinen.csv',
#  '../aozora_classification/aozora_data/mori/csv/vita_sexualis.csv',
#  '../aozora_classification/aozora_data/mori/csv/fuyuno_o.csv',
#  '../aozora_classification/aozora_data/mori/csv/saijitsu.csv',
#  '../aozora_classification/aozora_data/mori/csv/watashiga_jushigosaino_toki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sobyo_sandai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kodokujigoku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shinano_e.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chokoyuki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/celt_no_hakumei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/clarimonde.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/honjo_ryogoku_shinjishinkana.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/soseki_sanbono_aki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sarano_hana.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mudai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mori_sensei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kikaina_saikai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kujaku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jimokuki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ubuya.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kimono.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/gesaku_zanmai_shinkana.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/fumihogo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/umano_ashi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shimagi_akahiko.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/numachi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kaikano_otto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jipponno_hari.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/byoshozakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sato_haruoshino_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/gakko_tomodachi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/samusa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/negi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kokui_seibo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tsuneto_kyoshi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/umino_hotori.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kare_daini.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sosaku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/koryomu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shimoyo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/uogasi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/rashomon.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sogiki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/anikino_yona_kokoromochi.csv',
#  "../aozora_classification/aozora_data/akutagawa/csv/san'emonno_tsumi.csv",
#  '../aozora_classification/aozora_data/akutagawa/csv/tegami.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/oshino.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aruhino_oishi_kuranosuke.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/uchida_hyakken_shi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yonosukeno_hanashi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mittsuno_yubiwa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/saru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/toshishun.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kisono_yoshinaka.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/honyaku_shohin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/piano.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kirishitohoro_shoninden.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haigatenrankaio_mite.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kamigamino_bisho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kesato_morito.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/inuto_fue.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shinryokuno_niwa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/saihono_hito.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haruno_yowa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mittsuno_mado.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chichi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tsuioku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mata_issetsu1.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kyokundan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/toyoshima_yoshioshino_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/pekin_nikki_sho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mittsuno_takara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zasshin_issoku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mikan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kakusanto_shokuyoku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/watashinosukina_romance.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hokku_shiken.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kume_masao.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kin_shogun.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mensura_zoili.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yamashigi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nyushano_ji.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kigu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jigokuhen_shohan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hitorino_mumeisakka.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/dekiagatta_hito.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/un.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hitokureno_tsuchi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yuwaku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/poe.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hina.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/soseki_sanbono_fuyu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/isho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zappitsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mata_issetsu2.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shunkan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/saigo_takamori.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/wagayano_kogan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/eikyuni_fuyukaina.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/agunino_kami.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chugi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/asakusa_koen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/antono_sho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kikanshao_minagara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aru_kyuyue_okuru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/juensatsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bisho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kosei.csv',
#  "../aozora_classification/aozora_data/akutagawa/csv/ren'aito_meotoai.csv",
#  '../aozora_classification/aozora_data/akutagawa/csv/ogin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/rashomonno_atoni.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/goriteki_dojini_taryono.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yasukichino_techokara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sarukani_gassen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kekkon_nan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nidai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haha.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nenmatsuno_ichinichi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jozetsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bungeikansho_koza.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/konanno_ogi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/basho_zakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kugenuma_zakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kyokazenshu_mokuroku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shuzanzu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ojigi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shujuno_kotobano_jo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/proletariat.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tabatajin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nagasaki_shohin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/karenosho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/koshoku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/koengunki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shujuno_kotoba.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ahen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hyottoko.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nipponshosetsuno_shinayaku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yokosuka_shokei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sonokorono_akamonseikatsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hakkirishita_katachio.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/soshun.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nikko_shohin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yononakato_onna.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/fushodan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ababababa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/seiyoganoyona_nihonga.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yume.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kanzanjittoku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/enju.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/genkaku_sanbo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/issekiwa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/takita_tetsutaro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sennin2.csv',
#  "../aozora_classification/aozora_data/akutagawa/csv/nenniwa_nen'o_irecho.csv",
#  '../aozora_classification/aozora_data/akutagawa/csv/shosetsuno_gikyokuka.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/masaokashiki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/inukaikunni_tsuite.csv',
#  "../aozora_classification/aozora_data/akutagawa/csv/aruren'ai_shosetsu.csv",
#  '../aozora_classification/aozora_data/akutagawa/csv/kume_masaoshino_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nijunengono_senso.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/rushiheru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/niwa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hana.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tokaide.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/samayoeru_yudayajin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hekiken.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/eiyuno_utsuwa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sutego.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/carmen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/futarino_tomo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/oitaru_susanoo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shosetsuno_dokusha.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shokoseibo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kachikachiyama.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haruno_shinzo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/juliano_kichisuke.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/robai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/koseigoni.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/fuyu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/furansu_bungakuto_boku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/futari_komachi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kage.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/itojo_oboegaki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kondo_koichiro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/matsue_inshoki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nyosen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/akuma.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/momotaro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shigo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nipponno_onna.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/soteini.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jigokuhen_shinji.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/daiyonno_ottokara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/okunno_shinshu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/byochuzakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kyo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yuki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nankinno_kirisuto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/gosaijinto_jusaijinto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/oritsuto_korato.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sennin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kosugi_misei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/los_caprichos.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nagasaki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zoku_bungeitekina.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kaeru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tabakoto_akuma.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/itokara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/biseino_shin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yarigatakeni_nobotta_ki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haruno_yo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/numa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mujina.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zoku_yajinseikeino_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tokyoshohin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/denkichi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hensen_sonota.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nisemononidai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kareno_chosho_juhachi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/myona_hanashi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mino_mawari.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ronen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hokyoninno_shi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/natsumesenseito_takitasan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/daidojishinsukeno_hansei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yajinseikeino_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mittsuno_naze.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tatsumura_heizo_shi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/rojo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shokumotsutoshite.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hiratasensei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kiseru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shina_yuki_jijo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kottokan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tozaimondo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nyotai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/iida_dakotsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/seinento_shi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/toyono_aki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jinro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mizuno_mikka.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/daidoji_shinsuke.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/mado.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aru_katakiuchino_hanashi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/honno_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/harunohino_sashita.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/onsen_dayori.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yume_kyukana.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/onna.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bokuwa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yuyuso.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/omu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shusho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/butokai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/royaku_tanpenshuno_jo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/okubo_koshu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zoku_basho_zakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kaikano_satsujin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yoba.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/anchu_mondo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aru_ahono_issho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/otomino_teiso.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yarigatake_kiko.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/okawano_mizu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kodomono_byoki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chikagorono_yurei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kare.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/waga_sanbunshi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kamoryo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kumono_ito.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/doso_mondo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shiro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tenkibo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kikuchi_kan_zenshuno_jo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/uwagoto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/katakoi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shuchu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ism_to_yu_gono.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hankechi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/torano_hanashi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/taisho_juninen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/rokunomiyano_himegimi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/onigokko.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kanazukai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ojo_emaki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hitooyobi_geijutsuka.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shogun.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shofubito_boken.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shuppon.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/fugawarina_sakuhin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/papaohan.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/eguchi_kanshino_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tabata_nikki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/konparukai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/torokko.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bunshoto_kotobato.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/waga_haikaishugyo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/fushigina_shima.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shinkiro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/jashumon.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ryu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/futatsuno_tegami.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kappa.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/saino_ikkonarumo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kabocha.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/richard_burton.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bunsho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ogata_ryosai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hoonki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/iwano_homei_shi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/giwaku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/baibunmondo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/baikani_taisuru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/honjoryogoku.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/nezumikozo_jirokichi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haguruma.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kaicho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shiruko.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/geijutsu_sonota.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chokodozakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aru_shakaishugisha.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/gesaku_zanmai.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shosetsusaho.csv',
#  "../aozora_classification/aozora_data/akutagawa/csv/tanizaki_jun'ichiro_shi.csv",
#  '../aozora_classification/aozora_data/akutagawa/csv/anokorono_jibun.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/imogayu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shishu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hitotsuno_sakuga.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kantei.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bungakuzukino_kateikara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kochiya.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/akutagawa_ryunosuke_kashu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bungeitekina_amarini.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/rashomon_kyu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tanekono_yutsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/hiroshitono_mondo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/bokuno_tomodachi_nisannin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tokyoni_umarete.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yuri.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zoku_chokodozakki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/susanono_mikoto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kaigara.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chogyuno_koto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/takita_tetsutarokun.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/gunkan_kongo_kokaiki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/noroma_ningyo.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sagito_oshidori.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/haru.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/majutsu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/ichiban_kinorino_surutoki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shirami.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/balthasar.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kyoto_nikki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/karuizawade.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/sato_haruo_shi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/tenshin.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shonen.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kubota_mantaro.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/shanhai_yuki.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/aidokushono_insho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kubigaochita_hanashi.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/wasurerarenu_insho.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/zoku_saihono_hito.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/chuto.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/yabuno_naka.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/kamenno_hitobito.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/pastel_no_ryu.csv',
#  '../aozora_classification/aozora_data/akutagawa/csv/dobutsuen.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/11reishoki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/machiwa_furusato.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bungeisoshini_tsuite.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/chihobunkano_kakuritsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yureito_bungaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mano_taikutsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/farce_ni_tsuite.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bokusuino_konrei.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/jakyo_mondo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sehyoto_jibun.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/anogo_shimodagaishi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shito_hanauta.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tenno_shoron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kodanshi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/interino_kansho.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/machiwa_furusato_sakusha.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kokini_kaete.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mudai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tegami_zatsudan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sunao_kamu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/03misshitsu_daihanzai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/07chio_miru_shinju.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fushigina_onna.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/10komajinjano_matsurino.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/waga_seishinno_shui.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/niryuno_hito.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/odanobunaga.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shinsaku_iroha_garuta.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/watashino_go.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hannin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wagajinseikan_1.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/01_hangan_chimatao_iku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nihonno_shijin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mochino_tatari.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wagajinseikan_3.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wagajinseikan_4.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/01ango_isejinguni_yuku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tsurishino_shinkyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/06_kuraikana_toyoyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ketto.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/amakuchi_karakuchi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakkaronni_tsuite.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/daraku_ron_zoku_daraku_ron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ango.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/piero_dendosha.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/daigono_sato.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sohen.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/teiginjiken'o_ronzu.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/tsukihino_hanashi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kazeto_hikarito.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bunsho_sonota.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yokoku_satsujinjiken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/saihanni_saishite_fubuki_monogatari.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hongono_namikimichi.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/shinjin'e.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/gutara_senki.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/kan'inni_yosu.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/gendaino_sajutsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/09tokeikanno_himitsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/taiho_shugisha.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ikuji.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sinkanazukaino_mondai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/musha_burui_ron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shobushi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/01amakusa_shiro.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tanitanzono_shizukana_shosetsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/jinsei_mittsuno_tanoshimi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/murano_hitosawagi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hakuchi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/20kojiki_danshaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yonagahimeto_mimio.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/goseigen.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sengo_sinjinron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/watashino_soshiki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/amemiya_koan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/roumen.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/dekadan_bungakuron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kanzo_sensei.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nijuichi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/dosutoefusukito_baruzakku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kessen_kawanakajima.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/jinsei_annai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/03toyamano_kusurito_echigo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tokaino_nakano_koto.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/atarashiki_bungaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ishino_omoi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/dekadan_bungaku_ron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/seishunron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kayo_sakushano_kotoba.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/jo_nigetai_kokoro.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shinso_kakunogotoshi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/04asukano_maboroshi.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/ren'airon.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/supotsu_bungaku_seiji.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/maniwanenryuno_koto.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/furyoshonento_kirisuto.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wagajinseikan_8.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/01ango_shinnihonfudoki_kadai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mojito_sokuryokuto_bungaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/chisana_yagino_kiroku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bungakuno_furusato.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/omina.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tanoshii_yumeno_nakanite.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/aoi_jutan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hakkutsushita_bijyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/watashino_shosetsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/onna_kenshi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nijihakaseno_haitai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakushafuki_hi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/04kyo_ware_keirinsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/06tokyo_janguru_tanken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nihonno_mizu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nihon_seishin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ango_mushashugyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mo_gunbiwa_iranai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fubuki_monogatari.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/soridaijinga_moratta.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shukkemonogatari.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/watasiwa_umio_dakishimete.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mohanshonenni_gigiari.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bunshono_ichikeishiki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fumoto.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/geido_chini_otsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tokkotaini_sasagu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/flaubert_zakkan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shisei_kandan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/akusai_ron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/chiru_nihon.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sumono_hoso.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fukuin_satsujin_jikenni_tsuite.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nigitta_te.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/05aa_mujo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nomenno_himitsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tanteishosetsuo_kiru.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fukakaina_shitsuren.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/senkyo_satsujinjiken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/niigatano_sake.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/ikkagen'o_haisu.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/umino_kiri.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/haha.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kigino_sei_tanino_sei.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yamanokami_satsujin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kodan_sensei.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kanto_zuihitsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/risono_onna.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kaze_hakase.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kobayashisanto_watashino.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bunjin_igokai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wakaremo_tanoshi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/keigoron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/inochibiroio_shitahanashi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/koio_shiniiku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hanadakiyoteru_ron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wagashisono_ibuki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ieyasu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hamon.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/goraku_hoshino_kokorogamae.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tanteishosetsutowa.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/02takachihoni_fuyuame_fureri.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tandokuhankoni_arazu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/03hanatenguryu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/stendhal_no_buntai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/takeyabuno_ie.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shinshun_nihonno_sorao.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/inchiki_bungaku_bokumetsu_zatsudan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yoroppateki_seikaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nihonno_yamato_bunngaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/02dotonbori_makaritoru.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/02dokyo_doji.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nikutaijitaiga_shikosuru.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/keimano_genso.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bokuwamo_naotteiru.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/hon'yaku_sutefanu_mararume.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/fukuin_satsujin_jiken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tennoheikani_sasaguru.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/09akitaken_homonki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kiryu_tsushin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/rekishito_genjitsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shudanmiai.csv',
# ...
#  '../aozora_classification/aozora_data/sakaguchi/csv/asuwa_tenkini_nare.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/hon'inbo_goseigen.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/10fukumen_yashiki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kanashii_shinpu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/08takarazuka_joshi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mizudoritei.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/natsuto_ningyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakaguchiryuno_shogikan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/11kyoso_tenrankai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kasho_bunka.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tsuzokusakka_kafu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/rurono_tsuioku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kurai_seishun.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nijushichi_sai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/konnichino_kanso.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nishi_higashi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hanabi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/akirameteiru_kodomotachi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hyakumanninno_bungaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gaki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/endainaru_kokorogamae.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sobomu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mon_asakusa.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shiraiakirasenseini.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/shin'yawa_nemuruni_kagiru.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/12inazumawa_mitari.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yaneurano_hannin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tsuyuno_kotae.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/inochigake.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/izukoe.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tsukueto_futonto_onna.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kannenteki_sonota.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/darakuron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kazehakase_kyu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gomanna_me.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nichigetsusama.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gendaitowa.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/08ishino_shita.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/panpan_garu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kurotanimura.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kogarashino_sakagurakara.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kasutorisha_jiken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kitato_minami.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/furusatoni_yosuru_sanka.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/03nosakachuito_nakanishi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gunshuno_hito.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tsuchino_nakakarano.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/dokyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/waga_sensoni_taisho_seru_kufu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hidano_kao.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/omochabako.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/02_ooka_echizennokami.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hokurotenno.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bunshono_karadama.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/furyu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bungakuto_kokuminseikatsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tadano_bungaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kagenonai_hannin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/02choseiryu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sensoron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shito_kage.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ashinonaiotokoto_kubino.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/osakana_jyoshi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/12kodanshi_taijo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/izakayano_seijin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kyoyu.csv',
#  "../aozora_classification/aozora_data/sakaguchi/csv/09den'en_haremu.csv",
#  '../aozora_classification/aozora_data/sakaguchi/csv/teisono_habato_genkai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/rinshokushinno_yado.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakuraecho_sonota.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shisonaki_me.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kanzan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/binjyogatano_boryoku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hahao_koroshita.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/uragiri.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bunretsutekina_kanso.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kirisute_gomen.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ushi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/iyokuteki_sosaku_bunsho.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/jirorino_onna.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/dentono_musansha.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/golfto_waruinakama.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yokoku_satsujin_jiken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/08storippu_bato.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/17kazokuwa_rokunin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/02butokai_satsujinjiken.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tensaini_narisokonatta_otoko.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/onnauranaishino_mae.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kanino_awa.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/atarashiki_seikakukanjo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/chiisana_heya.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hansutairuno_ki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/bunkasai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/yadatsusekoate_shokan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/murasakidainagon.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/tanteino_maki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/inja_yamae_norikomu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shinkeisuijakuteki_yakyu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/makinosanno_shi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hanano_kakuritsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/abesadato_yu_onna.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hahano_jokyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/15rottenamu_bijinjutsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shiganaoyani_bungakuno.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/rekishito_jijitsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/07atami_fukko.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/hinsezareba_donsu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ihojinni_tsuite.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kyosono_bungaku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/04hienryu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nohitsu_jimu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/abesadasanno_insho.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/01shinden_gyoshinryu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/05_shujokaigan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/mumodan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/new_face.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/shindode_nakatta_ranbono_shi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gairaigo_zehi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/chikagorono_sakeno_hanashi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/koun_ryusui.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kinsen_mujo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fukuin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nigetai_kokoro.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nagashimano_shi.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/ikon.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/13guyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/06manbiki_kazoku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/miraino_tameni.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/chonaino_nitensai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakushano_kotoba.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/wagajinseikan_5.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kotanno_fukakuo_haisu.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/kuroda_josui.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/atogaki_izukoe.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gakudo_shoron.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakeno_ato_saki.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/10sekai_shinkiroku_byo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/watashiwa_umio_dakishimete_itai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/gaitoto_aozora.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/akirame_anego.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/18okami_daimyojin.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/koto.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/onarasama.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/01mayaku_jisatsu_shukyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/nihon_bunka_shikan.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sogano_abarenbo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/teppo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/16akawana.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/fujinroku.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/koki_dokyo.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/04makyono_kai.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/aoonino_fundoshio_arau.csv',
#  '../aozora_classification/aozora_data/sakaguchi/csv/sakushano_iibun.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/06komeino_maki.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/tairanomasakado.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/ume_chirahora.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/08enmyono_maki.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/hanakami_ronin.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/ashi.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/hataoka_junsa.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinranno_suimyaku.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinsho_taikoki09.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/kankanmushiwa_utau.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/rogokuno_hanayome.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinsho_taikoki07.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/04teigoku_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/tazaki_sounto_sonoko.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/tennoto_keiba.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/zuihitsu_shihon_taiheiki.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/09kenmu_rakugaki_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/oshiire_zuihitsu.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/zuihitsu_shinheike.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/yagyu_tsukikage_sho.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/05shidono_maki.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/08nitta_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/otani_gyobu.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/edo_sangokushi.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/montsukio_kiruno_ki.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/02yagyu_sekishusai.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/baishino_tsue.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/03hayashizaki_jinsuke.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shosetsuno_tane.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/gyomon.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinsho_taikoki01.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/04takahashi_deishu.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinda_chidori.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/natsumushi_andon.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/nabeshima_kainokami.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shizuka_gozen.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/minamotono_yoritomo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/nozuchino_hyaku.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/10kazabana_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/yamaura_kiyomaro.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinranshoninni_tsuite.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/uesugikenshin.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/ginga_matsuri.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/dainanko_fujin.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/01jo_kenno_yonkunshi.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/02toenno_maki.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/bunkano_hi.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/hakkan_dochu.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/zocho_tenno.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/utsukushii_nihonno_rekishi.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/haruno_kari.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/02basara_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/05yono_tsujino_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/12hengaiyoroku.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shoyu_botoke.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/03minakami_jo.csv',
#  '../aozora_classification/aozora_data/yoshikawa/csv/shinsho_taikoki03.csv',
#  "../aozora_classification/aozora_data/yoshikawa/csv/shosointen'o_miru.csv",
#  '../aozora_classification/aozora_data/yoshikawa/csv/kobaino_kyaku.csv',
#  ...]

# %%
for f in csvs:
    shutil.copy(f,'data/Aozora/csv/')

# %%
# !ls data/Aozora/csv/
# Out:
# 01amakusa_shiro.csv			kuriyama_daizen.csv
# 01ango_isejinguni_yuku.csv		kuroda_josui.csv
# 01ango_shinnihonfudoki_kadai.csv	kurotanimura.csv
# 01ashikaga_jo.csv			kusamakura.csv
# 01dokushaeno_kojo.csv			kuse.csv
# 01_hangan_chimatao_iku.csv		kyo.csv
# 01jo.csv				kyoikuto_bungei.csv
# 01jo_kenno_yonkunshi.csv		kyokazenshu_mokuroku.csv
# 01mayaku_jisatsu_shukyo.csv		kyokundan.csv
# 01shinden_gyoshinryu.csv		kyoni_tsukeru_yube.csv
# 02basara_jo.csv				kyoshikun.csv
# 02butokai_satsujinjiken.csv		kyosono_bungaku.csv
# 02chino_maki.csv			kyoto_nikki.csv
# 02choseiryu.csv				kyoyu.csv
# 02dokyo_doji.csv			london.csv
# 02dotonbori_makaritoru.csv		london_shosoku.csv
# 02_ooka_echizennokami.csv		los_caprichos.csv
# 02takachihoni_fuyuame_fureri.csv	maboroshino_tate.csv
# 02tenkoko_joshi.csv			machiwa_furusato.csv
# 02toenno_maki.csv			machiwa_furusato_sakusha.csv
# 02yagyu_sekishusai.csv			mado.csv
# 03datemasamuneno_shiro.csv		maihime.csv
# 03gunseino_maki.csv			majutsu.csv
# 03hanatenguryu.csv			makinosanno_saiten.csv
# 03hayashizaki_jinsuke.csv		makinosanno_shi.csv
# 03minakami_jo.csv			maniwanenryuno_koto.csv
# 03misshitsu_daihanzai.csv		mankan_tokorodokoro.csv
# 03mizuno_maki.csv			mano_taikutsu.csv
# 03nosakachuito_nakanishi.csv		masaoka_shiki.csv
# 03_seishinbyo_shindansho.csv		masaokashiki.csv
# 03toyamano_kusurito_echigo.csv		mata_issetsu1.csv
# 04asukano_maboroshi.csv			mata_issetsu2.csv
# 04hienryu.csv				matsue_inshoki.csv
# 04hino_maki.csv				matsunoya_rohachi.csv
# 04kyo_ware_keirinsu.csv			meian.csv
# 04makyono_kai.csv			meijikaika_ango_kojo.csv
# 04_ningyono_ie.csv			meijizano_shokan.csv
# 04somono_maki.csv			mensura_zoili.csv
# 04takahashi_deishu.csv			michikusa.csv
# 04teigoku_jo.csv			michino_ki.csv
# 05aa_mujo.csv				miekichiate_shokan.csv
# 05katsu_musui.csv			mikan.csv
# 05kazeno_maki.csv			minamotono_yoritomo.csv
# 05kieuseta_sabaku.csv			mino_mawari.csv
# 05ono_tadaaki.csv			miraino_tameni.csv
# 05shidono_maki.csv			mittsuno_mado.csv
# 05_shujokaigan.csv			mittsuno_naze.csv
# 05yono_tsujino_jo.csv			mittsuno_takara.csv
# 05yunomachi_erejii.csv			mittsuno_yubiwa.csv
# 06hakko_jo.csv				mizudoritei.csv
# 06komeino_maki.csv			mizuno_mikka.csv
# 06_kuraikana_toyoyo.csv			mochino_tatari.csv
# 06manbiki_kazoku.csv			mo_gunbiwa_iranai.csv
# 06nagasaki_chanpon.csv			mohanshonenni_gigiari.csv
# 06sorano_maki.csv			mohoto_dokuritsu.csv
# 06tokyo_janguru_tanken.csv		mojito_sokuryokuto_bungaku.csv
# 07atami_fukko.csv			momotaro.csv
# 07chihaya_jo.csv			mon_asakusa.csv
# 07chio_miru_shinju.csv			mon.csv
# 07hida_takayamano_massatsu.csv		montsukio_kiruno_ki.csv
# 07_miyasamawa_ikkyushinshi.csv		mori_sensei.csv
# 07nitenno_maki.csv			moso.csv
# 07sekihekino_maki.csv			mudai.csv
# 08_ango_aisai_monogatari.csv		mujina.csv
# 08boshokuno_maki.csv			mumodan.csv
# 08enmyono_maki.csv			munaguruma.csv
# 08ishino_shita.csv			murano_hitosawagi.csv
# 08nitta_jo.csv				murasakidainagon.csv
# 08storippu_bato.csv			murdoch_senseino_nihon_rekishi.csv
# 08takarazuka_joshi.csv			musha_burui_ron.csv
# 09akitaken_homonki.csv			mushuku_jinkokuki.csv
# 09den'en_haremu.csv			myona_hanashi.csv
# 09kenmu_rakugaki_jo.csv			nabeshima_kainokami.csv
# 09tokeikanno_himitsu.csv		nagasaki.csv
# 09tonanno_maki.csv			nagasaki_shohin.csv
# 10fukumen_yashiki.csv			nagashimano_shi.csv
# 10kazabana_jo.csv			nagatsuka_takashishino.csv
# 10komajinjano_matsurino.csv		nakajikiri.csv
# 10sekai_shinkiroku_byo.csv		nakamito_keishiki.csv
# 10suishino_maki.csv			nakamurachiheicho_nagamimi.csv
# 11gojogenno_maki.csv			namiko.csv
# 11kyoso_tenrankai.csv			nankinmushi_satsujinjiken.csv
# 11reishoki.csv				nankinno_kirisuto.csv
# 11tsukushi_jo.csv			nanpufu.csv
# 12hengaiyoroku.csv			narutohicho01.csv
# 12inazumawa_mitari.csv			narutohicho02.csv
# 12kodanshi_taijo.csv			narutohicho03.csv
# 12minatogawa_jo.csv			narutohicho04.csv
# 13guyo.csv				narutohicho05.csv
# 13kokubyaku_jo.csv			narutohicho06.csv
# 14maboroshino_to.csv			natsumesenseito_takitasan.csv
# 15rottenamu_bijinjutsu.csv		natsume_soseki_ron.csv
# 16akawana.csv				natsumushi_andon.csv
# 17kazokuwa_rokunin.csv			natsuto_ningyo.csv
# 18okami_daimyojin.csv			negi.csv
# 19odoru_tokei.csv			neko_chuhen.csv
# 20kojiki_danshaku.csv			neko_gehen.csv
# 21.csv					neko_jyo.csv
# 21tonbi_otoko.csv			neko_kokoku.csv
# ababababa.csv				nenmatsuno_ichinichi.csv
# abe_ichizoku.csv			nenniwa_nen'o_irecho.csv
# abesadasanno_insho.csv			new_face.csv
# abesadato_yu_onna.csv			nezumikozo_jirokichi.csv
# agunino_kami.csv			nezumizaka.csv
# ahen.csv				nichieino_omoide.csv
# aidokushono_insho.csv			nichigetsusama.csv
# aki.csv					nidai.csv
# akirame_anego.csv			nigetai_kokoro.csv
# akirameteiru_kodomotachi.csv		nigitta_te.csv
# akuma.csv				nigogoshakuni_kansuru.csv
# akusai_ron.csv				nihon_bunka_shikan.csv
# akusairon.csv				nihonjinni_tsuite.csv
# akutagawa_ryunosuke_kashu.csv		nihonno_mizu.csv
# ama.csv					nihonno_shijin.csv
# amakuchi_karakuchi.csv			nihonno_yamato_bunngaku.csv
# amemiya_koan.csv			nihon_seishin.csv
# anchu_mondo.csv				nihyakutoka.csv
# andreas_thameyers.csv			niigatano_sake.csv
# ango.csv				nijihakaseno_haitai.csv
# ango_mushashugyo.csv			nijuichi.csv
# anikino_yona_kokoromochi.csv		nijunengono_senso.csv
# anogo_shimodagaishi.csv			nijushichi_sai.csv
# anokorono_jibun.csv			nikko_shohin.csv
# antono_sho.csv				nikutaijitaiga_shikosuru.csv
# aoi_jutan.csv				ningen_sansui_zumaki.csv
# aoonino_fundoshio_arau.csv		nipponno_onna.csv
# aru_ahono_issho.csv			nipponshosetsuno_shinayaku.csv
# aruhino_oishi_kuranosuke.csv		niryuno_hito.csv
# aru_katakiuchino_hanashi.csv		nisemononidai.csv
# aru_kyuyue_okuru.csv			nishi_higashi.csv
# aruren'ai_shosetsu.csv			nishiogi_zuihitsu.csv
# aru_shakaishugisha.csv			niwa.csv
# asakusa_koen.csv			niwatori.csv
# ashi.csv				nobunaga_sakushano_kotoba.csv
# ashinonaiotokoto_kubino.csv		nohitsu_jimu.csv
# asobi.csv				nomenno_himitsu.csv
# asuwa_tenkini_nare.csv			noroma_ningyo.csv
# atarashiki_bungaku.csv			nowaki.csv
# atarashiki_seikaku_kanjo.csv		nozuchino_hyaku.csv
# atarashiki_seikakukanjo.csv		numachi.csv
# atogaki_izukoe.csv			numa.csv
# awarena_tonmasensei.csv			nusumareta_tegamino_hanashi.csv
# baibunmondo.csv				nyosen.csv
# baien_jo.csv				nyotai.csv
# baikani_taisuru.csv			nyushano_ji.csv
# baishino_tsue.csv			nyusyano_ji.csv
# balthasar.csv				odanobunaga.csv
# bara.csv				ogai_gyoshitowa_darezo.csv
# basho_zakki.csv				ogata_ryosai.csv
# bengara_kotatsu.csv			ogin.csv
# benkyoki.csv				oihirosuketoyu_otoko.csv
# binjyogatano_boryoku.csv		oitaru_susanoo.csv
# biseino_shin.csv			ojigi.csv
# bisho.csv				ojo_emaki.csv
# bocchan.csv				okamoto_ippei.csv
# bokasen.csv				okawano_mizu.csv
# bokuno_mukashi.csv			okitsu_yagoemonno_isho.csv
# bokuno_tomodachi_nisannin.csv		okitsu_yagoemon_shoko.csv
# bokusuino_konrei.csv			okubo_koshu.csv
# bokuwa.csv				okunno_shinshu.csv
# bokuwamo_naotteiru.csv			omina.csv
# buncho.csv				omocha_bako.csv
# bundanno_susei.csv			omochabako.csv
# bungakuno_furusato.csv			omoidasu_kotonado.csv
# bungakuto_kokuminseikatsu.csv		omu.csv
# bungakuzukino_kateikara.csv		onarasama.csv
# bungei_iin.csv				oni.csv
# bungeikansho_koza.csv			onigokko.csv
# bungeino_shugi.csv			onna.csv
# bungeino_tetsugaku.csv			onna_kenshi.csv
# bungeisoshini_tsuite.csv		onnano_ketto.csv
# bungeitekina_amarini.csv		onnauranaishino_mae.csv
# bungeito_dotoku.csv			onodera_junaino_tsuma.csv
# bungeito_heroic.csv			onsen_dayori.csv
# bungeiwa_danshi.csv			on'yoku.csv
# bunjin_igokai.csv			ookaechizen.csv
# bunkano_hi.csv				oriorino_ki.csv
# bunkasai.csv				oritsuto_korato.csv
# bunretsutekina_kanso.csv		osakana_jyoshi.csv
# bunshino_seikatsu.csv			osakano_hangyaku.csv
# bunsho.csv				oshaberi_kyoso.csv
# bunshono_ichikeishiki.csv		oshiire_zuihitsu.csv
# bunshono_karadama.csv			oshino.csv
# bunsho_sonota.csv			oshio_heihachiro.csv
# bunshoto_kotobato.csv			otaka.csv
# butokai.csv				otani_gyobu.csv
# byochuzakki.csv				otomino_teiso.csv
# byoin'yokocho.csv			oyaga_suterareru_seso.csv
# byoshozakki.csv				panpan_garu.csv
# carlyle_hakubutsukan.csv		papaohan.csv
# carmen.csv				pastel_no_ryu.csv
# celt_no_hakumei.csv			pekin_nikki_sho.csv
# chabanni_yosete.csv			piano.csv
# chazuke_sanryaku.csv			piero_dendosha.csv
# chichi.csv				pierre_philosophale.csv
# chihobunkano_kakuritsu.csv		pittya_satsujin_jiken.csv
# chiisana_heya.csv			poe.csv
# chijinto_shito.csv			proletariat.csv
# chikagorono_sakeno_hanashi.csv		rakudai.csv
# chikagorono_yurei.csv			rakujitsuno_sogonni_niru.csv
# chinmokuno_to.csv			ramuneshino_koto.csv
# chiru_nihon.csv				rashomon.csv
# chisana_yagino_kiroku.csv		rashomon_kyu.csv
# chogyuno_koto.csv			rashomonno_atoni.csv
# chohen_shosetsu_jihyo.csv		rekishi_sonomama.csv
# chokodozakki.csv			rekishito_genjitsu.csv
# chokoyuki.csv				rekishito_jijitsu.csv
# chonaino_nitensai.csv			ren'airon.csv
# chugi.csv				ren'aito_meotoai.csv
# chuto.csv				resignation_no_setsu.csv
# chuyo.csv				richard_burton.csv
# clarimonde.csv				rinrakuno_seishun.csv
# conrad.csv				rinshokushinno_yado.csv
# daidoji_shinsuke.csv			risono_onna.csv
# daidojishinsukeno_hansei.csv		robai.csv
# daigono_sato.csv			robinson_crusoe_jo.csv
# dainanko_fujin.csv			roen.csv
# daini_geijutsu_ronni_tsuite.csv		rogokuno_hanayome.csv
# daiyonno_ottokara.csv			rojin.csv
# danjono_kosainitsuite.csv		rojo.csv
# darakuron.csv				rokunomiyano_himegimi.csv
# daraku_ron_zoku_daraku_ron.csv		ronen.csv
# dazaiosamu_jyoshiko.csv			roumen.csv
# ddt_to_mannendoko.csv			royaku_tanpenshuno_jo.csv
# dekadan_bungaku_ron.csv			rurono_tsuioku.csv
# dekadan_bungakuron.csv			rushiheru.csv
# dekiagatta_hito.csv			ryu.csv
# denkichi.csv				saffron.csv
# densetsuno_jidai_jo.csv			sagito_oshidori.csv
# dentono_musansha.csv			sahashi_jingoro.csv
# dobutsuen.csv				saigono_ikku.csv
# dokushin.csv				saigo_takamori.csv
# dokyo.csv				saihanni_saishite_fubuki_monogatari.csv
# doraku.csv				saihono_hito.csv
# doso_mondo.csv				saijitsu.csv
# dosutoefusukito_baruzakku.csv		saiki_koi.csv
# edo_sangokushi.csv			saino_ikkonarumo.csv
# egoizumu_shoron.csv			saishuno_gogo.csv
# eguchi_kanshino_koto.csv		sakaguchiryuno_shogikan.csv
# eijitsu_shohin.csv			sakaijiken.csv
# eikyuni_fuyukaina.csv			sakazuki.csv
# eiyuno_utsuwa.csv			sakeno_ato_saki.csv
# endainaru_kokorogamae.csv		sakkaronni_tsuite.csv
# enju.csv				sakonno_ikari.csv
# eri.csv					sakubutsuno_hihyo.csv
# farce_ni_tsuite.csv			sakuraecho_sonota.csv
# faust.csv				sakurano_morino_mankaino.csv
# flaubert_zakkan.csv			sakushafuki_hi.csv
# florus.csv				sakushano_iibun.csv
# fubuki_monogatari.csv			sakushano_kotoba.csv
# fugawarina_sakuhin.csv			samayoeru_yudayajin.csv
# fugu.csv				samusa.csv
# fujinroku.csv				san'emonno_tsumi.csv
# fukakaina_shitsuren.csv			sanjussai.csv
# fukasetsu.csv				sanroku.csv
# fukuin.csv				sanshiro.csv
# fukuin_satsujin_jiken.csv		sanshiro_yokoku.csv
# fukuin_satsujin_jikenni_tsuite.csv	sanshodayu.csv
# fukushindan.csv				sanzankoji.csv
# fukushu.csv				sarano_hana.csv
# fumihogo.csv				saru.csv
# fumizukai.csv				sarukani_gassen.csv
# fumoto.csv				sato_haruo_shi.csv
# furansu_bungakuto_boku.csv		sato_haruoshino_koto.csv
# furenzoku_satsujinjiken.csv		satoimono_me.csv
# furui_techokara.csv			sehyoto_jibun.csv
# furusatoni_yosuru_sanka.csv		seinen.csv
# furyoshonento_kirisuto.csv		seinento_shi.csv
# furyu.csv				sei_nikolaus_no_yo.csv
# fushigina_onna.csv			seishinbyo_oboegaki.csv
# fushigina_shima.csv			seishunron.csv
# fushinchu.csv				seitawa_hyakunen_kataru.csv
# fushodan.csv				seiyoganoyona_nihonga.csv
# fusigina_kiko.csv			seiyoniwa_nai.csv
# futari_komachi.csv			sekaiman'yu.csv
# futarino_tomo.csv			semi.csv
# futatsuno_tegami.csv			sengo_gokakusha.csv
# fuyu.csv				sengo_sinjinron.csv
# fuyuno_o.csv				senkyo_satsujinjiken.csv
# gairaigo_zehi.csv			sennin2.csv
# gaitoto_aozora.csv			sennin.csv
# gaki.csv				senso_ikichigai.csv
# gakko_tomodachi.csv			sensoron.csv
# gakudo_shoron.csv			sensoto_hitorino_onna.csv
# gakushato_meiyo.csv			sentsuamani.csv
# gan.csv					sesson_hitsu_nasuzu.csv
# ganjitsu.csv				shanhai_yuki.csv
# geido_chini_otsu.csv			shaseibun.csv
# geijutsu_sonota.csv			shibue_chusai.csv
# gendainihonno_kaika.csv			shi.csv
# gendai_ninjutsuden.csv			shiganaoyani_bungakuno.csv
# gendaino_sajutsu.csv			shigaramisoshino_sanboronbun.csv
# gendaitowa.csv				shigo.csv
# gengono_kigen_fuki.csv			shikino_e.csv
# genjitsu_shugisha.csv			shimabara_ikki_ibun.csv
# genkaku_sanbo.csv			shimabaranoran_zakki.csv
# gesakusha_bungakuron.csv		shimagi_akahiko.csv
# gesaku_zanmai.csv			shimoyo.csv
# gesaku_zanmai_shinkana.csv		shinano_e.csv
# getobashi_yurai.csv			shina_yuki_jijo.csv
# ginga_matsuri.csv			shinda_chidori.csv
# giwaku.csv				shindode_nakatta_ranbono_shi.csv
# glass_dono_uchi.csv			shinjin'e.csv
# gogatsuno_uta.csv			shinju.csv
# gojiingahara.csv			shinkeisuijakuteki_yakyu.csv
# golfto_waruinakama.csv			shinkiro.csv
# gomanna_me.csv				shinozasano_kageno_kao.csv
# gonimo_meijinsen.csv			shinpen_chushingura.csv
# goraku_hoshino_kokorogamae.csv		shinranno_suimyaku.csv
# goriteki_dojini_taryono.csv		shinranshoninni_tsuite.csv
# gorotsukino_shoten.csv			shinrei_satsujin_jiken.csv
# gosaijinto_jusaijinto.csv		shinryokuno_niwa.csv
# goseigen.csv				shinsaku_iroha_garuta.csv
# gubijinso.csv				shinsho_taikoki01.csv
# gunkan_kongo_kokaiki.csv		shinsho_taikoki02.csv
# gunshuno_hito.csv			shinsho_taikoki03.csv
# gutara_senki.csv			shinsho_taikoki04.csv
# gyogenki.csv				shinsho_taikoki05.csv
# gyomon.csv				shinsho_taikoki06.csv
# gyunabe.csv				shinsho_taikoki07.csv
# haguruma.csv				shinsho_taikoki08.csv
# haha.csv				shinsho_taikoki09.csv
# hahano_jokyo.csv			shinsho_taikoki10.csv
# hahao_koroshita.csv			shinsho_taikoki11.csv
# haigatenrankaio_mite.csv		shinshun_nihonno_sorao.csv
# haikuto_yumono.csv			shinshu_tenmakyo.csv
# hakase_mondaino_nariyuki.csv		shinso_kakunogotoshi.csv
# hakase_mondaito_murdoch.csv		shinyaku_genji_jyo_mori.csv
# hakkan_dochu.csv			shin'yawa_nemuruni_kagiru.csv
# hakkirishita_katachio.csv		shiraiakirasenseini.csv
# hakkutsushita_bijyo.csv			shirami.csv
# hakuchi.csv				shiro.csv
# hamon.csv				shiruko.csv
# hanabi.csv				shisei_kandan.csv
# hana.csv				shisei_satujinjiken.csv
# hanadakiyoteru_ron.csv			shishu.csv
# hanakami_ronin.csv			shisonaki_me.csv
# hanako.csv				shisoto_bungaku.csv
# hanano_kakuritsu.csv			shitano_susabi.csv
# hanasakeru_ishi.csv			shito_hanauta.csv
# hankechi.csv				shito_kage.csv
# hannichi.csv				shizen'o_utsusu_bunsho.csv
# hannin.csv				shizuka_gozen.csv
# hansutairuno_ki.csv			shobushi.csv
# haru.csv				shofubito_boken.csv
# harunohino_sashita.csv			shogino_oni.csv
# haruno_kari.csv				shogono_satsujin.csv
# haruno_shinzo.csv			shogun.csv
# haruno_yo.csv				shojosaku_zengono_omoide.csv
# haruno_yowa.csv				shokoseibo.csv
# hasegawa.csv				shokudo.csv
# hasegawa_tatsunosuke.csv		shokumotsutoshite.csv
# hashino_shita.csv			shonen.csv
# hataoka_junsa.csv			shosetsuno_dokusha.csv
# hebi.csv				shosetsuno_gikyokuka.csv
# hekiken.csv				shosetsuno_tane.csv
# henna_oto_kyu.csv			shosetsusaho.csv
# henna_oto_shin.csv			shoshuno_ichinichi.csv
# hensen_sonota.csv			shosointen'o_miru.csv
# hidano_kao.csv				shoyu_botoke.csv
# higanni_tsuite.csv			shuchu.csv
# higansugimade.csv			shudanmiai.csv
# hina.csv				shujuno_kotoba.csv
# hinoeumano_hanashi.csv			shujuno_kotobano_jo.csv
# hinsezareba_donsu.csv			shukkemonogatari.csv
# hiratasensei.csv			shukumeino_candide.csv
# hiroshitono_mondo.csv			shumino_iden.csv
# hitaino_otokoo_yomu.csv			shunkan.csv
# hitokureno_tsuchi.csv			shuppon.csv
# hitonokono_oyatonarite.csv		shusho.csv
# hitooyobi_geijutsuka.csv		shuzanzu.csv
# hitoributai.csv				sinkanazukaino_mondai.csv
# hitorino_mumeisakka.csv			sobomu.csv
# hitotsuno_sakuga.csv			sobyo_sandai.csv
# hokage.csv				sogano_abarenbo.csv
# hokku_shiken.csv			sogiki.csv
# hokurotenno.csv				sohen.csv
# hokyoninno_shi.csv			sokkyo_shijin.csv
# hongono_namikimichi.csv			somechigae.csv
# hon'inbo_goseigen.csv			sonokorono_akamonseikatsu.csv
# honjoryogoku.csv			sorekara.csv
# honjo_ryogoku_shinjishinkana.csv	sorekara_yokoku.csv
# honno_koto.csv				soridaijinga_moratta.csv
# hon'yakuni_tsuite.csv			sosaku.csv
# honyaku_shohin.csv			sosakuka.csv
# hon'yaku_sutefanu_mararume.csv		soseki_sanbono_aki.csv
# hoonki.csv				soseki_sanbono_fuyu.csv
# hosokawa_garasha_fujin.csv		soshun.csv
# hyakumanninno_bungaku.csv		soteini.csv
# hyakumonogatari.csv			stendhal_no_buntai.csv
# hyottoko.csv				suginohara_shina.csv
# ichiban_kinorino_surutoki.csv		suiri_shosetsuni_tsuite.csv
# ichiya.csv				suiri_shosetsuron.csv
# ieyasu.csv				sumono_hoso.csv
# igo_shugyo.csv				sunao_kamu.csv
# ihojinni_tsuite.csv			supotsu_bungaku_seiji.csv
# iida_dakotsu.csv			susanono_mikoto.csv
# ikkagen'o_haisu.csv			sutego.csv
# ikon.csv				syojyosaku_tsuikaidan.csv
# ikuji.csv				tabakoto_akuma.csv
# imogayu.csv				tabatajin.csv
# inaka.csv				tabata_nikki.csv
# inchiki_bungaku_bokumetsu_zatsudan.csv	tadano_bungaku.csv
# inja_yamae_norikomu.csv			taiho_shugisha.csv
# inochibiroio_shitahanashi.csv		taiko_fujin.csv
# inochigake.csv				taimoo_idaku_kappa.csv
# interino_kansho.csv			tairanomasakado.csv
# inu.csv					taisho_juninen.csv
# inukaikunni_tsuite.csv			takahamakyosi_cho_keito.csv
# inuto_fue.csv				takasebune.csv
# ishikito_jikantono_kankei.csv		takasebune_engi.csv
# ishino_omoi.csv				takeyabuno_ie.csv
# isho.csv				takita_tetsutaro.csv
# ismno_koka.csv				takita_tetsutarokun.csv
# ism_to_yu_gono.csv			tandokuhankoni_arazu.csv
# issekiwa.csv				tanekono_yutsu.csv
# itabasami.csv				tanitanzono_shizukana_shosetsu.csv
# itojo_oboegaki.csv			tani_tateki_fujin.csv
# itokara.csv				tanizaki_jun'ichiro_shi.csv
# iwano_homei_shi.csv			tanoshii_yumeno_nakanite.csv
# iyokuteki_sosaku_bunsho.csv		tanteino_maki.csv
# iyokuteki_sosaku_bunshono_keishiki.csv	tanteishosetsuo_kiru.csv
# izakayano_seijin.csv			tanteishosetsutowa.csv
# izawa_ranken.csv			tatsumura_heizo_shi.csv
# izukoe.csv				tayama_katai.csv
# jakyo_mondo.csv				tazaki_sounto_sonoko.csv
# jashumon.csv				tegami.csv
# jigokuhen_shinji.csv			tegami_zatsudan.csv
# jigokuhen_shohan.csv			teichono_isho.csv
# jiisan_baasan.csv			teiginjiken'o_ronzu.csv
# jimokuki.csv				teikensensei.csv
# jinro.csv				teisono_habato_genkai.csv
# jinsei_annai.csv			tenkibo.csv
# jinsei.csv				tennoheikani_sasaguru.csv
# jinsei_mittsuno_tanoshimi.csv		tenno_shoron.csv
# jipponno_hari.csv			tennoto_keiba.csv
# jirokichi_koshi.csv			tenohira_jiden.csv
# jirorino_onna.csv			tensaini_narisokonatta_otoko.csv
# jitenno_susume.csv			tenshin.csv
# jitensha_nikki.csv			tentoroku.csv
# jo_nigetai_kokoro.csv			teppo.csv
# joseini_susumeru_tosho.csv		tokaide.csv
# jozetsu.csv				tokaino_nakano_koto.csv
# juamino_tegami.csv			tokkotaini_sasagu.csv
# juensatsu.csv				tokyoni_umarete.csv
# juliano_kichisuke.csv			tokyoshohin.csv
# jusanji.csv				torano_hanashi.csv
# kabocha.csv				torokko.csv
# kachikachiyama.csv			toryu_hikakugengogaku.csv
# kaeru.csv				tosei_rakugakicho.csv
# kagaribino_onna.csv			toshishun.csv
# kage.csv				toyo_bijutsu_zufu.csv
# kagenonai_hannin.csv			toyono_aki.csv
# kagero_dangi.csv			toyoshima_yoshioshino_koto.csv
# kaicho.csv				tozaimondo.csv
# kaigara.csv				tsuchini_tsuie.csv
# kaikano_otto.csv			tsuchini_tsuite.csv
# kaikano_satsujin.csv			tsuchino_naka.csv
# kairoko.csv				tsuchino_nakakarano.csv
# kajo_chahan.csv				tsuge_shirozaemon.csv
# kakeochi.csv				tsuina.csv
# kakusanto_shokuyoku.csv			tsuioku.csv
# kamenno_hitobito.csv			tsujibasha.csv
# kamigamino_bisho.csv			tsukihino_hanashi.csv
# kamisamao_undahitobito.csv		tsukueto_futonto_onna.csv
# kamoryo.csv				tsuneto_kyoshi.csv
# kanashii_shinpu.csv			tsuri.csv
# kanazukai.csv				tsurishino_shinkyo.csv
# kanazukai_iken.csv			tsuyuno_kotae.csv
# kan'inni_yosu.csv			tsuzokusakka_kafu.csv
# kanino_awa.csv				tsuzokuto_henboto.csv
# kankanmushiwa_utau.csv			ubuya.csv
# kannenteki_sonota.csv			uchida_hyakken_shi.csv
# kano_yoni.csv				uesugikenshin.csv
# kansokano_umarederu_tameni.csv		umano_ashi.csv
# kantei.csv				ume_chirahora.csv
# kanto_zuihitsu.csv			umino_hotori.csv
# kanzan.csv				umino_kiri.csv
# kanzan_jittoku.csv			un.csv
# kanzanjittoku.csv			uogasi.csv
# kanzan_jittoku_engi.csv			uragiri.csv
# kanzanjittoku_engi_shinji.csv		ushi.csv
# kanzanjittoku_shinji.csv		utakatano_ki.csv
# kanzo_sensei.csv			utsukushii_nihonno_rekishi.csv
# kappa.csv				uwagoto.csv
# karafuto_datsugokuki.csv		uzushio.csv
# karasu.csv				vater_sergius.csv
# kare.csv				vita_sexualis.csv
# kare_daini.csv				wagachio_ou_hitobito.csv
# kareno_chosho_juhachi.csv		waga_haikaishugyo.csv
# karenosho.csv				wagahaiwa_nekodearu.csv
# karuizawade.csv				wagajinseikan_1.csv
# kasho_bunka.csv				wagajinseikan_2.csv
# kasutorisha_jiken.csv			wagajinseikan_3.csv
# katakoi.csv				wagajinseikan_4.csv
# kayo_sakushano_kotoba.csv		wagajinseikan_5.csv
# kaze_hakase.csv				wagajinseikan_6.csv
# kazehakase_kyu.csv			wagajinseikan_7.csv
# kazeto_hikarito.csv			wagajinseikan_8.csv
# kazuisuchika.csv			waga_kufuseru_ojiya.csv
# keiba.csv				waga_sanbunshi.csv
# keigoron.csv				waga_seishinno_shui.csv
# keimano_genso.csv			waga_sensoni_taisho_seru_kufu.csv
# kekkon_nan.csv				wagashisono_ibuki.csv
# kenjutsuno_gokuio_kataru.csv		wagayano_kogan.csv
# kennan_jonan.csv			wakaremo_tanoshi.csv
# kesato_morito.csv			wani.csv
# kessen_kawanakajima.csv			warai.csv
# ketto.csv				wasurerarenu_insho.csv
# kigino_sei_tanino_sei.csv		watashiga_jushigosaino_toki.csv
# kigu.csv				watashino_go.csv
# kikaina_saikai.csv			watashino_keikashita.csv
# kikanshao_minagara.csv			watashino_kojinshugi.csv
# kikokujino_ichiya.csv			watashino_shosetsu.csv
# kikoto_kyoshu.csv			watashino_soshiki.csv
# kikuchi_kan_zenshuno_jo.csv		watashinosukina_romance.csv
# kimono.csv				watashino_tanteishosetsu.csv
# kindanni_karamaru_shiteki_yoso.csv	watashiwa_dare.csv
# kinkyohokoku.csv			watashiwa_umio_dakishimete_itai.csv
# kinosita_mokutaro_cho.csv		watasiwa_umio_dakishimete.csv
# kinsen_mujo.csv				xanthis.csv
# kin_shogun.csv				yabuno_naka.csv
# kirishitohoro_shoninden.csv		yadatsusekoate_shokan.csv
# kirisute_gomen.csv			yagyu_tsukikage_sho.csv
# kiryu_tsushin.csv			yajinseikeino_koto.csv
# kiseru.csv				yakuhon_faust.csv
# kisono_yoshinaka.csv			yamanokami_satsujin.csv
# kitato_minami.csv			yamano_kifujin.csv
# kobaino_kyaku.csv			yamashigi.csv
# kobayashisanto_watashino.csv		yamaura_kiyomaro.csv
# kochiya.csv				yamirongo.csv
# kodama.csv				yaneurano_hannin.csv
# kodan_sensei.csv			yarigatake_kiko.csv
# kodanshi.csv				yarigatakeni_nobotta_ki.csv
# kodokujigoku.csv			yasui_fujin.csv
# kodoku_kandan.csv			yasukichino_techokara.csv
# kodomono_byoki.csv			yoba.csv
# koeber_rsensei.csv			yokoku_satsujin_jiken.csv
# koeber_sensei.csv			yokoku_satsujinjiken.csv
# koengunki.csv				yokosuka_shokei.csv
# kofu.csv				yokuboni_tsuite.csv
# kogarashino_sakagurakara.csv		yokyo.csv
# koio_shiniiku.csv			yonagahimeto_mimio.csv
# kojin.csv				yono_egakantosuru.csv
# koki_dokyo.csv				yononakato_onna.csv
# kokini_kaete.csv			yonosukeno_hanashi.csv
# koki_rohen_yawashu.csv			yoroppateki_seikaku.csv
# kokoro.csv				yoshihisa_shinno_nenpu.csv
# kokoro_jijo.csv				yoto_mannenhitsu.csv
# kokoro_kokoku.csv			yowa_benmeisu.csv
# kokoro_yokoku.csv			yugaono_mon.csv
# kokui_seibo.csv				yuigon_sanshu.csv
# konanno_ogi.csv				yuki.csv
# kondo_koichiro.csv			yukishigekoyo_egoisutoni.csv
# kongono_jiinseikatsu.csv		yume.csv
# konnichino_kanso.csv			yume_juya.csv
# konparukai.csv				yume_kyukana.csv
# konton.csv				yureito_bungaku.csv
# koryomu.csv				yuri.csv
# kosei.csv				yuwaku.csv
# koseigoni.csv				yuyuso.csv
# koshoku.csv				zainin.csv
# kosugi_misei.csv			zappitsu.csv
# kotanno_fukakuo_haisu.csv		zasshin_issoku.csv
# koto.csv				zenso.csv
# kotono_sorane.csv			zocho_tenno.csv
# kottokan.csv				zoku_basho_zakki.csv
# koun_ryusui.csv				zoku_bungeitekina.csv
# kubigaochita_hanashi.csv		zokubutsuseito_sakka.csv
# kubota_mantaro.csv			zoku_chokodozakki.csv
# kudan.csv				zoku_darakuron.csv
# kugenuma_zakki.csv			zoku_saihono_hito.csv
# kujaku.csv				zoku_sensoto_hitorino.csv
# kume_masao.csv				zoku_soku_bodai.csv
# kume_masaoshino_koto.csv		zoku_yajinseikeino_koto.csv
# kumokiri_enmacho.csv			zuihitsu_miyamoto_muasashi.csv
# kumono_ito.csv				zuihitsu_shihon_taiheiki.csv
# kurai_seishun.csv			zuihitsu_shinheike.csv

# %% [markdown]
# ## read data

# %%
ddf = dd.read_csv('data/Aozora/csv/*.csv')

# %%
ddf.head()
# Out:
#    Unnamed: 0       auth                       piece  \
# 0           0  sakaguchi  01_hangan_chimatao_iku.txt
# 1           1  sakaguchi  01_hangan_chimatao_iku.txt
# 2           2  sakaguchi  01_hangan_chimatao_iku.txt
# 3           3  sakaguchi  01_hangan_chimatao_iku.txt
# 4           4  sakaguchi  01_hangan_chimatao_iku.txt
#
#                                                 line
# 0                                             安吾人生案内
# 1                                        その一〔判官巷を往く〕
# 2                                               坂口安吾
# 3                                                NaN
# 4  ----------------------------------------------...

# %%
ddf = ddf.rename(columns={'Unnamed: 0':'line_num'})

# %%
ddf.dtypes
# Out:
# line_num     int64
# auth        object
# piece       object
# line        object
# dtype: object

# %%
ddf['auth'].unique().compute()
# Out:
# 0    sakaguchi
# 1    yoshikawa
# 2    akutagawa
# 3         mori
# 4      natsume
# Name: auth, dtype: object

# %%
# filter lines
# line number >=20 and number of letters >= 20
ddf[(ddf['line_num']>=20) & (ddf['line'].str.len()>=20)].sample(frac=0.2).head()
# Out:
#      line_num       auth                       piece  \
# 170       170  sakaguchi  01_hangan_chimatao_iku.txt
# 234       234  sakaguchi  01_hangan_chimatao_iku.txt
# 129       129  sakaguchi  01_hangan_chimatao_iku.txt
# 235       235  sakaguchi  01_hangan_chimatao_iku.txt
# 295       295  sakaguchi  01_hangan_chimatao_iku.txt
#
#                                                   line
# 170  概して彼らの特異性は視覚よりも聴覚にくるものがグロテスクで、一見して男と分らなくとも、声をき...
# 234  少年の低能ぶりは、やがてもっと低能ではなくなるだろうし、低能でなくなれば、という救いはあると...
# 129            人間の気持はたとえ十六の少年でも、そう単純で、ハッキリしたものではあり得ない。
# 235                           崇高な殺人などを冷静に考える低能には救いがない。
# 295                  ジミーとは、もう別れられないのではないかという気もするんですが……

# %%
ddf_fitered = ddf.loc[(ddf['line_num']>=20) & (ddf['line'].str.len()>=20),['auth','line']]

# %%
ddf_fitered['auth'].unique().compute()
# Out:
# 0    sakaguchi
# 1    yoshikawa
# 2    akutagawa
# 3         mori
# 4      natsume
# Name: auth, dtype: object

# %%
ddf_fitered.groupby('auth').count().compute()
# Out:
#              line
# auth
# sakaguchi   96401
# yoshikawa  224517
# akutagawa   45793
# mori        54211
# natsume     68801

# %%
ddf_fitered.shape[0].compute()
# Out:
# 489723

# %% [markdown]
# ### train test split

# %%
df = ddf_fitered.compute()

# %%
df.head()
# Out:
#          auth                                               line
# 23  sakaguchi              仕事の用で旅にでることが多いので、その期間の新聞を読み損うことが少くない。
# 24  sakaguchi  旅から戻ってきて、たまった古新聞を一々見る気持にもならないので、いろいろの重大ニュースを知ら...
# 26  sakaguchi  そんな次第で、オール読物の編輯部からきた三ツの手記のうち、二ツの出来事はちょうど私が旅行中で...
# 27  sakaguchi  もっとも、一ツはラジオの社会の窓だそうだが、ラジオが探訪する以上は直前に新聞記事でもあったはずだ。
# 29  sakaguchi  はじめの相談では、月々の今日的な出来事、主として犯罪の犯人の手記にもとづく社会時評というので...

# %%
trn_val, tst = train_test_split(df,test_size=0.05,random_state=0)

# %%
trn, val = train_test_split(trn_val,test_size=5/95,random_state=0)

# %%
trn.head()
# Out:
#            auth                                               line
# 1588  yoshikawa                          『いちど、もっとひどく、血を吐いたこともあるから』
# 5134  yoshikawa                   ――で、ここの大廊下を鈴の間の廊と呼びならわしているのであった。
# 5156  yoshikawa           旅先だと思ってたくさんおいじめ、高麗村へ帰ったらお祖父様にいいつけてあげるから」
# 479   akutagawa  今度掲げるだけに「大導寺信輔の半生」と言う題は相当しないのに違いないが、他に替る題もない為に...
# 6267  yoshikawa                        底本：「私本太平記（五）」吉川英治歴史時代文庫、講談社

# %%
val.head()
# Out:
#            auth                                               line
# 300   akutagawa  しかし、私が閣下にこう云う事を御訴え致すのは、単に私たち夫妻に無理由な侮辱が加えられるからば...
# 2652  yoshikawa         「――強右衛門とやら、万死に一生もあるまじき中を、よくこれまで使いに参ってくれたな。
# 290   akutagawa  それからは、「ただあなたがお気の毒ね」と申して、じっと私の顔を見つめたきり、涙を乾かしてしま...
# 21    akutagawa                            まるで濡れた壁土のような、重苦しい黄色である。
# 6354  yoshikawa                      関羽は打ち消して、しきりと陽気な話題へわざと話をそらした。

# %%
tst.head()
# Out:
#           auth                                               line
# 50   akutagawa  あの皸だらけの頬は愈赤くなつて、時々｜鼻洟をすすりこむ音が、小さな息の切れる声と一しよに、せ...
# 89   sakaguchi  私は検事の訊問などにも、易者と同じような最大公約数的な設問法がとりいれられているムキがあるよ...
# 872  yoshikawa   ――で、昨日から、六波羅兵と放免（密偵）どもの、煮炊きの跡や馬糞やらで、そこは狼藉を極めていた。
# 536  akutagawa                    今日の本所は火事には会っても、洪水には会うことはないであろう。
# 448  akutagawa  ところが、その日は、小姓の手から神酒を入れた瓶子を二つ、三宝へのせたまま受取って、それを神前...

# %%
print('Data size')
print('Train: {}'.format(trn.shape[0]))
print('Validate: {}'.format(val.shape[0]))
print('Test: {}'.format(tst.shape[0]))
# Out:
# Data size
# Train: 440749
# Validate: 24487
# Test: 24487

# %% [markdown]
# ### save

# %%
trn.to_csv('data/Aozora/train.csv',header=None,index=None)

# %%
val.to_csv('data/Aozora/valid.csv',header=None,index=None)

# %%
tst.to_csv('data/Aozora/test.csv',header=None,index=None)

# %% [markdown]
# ## prepare data for lm fine tuning and classification
# basically copying from train_cls.py

# %%
data_dir='data'
lang='ja' 
cuda_id=0 
pretrain_name='wt-100' 
model_dir='data/wiki/ja-100/models'
fig_dir='data/wiki/ja-100/figs'
max_vocab=8000
name='Aozora-clas'
dataset='Aozora' 
frac_ds=1.0
spm_dir = 'data/wiki/ja/'

# %%
data_dir = Path(data_dir)
assert data_dir.name == 'data',\
    f'Error: Name of data directory should be data, not {data_dir.name}.'
dataset_dir = data_dir / dataset
model_dir = Path(model_dir)
fig_dir = Path(fig_dir)
fig_dir.mkdir(exist_ok=True)

# %%
if not torch.cuda.is_available():
    print('CUDA not available. Setting device=-1.')
    cuda_id = -1
torch.cuda.set_device(cuda_id)

print(f'Dataset: {dataset}. Language: {lang}.')
# Out:
# Dataset: Aozora. Language: ja.

# %%
# here we're just loading the trained spm model
sp = get_sentencepiece(spm_dir, None, 'wt-all', vocab_size=max_vocab)

# %%
# load train, valid in df
train_df = pd.read_csv(dataset_dir/'train.csv',header=None)
valid_df = pd.read_csv(dataset_dir/'valid.csv',header=None)
test_df = pd.read_csv(dataset_dir/'test.csv',header=None)

# %%
train_df.head()
# Out:
#            0                                                  1
# 0  yoshikawa                          『いちど、もっとひどく、血を吐いたこともあるから』
# 1  yoshikawa                   ――で、ここの大廊下を鈴の間の廊と呼びならわしているのであった。
# 2  yoshikawa           旅先だと思ってたくさんおいじめ、高麗村へ帰ったらお祖父様にいいつけてあげるから」
# 3  akutagawa  今度掲げるだけに「大導寺信輔の半生」と言う題は相当しないのに違いないが、他に替る題もない為に...
# 4  yoshikawa                        底本：「私本太平記（五）」吉川英治歴史時代文庫、講談社

# %% [markdown]
# ### lm data

# %%
data_lm = TextLMDataBunch.from_df(path=dataset_dir,train_df=train_df,valid_df=valid_df,test_df=test_df,**sp)

# %% [markdown]
# ### classification data

# %%
data_clas = TextClasDataBunch.from_df(path=dataset_dir,train_df=train_df,valid_df=valid_df,test_df=test_df,**sp)

# %%
data_clas.valid_ds.y.c2i
# Out:
# {'akutagawa': 0, 'mori': 1, 'natsume': 2, 'sakaguchi': 3, 'yoshikawa': 4}

# %% [markdown]
# ### save textdatabunch with multiple data sizes for train
# - save time when testing models with different train data sizes

# %%
cache_name='tmp/lm/full'
caceh_name = Path(cache_name)

# %%
data_lm.save(cache_name)

# %%
data_lm.path
# Out:
# PosixPath('data/Aozora')

# %%
Path(data_dir/dataset)
# Out:
# PosixPath('data/Aozora')

# %%
data_lm_read = TextLMDataBunch.load(path=Path(data_dir/dataset),cache_name=cache_name)

# %%
data_lm
# Out:
# TextLMDataBunch;
# Train: LabelList
# y: LMLabel (440749 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/Aozora
# x: LMTextList (440749 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁『 いち ど 、 も っと ひ ど く 、 血 を 吐 いた こともある から 』, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ― ― で 、 ここ の大 廊 下 を 鈴 の間 の 廊 と 呼び なら わ している の であった 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 旅 先 だと 思 って た く さん お い じ め 、 高 麗 村 へ 帰 った ら お 祖父 様 に いい つけ て あげ る から 」, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 今 度 掲げ る だけ に 「 大 導 寺 信 輔 の 半 生 」 と言う 題 は 相当 しない の に 違い ない が 、 他に 替 る 題 もない 為 に や む を得 ず 用いる ことに した 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 底 本 : 「 私 本 太 平 記 ( 五 )」 吉 川 英 治 歴史 時代 文庫 、 講談社]...
# Path: data/Aozora;
# Valid: LabelList
# y: LMLabel (24487 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/Aozora
# x: LMTextList (24487 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁しかし 、 私 が 閣 下 に こう <unk> う 事 を 御 訴え 致 す の は 、 単 に 私 たち 夫妻 に 無 理由 な <unk> が 加 え られる から ばかり では ご ざ い ま せん 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁「 ― ― 強 右衛門 と や ら 、 万 死 に 一 生 もある ま じ き 中 を 、 よく これまで 使い に 参 って く れた な 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ それ からは 、「 ただ あなた が お 気 の 毒 ね 」 と 申し て 、 じ っと 私 の 顔 を見 つ めた き り 、 涙 を 乾 か し てしまい ま した 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ まる で <unk> れた 壁 土 のような 、 重 苦し い 黄色 である 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 関 羽 は 打ち 消 して 、 し き り と 陽 気 な 話題 へ わ ざ と 話 を そ ら した 。]...
# Path: data/Aozora;
# Test: LabelList
# y: LMLabel (24487 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/Aozora
# x: LMTextList (24487 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ あ の <unk> だ ら け の <unk> は <unk> 赤 く な つ て 、 時 々 | 鼻 <unk> を す す り こ む 音 が 、 小さな 息 の 切れ る 声 と 一 し よ に 、 せ は し なく 耳 へ は い つ て 来 る 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 私 は 検 事 の <unk> 問 など にも 、 易 者 と同じ ような 最大 公 約 数 的な 設 問 法 が と り い れ られている ム キ がある ような 気 が する 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ― ― で 、 <unk> 日から 、 六 波 羅 兵 と 放 免 ( 密 偵 ) ど もの 、 <unk> き の 跡 や 馬 <unk> や ら で 、 そこ は 狼 <unk> を 極めて いた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 今日 の 本 所 は 火 事 には 会 って も 、 洪水 には 会 うこと はない であろう 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ところ が 、 その 日 は 、 小 姓 の 手 から 神 酒 を 入れた <unk> 子 を 二 つ 、 三 宝 への せ た まま 受 取 って 、 それを 神 前 へ 備え よう とする と 、 どう した 拍 子 か <unk> 子は 二 つ とも 倒れ て 、 神 酒 が 外 へ こ ぼ れ てしまった 。]...
# Path: data/Aozora

# %%
data_lm_read
# Out:
# TextLMDataBunch;
# Train: LabelList
# y: LMLabel (440749 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/Aozora
# x: LMTextList (440749 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁『 いち ど 、 も っと ひ ど く 、 血 を 吐 いた こともある から 』, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ― ― で 、 ここ の大 廊 下 を 鈴 の間 の 廊 と 呼び なら わ している の であった 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 旅 先 だと 思 って た く さん お い じ め 、 高 麗 村 へ 帰 った ら お 祖父 様 に いい つけ て あげ る から 」, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 今 度 掲げ る だけ に 「 大 導 寺 信 輔 の 半 生 」 と言う 題 は 相当 しない の に 違い ない が 、 他に 替 る 題 もない 為 に や む を得 ず 用いる ことに した 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 底 本 : 「 私 本 太 平 記 ( 五 )」 吉 川 英 治 歴史 時代 文庫 、 講談社]...
# Path: data/Aozora;
# Valid: LabelList
# y: LMLabel (24487 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/Aozora
# x: LMTextList (24487 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁しかし 、 私 が 閣 下 に こう <unk> う 事 を 御 訴え 致 す の は 、 単 に 私 たち 夫妻 に 無 理由 な <unk> が 加 え られる から ばかり では ご ざ い ま せん 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁「 ― ― 強 右衛門 と や ら 、 万 死 に 一 生 もある ま じ き 中 を 、 よく これまで 使い に 参 って く れた な 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ それ からは 、「 ただ あなた が お 気 の 毒 ね 」 と 申し て 、 じ っと 私 の 顔 を見 つ めた き り 、 涙 を 乾 か し てしまい ま した 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ まる で <unk> れた 壁 土 のような 、 重 苦し い 黄色 である 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 関 羽 は 打ち 消 して 、 し き り と 陽 気 な 話題 へ わ ざ と 話 を そ ら した 。]...
# Path: data/Aozora;
# Test: LabelList
# y: LMLabel (24487 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/Aozora
# x: LMTextList (24487 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ あ の <unk> だ ら け の <unk> は <unk> 赤 く な つ て 、 時 々 | 鼻 <unk> を す す り こ む 音 が 、 小さな 息 の 切れ る 声 と 一 し よ に 、 せ は し なく 耳 へ は い つ て 来 る 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 私 は 検 事 の <unk> 問 など にも 、 易 者 と同じ ような 最大 公 約 数 的な 設 問 法 が と り い れ られている ム キ がある ような 気 が する 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ― ― で 、 <unk> 日から 、 六 波 羅 兵 と 放 免 ( 密 偵 ) ど もの 、 <unk> き の 跡 や 馬 <unk> や ら で 、 そこ は 狼 <unk> を 極めて いた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 今日 の 本 所 は 火 事 には 会 って も 、 洪水 には 会 うこと はない であろう 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ところ が 、 その 日 は 、 小 姓 の 手 から 神 酒 を 入れた <unk> 子 を 二 つ 、 三 宝 への せ た まま 受 取 って 、 それを 神 前 へ 備え よう とする と 、 どう した 拍 子 か <unk> 子は 二 つ とも 倒れ て 、 神 酒 が 外 へ こ ぼ れ てしまった 。]...
# Path: data/Aozora

# %% [markdown]
# successfully saved and loaded full length TextLMDataBunch

# %%
cache_name = Path('tmp/clas/full')
data_clas.save(cache_name)

# %%
data_clas_read = TextClasDataBunch.load(path=Path(data_dir/dataset),cache_name=cache_name)

# %%
data_clas_read
# Out:
# TextClasDataBunch;
# Train: LabelList
# y: CategoryList (440749 items)
# [Category yoshikawa, Category yoshikawa, Category yoshikawa, Category akutagawa, Category yoshikawa]...
# Path: .
# x: TextList (440749 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁『 いち ど 、 も っと ひ ど く 、 血 を 吐 いた こともある から 』, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ― ― で 、 ここ の大 廊 下 を 鈴 の間 の 廊 と 呼び なら わ している の であった 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 旅 先 だと 思 って た く さん お い じ め 、 高 麗 村 へ 帰 った ら お 祖父 様 に いい つけ て あげ る から 」, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 今 度 掲げ る だけ に 「 大 導 寺 信 輔 の 半 生 」 と言う 題 は 相当 しない の に 違い ない が 、 他に 替 る 題 もない 為 に や む を得 ず 用いる ことに した 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 底 本 : 「 私 本 太 平 記 ( 五 )」 吉 川 英 治 歴史 時代 文庫 、 講談社]...
# Path: data/Aozora;
# Valid: LabelList
# y: CategoryList (24487 items)
# [Category akutagawa, Category yoshikawa, Category akutagawa, Category akutagawa, Category yoshikawa]...
# Path: .
# x: TextList (24487 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁しかし 、 私 が 閣 下 に こう <unk> う 事 を 御 訴え 致 す の は 、 単 に 私 たち 夫妻 に 無 理由 な <unk> が 加 え られる から ばかり では ご ざ い ま せん 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁「 ― ― 強 右衛門 と や ら 、 万 死 に 一 生 もある ま じ き 中 を 、 よく これまで 使い に 参 って く れた な 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ それ からは 、「 ただ あなた が お 気 の 毒 ね 」 と 申し て 、 じ っと 私 の 顔 を見 つ めた き り 、 涙 を 乾 か し てしまい ま した 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ まる で <unk> れた 壁 土 のような 、 重 苦し い 黄色 である 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 関 羽 は 打ち 消 して 、 し き り と 陽 気 な 話題 へ わ ざ と 話 を そ ら した 。]...
# Path: data/Aozora;
# Test: LabelList
# y: CategoryList (24487 items)
# [Category yoshikawa, Category yoshikawa, Category yoshikawa, Category yoshikawa, Category yoshikawa]...
# Path: .
# x: TextList (24487 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ あ の <unk> だ ら け の <unk> は <unk> 赤 く な つ て 、 時 々 | 鼻 <unk> を す す り こ む 音 が 、 小さな 息 の 切れ る 声 と 一 し よ に 、 せ は し なく 耳 へ は い つ て 来 る 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 私 は 検 事 の <unk> 問 など にも 、 易 者 と同じ ような 最大 公 約 数 的な 設 問 法 が と り い れ られている ム キ がある ような 気 が する 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ― ― で 、 <unk> 日から 、 六 波 羅 兵 と 放 免 ( 密 偵 ) ど もの 、 <unk> き の 跡 や 馬 <unk> や ら で 、 そこ は 狼 <unk> を 極めて いた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 今日 の 本 所 は 火 事 には 会 って も 、 洪水 には 会 うこと はない であろう 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ ところ が 、 その 日 は 、 小 姓 の 手 から 神 酒 を 入れた <unk> 子 を 二 つ 、 三 宝 への せ た まま 受 取 って 、 それを 神 前 へ 備え よう とする と 、 どう した 拍 子 か <unk> 子は 二 つ とも 倒れ て 、 神 酒 が 外 へ こ ぼ れ てしまった 。]...
# Path: data/Aozora

# %%
# full train data has about 400k items so these numbers of train data will be saved for experiments
num_trains = [1e2,1e3,1e4,1e5]

# %%
for num_train in num_trains:
    num_train = int(num_train)
    print(num_train)
    
    # sample train data
    tmp_train_df = train_df.sample(n=num_train,random_state=42)
    
    # create data bunches
    tmp_lm = TextLMDataBunch.from_df(path=dataset_dir,train_df=tmp_train_df,valid_df=valid_df,test_df=test_df,**sp)
    tmp_clas = TextClasDataBunch.from_df(path=dataset_dir,train_df=tmp_train_df,valid_df=valid_df,test_df=test_df,**sp)
    
    # name of tmp cache
    tmp_cache_lm = Path(f'tmp/lm/{num_train}')
    tmp_cache_clas = Path(f'tmp/clas/{num_train}')
    
    # save
    tmp_lm.save(tmp_cache_lm)
    tmp_clas.save(tmp_cache_clas)

# %% [markdown]
# # LM fine tuning & Classification

# %%
def lm_fine_tuning( data_lm, lm_lr, bptt, emb_sz, nh, nl, qrnn,
                pad_token,
                pretrained_fnames, 
                model_dir,
                lm_enc_finetuned,
                lm_drop_mult, use_pretrained_lm,fine_tune_lm):
    
    
    if not use_pretrained_lm:
        pretrained_fnames = None
    
    learn = language_model_learner(
        data_lm, bptt=bptt, emb_sz=emb_sz, nh=nh, nl=nl, qrnn=qrnn,
        pad_token=pad_token,
        pretrained_fnames=pretrained_fnames, 
        path=model_dir.parent, model_dir=model_dir.name,
        drop_mult=lm_drop_mult
    )
    
    if fine_tune_lm:
        print('Fine-tuning the language model...')
        learn.unfreeze()
        learn.fit(4, slice(lm_lr/(10**2), lm_lr))
    #     learn.fit(10, slice(1e-3, 1e-1))
    else:
        print('Skipping fine tuning')

    # save fine tuned lm
    print(f"Saving models at {learn.path / learn.model_dir}")
    learn.save_encoder(lm_enc_finetuned)
    
    return learn

# %%
def classify_multiclas(data_clas, clas_lr, bptt, 
                        pad_token,
                        model_dir,
                        qrnn, emb_sz, nh, nl,clas_drop_mult,
                        fine_tune_lm, use_lm,cls_weights):
    
    
    print("Starting classifier training")
    learn = text_classifier_learner(data_clas, bptt=bptt, pad_token=pad_token,
                                  path=model_dir.parent, model_dir=model_dir.name,
                                  qrnn=qrnn, emb_sz=emb_sz, nh=nh, nl=nl,drop_mult=clas_drop_mult
                                    )
    learn.model.reset()
    
    if use_lm:
        print('Loading language model')
        lm_enc = lm_enc_finetuned # if fine_tune_lm else lm_name
        learn.load_encoder(lm_enc)
    else:
        print('Training from scratch without language model')

    # train
    learn.freeze_to(-1)
    learn.fit_one_cycle(1, clas_lr, moms=(0.8, 0.7), wd=1e-7)

    learn.freeze_to(-2)
    learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)

    learn.freeze_to(-3)
    learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)

    learn.unfreeze()
    learn.fit_one_cycle(2, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)
    
    # results
    results={}
    results['accuracy_multi'] = learn.validate()[1]
    results['F1'] = learn.validate()[2]
    print(results)
    
    # save classifier
    print(f"Saving models at {learn.path / learn.model_dir}")
    learn.save(f'{model_name}_{name}')
    
    # prediction on validation data
    preds=learn.get_preds()

    # prediction
    p=preds[0]
    p = p.tolist()
    p = np.asarray(p)

    # binarize
    y_pred = (p>=0.5)*1.0


    # target
    t = preds[1].tolist()
    y_true = np.asarray(t)
    
    return y_true, y_pred

# %%
def evaluation(y_true,y_pred):
    ## metrics
    f1_micro = f1_score(y_true,y_pred,average='micro')
    f1_macro = f1_score(y_true,y_pred,average='macro')

    print('F1 score')
    print('micro: {}'.format(f1_micro))
    print('macro: {}'.format(f1_macro))

    precision_micro = precision_score(y_true,y_pred,average='micro')
    precision_macro = precision_score(y_true,y_pred,average='macro')

    print('\nPrecision score')
    print('micro: {}'.format(precision_micro))
    print('macro: {}'.format(precision_macro))

    recall_micro = recall_score(y_true,y_pred,average='micro')
    recall_macro = recall_score(y_true,y_pred,average='macro')

    print('\nRecall score')
    print('micro: {}'.format(recall_micro))
    print('macro: {}'.format(recall_macro))
    
    acc = accuracy_score(y_true,y_pred,average='macro')

    print('\nAccuracy score: {}'.format(acc))
    
    results = dict(
        f1_micro=f1_micro,
        f1_macro=f1_macro,
        precision_micro=precision_micro,
        precision_macro=precision_macro,
        recall_micro=recall_micro,
        recall_macro=recall_macro,
        accuracy=acc
    )
    
    return results

# %% [markdown]
# ###  Parameters

# %%
# common to lm fine tuning and classification
qrnn=True
bs=20 
bptt=70
pad_token=PAD_TOKEN_ID

if qrnn:
    emb_sz, nh, nl = 400, 1550, 3
else:
    emb_sz, nh, nl = 400, 1150, 3
    
# lm fine tuning
fine_tune_lm=True 
lm_lr=2e-2
lm_drop_mult=0.5
use_pretrained_lm=True

# classification
clas_lr=2e-2
clas_drop_mult=0.1
use_lm=True

# reduction of training data
frac_ds = 1.0

# %% [markdown]
# ### look for appropriate lrs

# %%
# train num_train items
num_train = 10000
data_lm = TextLMDataBunch.load(path=Path(data_dir/dataset),cache_name=Path(f'tmp/lm/{num_train}'))
data_clas = TextClasDataBunch.load(path=Path(data_dir/dataset),cache_name=Path(f'tmp/clas/{num_train}'))

# %%
# lm
model_name = 'qrnn' if qrnn else 'lstm'
lm_name = f'{model_name}_{pretrain_name}'
pretrained_fnames = (lm_name, f'itos_{pretrain_name}')

ensure_paths_exists(data_dir,
                    dataset_dir,
                    model_dir,
                    model_dir/f"{pretrained_fnames[0]}.pth",
                    model_dir/f"{pretrained_fnames[1]}.pkl")
lm_enc_finetuned  = f"{lm_name}_{dataset}_enc"
learn = language_model_learner(
    data_lm, bptt=bptt, emb_sz=emb_sz, nh=nh, nl=nl, qrnn=qrnn,
    pad_token=pad_token,
    pretrained_fnames=pretrained_fnames, 
    path=model_dir.parent, model_dir=model_dir.name,
    drop_mult=lm_drop_mult
)

learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lm_lr = 1e-2
learn.fit(4, slice(lm_lr/(10**2), lm_lr))
# Out:
# Total time: 02:43
# epoch  train_loss  valid_loss  accuracy
# 1      4.425859    3.879478    0.349505  (00:40)
# 2      4.171316    3.812047    0.354901  (00:40)
# 3      4.030075    3.769356    0.359484  (00:41)
# 4      3.924823    3.749217    0.361631  (00:41)

# %%
learn.save_encoder(lm_enc_finetuned)

# %%
learn.predict('料金が高い',n_words=200,no_unk=False)
# Out:
# Total time: 00:12
# '料金が高い 美 を 、 従来の 補 のみ 勇 がない 、 フ ギ グ ロック 海岸 <unk> 13 と 寝 で 楽 ば ない ん を 当 ペ チ 論理 宅 は 、 マーケット で 、 「 あらゆる 、 半 所 の 刺 され ない の 丹 洲 機 に 飛 り 、 夕 、 鉄 時 勝 とも 、 や 、 他の 15 ポ ク ア フ ト コ ラ ショ タ ミン ろ ▁ 彼 な の 方 べ で る ね らい この 場所 などで 腰 手 を ぬ 三 世 を 出た 影響 の <unk> 一つ 聖 、 俺 が 働き し の 他に 階 の うえ 人 とは 、 代 を 納 に 降 寄 り 厳 <unk> <unk> よ <unk> ( カル モ ラ ミ エ チ ▁ 若 大手 の 隆 政 共 出す 白 土 川 、 自ら 一 価 1 中央 の <unk> 戦後 に する に い な 在 任 創 紀 椎 ▁/ 内 は 見 に 、 大 を 、 真 で 引き かけた お ▁ 1 に ) ▁ とし コ ト ト イ リア など 同じ 、 ▁ xxbos ▁ 石 に 中国 などが 一 伊 織 に'

# %%
# change metric from accuracy to accuarcy_thresh and f1
accuracy_multi =  partial(accuracy_thresh,thresh=0.5,sigmoid=True)
f1 = partial(fbeta,thresh=0.5,beta=1,sigmoid=True) # corresponds to f1 score in sklearn with 'samples' option?

print("Starting classifier training")
learn = text_classifier_learner(data_clas, bptt=bptt, pad_token=pad_token,
                              path=model_dir.parent, model_dir=model_dir.name,
                              qrnn=qrnn, emb_sz=emb_sz, nh=nh, nl=nl,drop_mult=clas_drop_mult
                                )
learn.model.reset()

if use_lm:
    print('Loading language model')
    lm_enc = lm_enc_finetuned # if fine_tune_lm else lm_name
    learn.load_encoder(lm_enc)
else:
    print('Training from scratch without language model')

# change metric
# learn.metrics = [accuracy_multi,f1]

# CRITICAL STEP
#- need to adjust pos_weight of loss function to get the model working
# if cls_weights is not None:
#     pos_weight = torch.cuda.FloatTensor(cls_weights[data_clas.train_ds.y.classes].values)
#     bce_logits_weighted = partial(F.binary_cross_entropy_with_logits,  pos_weight=pos_weight)
#     learn.loss_func = bce_logits_weighted

# train
learn.freeze_to(-1)
# Out:
# Starting classifier training
# Loading language model

# %%
learn.loss_func
# Out:
# <function torch.nn.functional.cross_entropy(input, target, weight=None, size_average=None, ignore_index=-100, reduce=None, reduction='mean')>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
clas_lr = 1e-2
learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)
# Out:
# Total time: 00:54
# epoch  train_loss  valid_loss  accuracy
# 1      1.031910    1.031520    0.624086  (00:54)

# %%
learn.freeze_to(-2)
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
clas_lr = 1e-2
learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)
# Out:
# Total time: 00:55
# epoch  train_loss  valid_loss  accuracy
# 1      0.883861    1.006253    0.625148  (00:55)

# %%
learn.freeze_to(-3)
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
clas_lr = 1e-6
learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)
# Out:
# Total time: 01:03
# epoch  train_loss  valid_loss  accuracy
# 1      0.818259    1.020418    0.616368  (01:03)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# prediction on validation data
preds=learn.get_preds()

# prediction
p=preds[0]
p = p.tolist()
p = np.asarray(p)

# binarize
y_pred = p.argmax(axis=1)


# target
t = preds[1].tolist()
y_true = np.asarray(t)

# %%
p[:5]
# Out:
# array([[0.045355, 0.206556, 0.367422, 0.253116, 0.12755 ],
#        [0.092752, 0.125506, 0.123425, 0.497199, 0.161118],
#        [0.150209, 0.346157, 0.309478, 0.094615, 0.099541],
#        [0.147807, 0.130166, 0.162102, 0.515924, 0.044001],
#        [0.121534, 0.14517 , 0.083663, 0.49848 , 0.151153]])

# %%
y_pred[:5]
# Out:
# array([2, 3, 1, 3, 3])

# %%
y_true[:5]
# Out:
# array([2, 2, 2, 3, 0])

# %%
data_clas.train_ds.y.classes
# Out:
# array(['akutagawa', 'mori', 'natsume', 'sakaguchi', 'yoshikawa'], dtype='<U9')

# %%
plt.hist(y_pred)
# Out:
# (array([1391.,    0., 2597.,    0.,    0., 2701.,    0., 8762.,    0., 9036.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(y_true)
# Out:
# (array([ 2278.,     0.,  2646.,     0.,     0.,  3455.,     0.,  4816.,     0., 11292.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data_clas.train_ds.y.items.astype(int))
# Out:
# (array([ 937.,    0., 1104.,    0.,    0., 1432.,    0., 1911.,    0., 4616.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
y_true.shape
# Out:
# (24487,)

# %%
accuracy_score(y_true,y_pred)
# Out:
# 0.6163678686650059

# %%
confusion_matrix(y_true,y_pred)
# Out:
# array([[ 603,  264,  289,  821,  301],
#        [ 196, 1195,  265,  796,  194],
#        [ 186,  313, 1508, 1144,  304],
#        [ 158,  136,  188, 3942,  392],
#        [ 248,  689,  451, 2059, 7845]])

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
#     if normalize:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
class_names = data_clas.valid_ds.y.classes
class_names
# Out:
# array(['akutagawa', 'mori', 'natsume', 'sakaguchi', 'yoshikawa'], dtype='<U9')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_true, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix')

# %% [markdown]
# - 夏目漱石と予測して間違えることが多い。文体が平均的なのか、それとも他のみんなに影響を与えているからか
# - 坂口安吾の文章は他の著者と間違えられることが多い。文体が揺れている？

# %%
train_df[train_df[0]=='sakaguchi'].head(20)
# Out:
#             0                                                  1
# 7   sakaguchi                      否、家出後の暫時の目鼻がほぼリンカクをなしていたのである。
# 15  sakaguchi       つまり荒君は非常に現実家のようだが、根柢的には夢想児なので、平野君とて、やっぱりそうだ。
# 22  sakaguchi                           一般に犬は飼主を信頼するが人間を信頼していない。
# 24  sakaguchi               モチ竿の先端を見ている犬の目は、恐怖と、アワレミを乞う断末魔の目である。
# 26  sakaguchi             だから、昨晩のような不景気なときなら、第一、下の夫婦がグズグズしてやしない。
# 27  sakaguchi                             「うちのチンピラは先生の愛読者なんですのよ。
# 28  sakaguchi                    「オレはとにかく、今夜からは、サクラ拳闘クラブへ居候の合宿だ。
# 39  sakaguchi     誰しも人にお説教する程度の物の理は弁えていても、自分自身が理の如くに行為できるわけではない。
# 41  sakaguchi                               まもなく二人の見知らぬ訪客が現れたのだ。
# 44  sakaguchi               ボクは強盗して生きのびるほどの度胸はないから、死ぬよりほかに仕方がない。
# 45  sakaguchi                       その壁際には他に人の姿が近づいたことはなかったようです。
# 50  sakaguchi  知人から邸を借りたいと話があった時にも、本当に利き目のある術ではなくて、インチキと承知で世界...
# 53  sakaguchi  のみならず、小説は小説全体として完成さるべきものであるから、個々の文章が如何ほど独立した完璧...
# 67  sakaguchi                          二本の光芒は客席の真上をクルクル狂いみだれている。
# 71  sakaguchi                              いつでも何クソとねばらなければいけないわ。
# 77  sakaguchi  「もともと後家といふものは助平だとさ」大晦日の夜、他巳吉は、たしかそのやうに鼻唄を唄つた筈である。
# 86  sakaguchi                     邪教的な要素と最も絶縁されたものでなければならないのである。
# 87  sakaguchi                            お前は私の時間は出席しなくてもいゝ、と言つた。
# 88  sakaguchi                             「向う見ずに取引きをひろげたってダメですよ。
# 89  sakaguchi                          こんな風に考えているのは、よくないことかも知れぬ。

# %%
train_df[train_df[0]=='natsume'].head(20)
# Out:
#            0                                                  1
# 17   natsume               ことに病気になって仰向に寝てからは、絶えず美くしい雲と空が胸に描かれた。
# 21   natsume  けれどもそれは強がちに、自分達の身の上について、特に御米の注意を惹くために口にした、故意の観...
# 25   natsume           私がここでとくに「近頃」と断ったのは、書生時代の古い回想から来たものであります。
# 32   natsume                      小林は押問答の末、とうとう三枚のうち一枚を原の手に渡した。
# 38   natsume        向うの方で凸凹の地面をならして新墓地を作っている男が、鍬の手を休めて私たちを見ていた。
# 40   natsume                              茶碗を下へ置かないで、そのまま口へつけた。
# 42   natsume                      「堀田には出せ、私には出さないで好いと云う法がありますか」
# 47   natsume                 ……」ここにウィリアムとあるはわが四世の祖だとウィリアムが独り言う。
# 52   natsume                武者絵、錦絵、二枚つづき三枚つづきの絵も彼のいうがままに買ってくれた。
# 56   natsume                             「なるほど梅に鶯だ」と自分も云いたくなった。
# 58   natsume                               ようやくのことで、美禰子のそばまで来て、
# 65   natsume  嫂の前へ出て、こう差し向いに坐ったが最後、とうてい真底から誠実に兄のために計る事はできないの...
# 68   natsume                              すると偶然｜下のようなのが彼の眼に触れた。
# 69   natsume  それからは弁当の死骸｜即ち竹の皮、古新聞、あるいは古草履、古下駄、ふると云う名のつくものを大...
# 83   natsume            学者の例証するところによると、一｜疋の大口魚が毎年生む子の数は百万疋とか聞く。
# 95   natsume                 しばらくすると向う岸から長い手を出して余を引張るかと怪しまれて来た。
# 99   natsume                            カンフル、カンフルと云う杉本さんの声が聞えた。
# 104  natsume                いくら謝まったってどうしたって事実を取り消す訳には行かないんですもの」
# 106  natsume  腰から上といえども、降る雨に誘われて着く、よなを、一面に浴びたから、ほとんど下水へ落ち込んだ...
# 119  natsume  あるくのは御随意だが、権利が同等であるときまったなら、衝突しそうな場合には御互に示談をして、...

# %%
train_df[train_df[0]=='akutagawa'].head(20)
# Out:
#              0                                                  1
# 3    akutagawa  今度掲げるだけに「大導寺信輔の半生」と言う題は相当しないのに違いないが、他に替る題もない為に...
# 9    akutagawa                         水はただ突当りの橋の下へまっ直に一すじつづいている。
# 10   akutagawa  現にビルコフの伝記によれば、あの逞しいトルストイさへ半狂乱になつて家出したのは、つい近頃の新...
# 11   akutagawa               更に又諸家の文芸評論の中にもタイチ派とフランス派とのあるのを感じてゐる。
# 29   akutagawa            ではなぜその話を信じないのか？幽霊などを見る者は迷信に囚われて居るからである。
# 66   akutagawa                            彼は特に、和泉屋のこの感服を好まないのである。
# 72   akutagawa                       お蓮もまたどうかすると、弥勒寺橋の方へ引っ返そうとする。
# 79   akutagawa                            僕も亦僕の一家に天才のないことに安んじてゐる。
# 82   akutagawa           殊に僕の親友だつた、嘴の腐つた学生のラツプは、――或けふのやうに曇つた午後です。
# 109  akutagawa     「実は手遅れになった病人だしするから、せめて火葬にする時だけは一等にしたいと思うんですがね。
# 113  akutagawa                         それは或は愛よりも憐みに近いものだつたかも知れない。
# 121  akutagawa      「行はれない？だつてあなたの話ではあなたがたもやはり我々のやうに行つてゐると思ひますがね。
# 138  akutagawa                            僕「じゃどこの野菜のことを知っているのです？」
# 167  akutagawa        それは葦原醜男を殺した事が、何となく彼の心の底へ毒をさしたやうな気がするからであつた。
# 168  akutagawa           封筒の中には手紙のほかにも、半紙に一の字を引いたのが、四つ折のままはいっていた。
# 172  akutagawa                      入力、校正、制作にあたったのは、ボランティアの皆さんです。
# 179  akutagawa   これを見た大手先の大小名の家来は、驚破、殿中に椿事があったと云うので、立ち騒ぐ事が一通りでない。
# 184  akutagawa  当時は十二歳の児童なりしが、ストラタフオルドの学校にて、羅甸並に希臘の初学を卒業せしものなり...
# 195  akutagawa                         彼女は夫の袂を引き、「あら、あなた、鼠が」と言った。
# 199  akutagawa                               けれ共彼女の命令には何の答も来なかつた。

# %% [markdown]
# ## Assessments

# %% [markdown]
# ### functions

# %%
def set_deterministic(deterministic=True):
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        torch.manual_seed(0)
        np.random.seed(0)

# %%
def lm_fine_tuning( data_lm, lm_lr, bptt, emb_sz, nh, nl, qrnn,
                pad_token,
                pretrained_fnames, 
                model_dir,
                lm_enc_finetuned,
                lm_drop_mult, use_pretrained_lm,fine_tune_lm,deterministic):
    
    
    if not use_pretrained_lm:
        pretrained_fnames = None
    
    learn = language_model_learner(
        data_lm, bptt=bptt, emb_sz=emb_sz, nh=nh, nl=nl, qrnn=qrnn,
        pad_token=pad_token,
        pretrained_fnames=pretrained_fnames, 
        path=model_dir.parent, model_dir=model_dir.name,
        drop_mult=lm_drop_mult
    )
    
    set_deterministic(deterministic)
    
    if fine_tune_lm:
        print('Fine-tuning the language model...')
        learn.unfreeze()
        learn.fit(4, slice(lm_lr/(10**2), lm_lr))
    #     learn.fit(10, slice(1e-3, 1e-1))
    else:
        print('Skipping fine tuning')

    # save fine tuned lm
    print(f"Saving models at {learn.path / learn.model_dir}")
    learn.save_encoder(lm_enc_finetuned)
    
    return learn

# %%
def classify_multiclas(data_clas, clas_lr, bptt, 
                        pad_token,
                        model_dir,
                        qrnn, emb_sz, nh, nl,clas_drop_mult,
                        fine_tune_lm, use_lm,deterministic):
    
    
    print("Starting classifier training")
    learn = text_classifier_learner(data_clas, bptt=bptt, pad_token=pad_token,
                                  path=model_dir.parent, model_dir=model_dir.name,
                                  qrnn=qrnn, emb_sz=emb_sz, nh=nh, nl=nl,drop_mult=clas_drop_mult
                                    )
    learn.model.reset()
    
    if use_lm:
        print('Loading language model')
        lm_enc = lm_enc_finetuned # if fine_tune_lm else lm_name
        learn.load_encoder(lm_enc)
    else:
        print('Training from scratch without language model')

    # train
    set_deterministic(deterministic)
    
    learn.freeze_to(-1)
    learn.fit_one_cycle(1, clas_lr, moms=(0.8, 0.7), wd=1e-7)

    learn.freeze_to(-2)
    learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)

    learn.freeze_to(-3)
    learn.fit_one_cycle(1, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)

    learn.unfreeze()
    learn.fit_one_cycle(2, slice(clas_lr / (2.6 ** 4), clas_lr), moms=(0.8, 0.7), wd=1e-7)
    
    # results
    results={}
    results['accuracy'] = learn.validate()[1]
    print(results)
    
    # save classifier
    print(f"Saving models at {learn.path / learn.model_dir}")
    learn.save(f'{model_name}_{name}')
    
    # prediction on validation data
    preds=learn.get_preds()

    # prediction
    p=preds[0]
    p = p.tolist()
    p = np.asarray(p)

    # binarize
    y_pred = p.argmax(axis=1)


    # target
    t = preds[1].tolist()
    y_true = np.asarray(t)
    
    return y_true, y_pred

# %%
def evaluation(y_true,y_pred):
    ## metrics
    f1_micro = f1_score(y_true,y_pred,average='micro')
    f1_macro = f1_score(y_true,y_pred,average='macro')

    print('F1 score')
    print('micro: {}'.format(f1_micro))
    print('macro: {}'.format(f1_macro))

    precision_micro = precision_score(y_true,y_pred,average='micro')
    precision_macro = precision_score(y_true,y_pred,average='macro')

    print('\nPrecision score')
    print('micro: {}'.format(precision_micro))
    print('macro: {}'.format(precision_macro))

    recall_micro = recall_score(y_true,y_pred,average='micro')
    recall_macro = recall_score(y_true,y_pred,average='macro')

    print('\nRecall score')
    print('micro: {}'.format(recall_micro))
    print('macro: {}'.format(recall_macro))
    
    acc = accuracy_score(y_true,y_pred)

    print('\nAccuracy score: {}'.format(acc))
    
    results = dict(
        f1_micro=f1_micro,
        f1_macro=f1_macro,
        precision_micro=precision_micro,
        precision_macro=precision_macro,
        recall_micro=recall_micro,
        recall_macro=recall_macro,
        accuracy=acc
    )
    
    return results

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
#     if normalize:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def save_confusion_matrix(y_true,y_pred,class_names,fn):
    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_true, y_pred)

    # Plot non-normalized confusion matrix
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix')
    plt.gcf().savefig(fn)

# %%
# Create Params dictionary
class Params(object):
    def __init__(self, qrnn,bs,bptt,emb_sz, nh, nl,fine_tune_lm,lm_lr,lm_drop_mult,
                 use_pretrained_lm,clas_lr,clas_drop_mult,use_lm,num_train,deterministic):
        self.qrnn = qrnn
        self.fine_tune_lm = fine_tune_lm
        self.bs = bs
        self.bptt = bptt
        self.emb_sz = emb_sz
        self.nh = nh
        self.nl = nl
        self.lm_lr = lm_lr
        self.lm_drop_mult = lm_drop_mult
        self.use_pretrained_lm = use_pretrained_lm
        self.clas_lr = clas_lr
        self.clas_drop_mult = clas_drop_mult
        self.use_lm = use_lm
        self.num_train = num_train
        self.deterministic = deterministic

# %% [markdown]
# ###  Parameters

# %%
# common to lm fine tuning and classification
qrnn=True
bs=20 
bptt=70
pad_token=PAD_TOKEN_ID

if qrnn:
    emb_sz, nh, nl = 400, 1550, 3
else:
    emb_sz, nh, nl = 400, 1150, 3
    
# lm fine tuning
fine_tune_lm=True 
lm_lr=1e-2
lm_drop_mult=0.5
use_pretrained_lm=False

# classification
clas_lr=1e-2
clas_drop_mult=0.1
use_lm=True

# number of training data
num_train = 1000

# reduce fluctuation between runs
deterministic = True

# %%
mlflow.set_experiment('20181213_Aozora_vocab8k')

# %%
with mlflow.start_run():
    set_deterministic(deterministic)
    
    ## Log our parameters into mlflow
    num_train = int(num_train)
    args = Params(qrnn,bs,bptt,emb_sz, nh, nl,fine_tune_lm,lm_lr,lm_drop_mult,
                 use_pretrained_lm,clas_lr,clas_drop_mult,use_lm,num_train,deterministic)
    for key, value in vars(args).items():
        mlflow.log_param(key, value)
    
    ## create data set
    data_lm = TextLMDataBunch.load(path=Path(data_dir/dataset),cache_name=Path(f'tmp/lm/{num_train}'))
    data_clas = TextClasDataBunch.load(path=Path(data_dir/dataset),cache_name=Path(f'tmp/clas/{num_train}'))
    
    ## preprocess
    if qrnn:
        print('Using QRNNs...')
    model_name = 'qrnn' if qrnn else 'lstm'
    lm_name = f'{model_name}_{pretrain_name}'
    pretrained_fnames = (lm_name, f'itos_{pretrain_name}')

    ensure_paths_exists(data_dir,
                        dataset_dir,
                        model_dir,
                        model_dir/f"{pretrained_fnames[0]}.pth",
                        model_dir/f"{pretrained_fnames[1]}.pkl")
    lm_enc_finetuned  = f"{lm_name}_{dataset}_enc"
    cm_name = fig_dir / f'{lm_name}_{dataset}_confusionmatrix.png'

    ## fine tune lm 
    if use_lm:
        lm=lm_fine_tuning( data_lm, lm_lr, bptt, emb_sz, nh, nl, qrnn,
                    pad_token,
                    pretrained_fnames, 
                    model_dir,
                    lm_enc_finetuned,
                    lm_drop_mult, use_pretrained_lm,fine_tune_lm,deterministic)


    ## create classifier
    y_true, y_pred = classify_multiclas(data_clas, clas_lr, bptt, 
                        pad_token,
                        model_dir,
                        qrnn, emb_sz, nh, nl,clas_drop_mult,
                        fine_tune_lm, use_lm,deterministic)

    ## Evaluation
    results = evaluation(y_true,y_pred)
    class_names = data_clas.valid_ds.y.classes
    save_confusion_matrix(y_true,y_pred,class_names,cm_name)
    
    ## Log metrics
    for key, value in results.items():
        mlflow.log_metric(key, value)
        
    ## Save artifacts
    # pretrained lm
    mlflow.log_artifact(model_dir/f"{pretrained_fnames[0]}.pth")
    mlflow.log_artifact(model_dir/f"{pretrained_fnames[1]}.pkl")
    
    # fine tuned lm
    if fine_tune_lm & use_lm:
         mlflow.log_artifact(model_dir / f'{lm_enc_finetuned}.pth')
    
    # classifier
    mlflow.log_artifact(model_dir / f'{model_name}_{name}.pth')
    
    # confusion matrix
    mlflow.log_artifact(cm_name)
# Out:
# F1 score
# micro: 0.3723608445297505
# macro: 0.21156708156538015
#
# Precision score
# micro: 0.3723608445297505
# macro: 0.36886488831705677
#
# Recall score
# micro: 0.3723608445297505
# macro: 0.27660759586652794
#
# Accuracy score: 0.3723608445297505
