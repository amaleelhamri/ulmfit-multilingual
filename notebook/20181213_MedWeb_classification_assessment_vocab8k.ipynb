# %%
"""
Train a classifier on top of a language model trained with `pretrain_lm.py`.
Optionally fine-tune LM before.
"""
import numpy as np
import pickle

import torch
import torch.nn.functional as F
from fastai.text import TextLMDataBunch, TextClasDataBunch, language_model_learner, text_classifier_learner, LanguageLearner
from fastai import fit_one_cycle
from fastai_contrib.utils import PAD, UNK, read_clas_data, PAD_TOKEN_ID, DATASETS, TRN, VAL, TST, ensure_paths_exists, get_sentencepiece
from fastai.text.transform import Vocab
from fastai.metrics import accuracy, accuracy_thresh, fbeta

import fire
from collections import Counter
from pathlib import Path

import pandas as pd
import csv
from functools import partial
from sklearn.metrics import f1_score, precision_score, recall_score
import mlflow
import os

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # NTCIR-13 MedWeb
# http://research.nii.ac.jp/ntcir/permission/ntcir-13/perm-ja-MedWeb.html

# %% [markdown]
# ## copy data

# %%
# !ls /home/ubuntu/dev/download/data/MedWeb_TestCollection/
# Out:
# NTCIR-13_MedWeb_en_test.xlsx	  NTCIR-13_MedWeb_ja_training.xlsx  readme.txt
# NTCIR-13_MedWeb_en_training.xlsx  NTCIR-13_MedWeb_zh_test.xlsx
# NTCIR-13_MedWeb_ja_test.xlsx	  NTCIR-13_MedWeb_zh_training.xlsx

# %%
# !cat /home/ubuntu/dev/download/data/MedWeb_TestCollection/readme.txt
# Out:
# NTCIR-13 MedWeb task: Test set
#
# Training data
# -MedWeb Japanese subtask train data: NTCIR-13_MedWeb_ja_training.xlsx
# -MedWeb English subtask train data: NTCIR-13_MedWeb_en_training.xlsx
# -MedWeb Chinese subtask train data: NTCIR-13_MedWeb_zh_training.xlsx
#
# Test data
# -MedWeb Japanese subtask test data: NTCIR-13_MedWeb_ja_test.xlsx
# -MedWeb English subtask test data: NTCIR-13_MedWeb_en_test.xlsx
# -MedWeb Chinese subtask test data: NTCIR-13_MedWeb_zh_test.xlsx
#
#
# Columns in each sheet are as follows.
# ID: Pseudo tweet ID that corresponds to the corpora of other language (e.g., the tweet of ``1en'' corresponds to the tweets of ``1ja'' and ``1zh'')
# Tweet: Pseudo tweet message
# Influenza: P (Positive) / N (Negative)
# Diarrhea: P (Positive) / N (Negative)
# Hayfever: P (Positive) / N (Negative)
# Cough: P (Positive) / N (Negative)
# Headache: P (Positive) / N (Negative)
# Fever: P (Positive) / N (Negative)
# Runnynose: P (Positive) / N (Negative)
# Cold: P (Positive) / N (Negative)
#
# For details, please refer to the MedWeb website (http://mednlp.jp/medweb/NTCIR-13/) and the “Overview of the NTCIR-13 MedWeb Task” in the NTCIR Online Proceedings.
#
# Shoko Wakamiya, Mizuki Morita, Yoshinobu Kano, Tomoko Ohkuma, Eiji Aramaki, Overview of the NTCIR-13: MedWeb Task, In Proceedings of the 13th NTCIR Conference, 2017.

# %%
# !mkdir -p data/MedWeb

# %%
# !cp /home/ubuntu/dev/download/data/MedWeb_TestCollection/*ja* data/MedWeb/

# %%
# !ls data/MedWeb/
# Out:
# lbl_names.pkl  NTCIR-13_MedWeb_ja_test.xlsx	 tmp	    valid_ch.txt
# models	       NTCIR-13_MedWeb_ja_training.xlsx  train.csv  valid.csv

# %% [markdown]
# ## read data

# %% [markdown]
# ### train

# %%
trn = pd.read_excel('data/MedWeb/NTCIR-13_MedWeb_ja_training.xlsx',sheet_name='ja_train')

# %%
trn.head(100)
# Out:
#        ID                                              Tweet Influenza  \
# 0     1ja                                    風邪を引くと全身がだるくなる。         n
# 1     2ja                                花粉症の症状が出てきたのは久し振りだ。         n
# 2     3ja                           花粉症のせいでずっと微熱でぼーっとしてる。眠い。         n
# 3     4ja                                   薬飲んだけど鼻水おさまる気配なし         n
# 4     5ja                         ネパールに旅行に行った際に下痢になって大変だったよ。         n
# 5     6ja                咳くらいで休むのはゆとりだけだろ。どんなときでも仕事にでるのは大事だ。         n
# 6     7ja                                       鼻づまりで今日は休むわー         n
# 7     8ja                                       まさか花粉症になるとは。         n
# 8     9ja                              熱は出てるけどお腹に来る風邪じゃなさそう。         n
# 9    10ja                                        痰に血が混じってきもい         n
# 10   11ja              来春は花粉が少ないとか言われても、秋の花粉症のほうが重症な私には関係ない。         n
# 11   12ja                               あかん。咳込みすぎて頭まで痛くなってきた         n
# 12   13ja           微熱が出たから風邪かなって思ったら花粉症だった、花粉症でも熱出るって知らんかった         n
# 13   14ja                              インフルエンザのワクチン打ちに行ってきた。         n
# 14   15ja                                    頭痛がやばいから帰宅して寝るー         n
# 15   16ja                                      風邪もりっぱな病気の１つ。         n
# 16   17ja                  サッカーの試合観戦のため、ネパールに行っている間中下痢に苦しんだ。         n
# 17   18ja                                        痰抑える方法ないかな。         n
# 18   19ja                               最悪だー風邪ひいたー。頭がぼーっとする。         n
# 19   20ja  犬のブログを通じて知り合った人が鼻づまりで息ができず苦しいらしい。たかが鼻水だけの鼻風邪と侮...         n
# 20   21ja           風邪だから薬を飲んでいるけど、副作用のせいで眠い。休めるなら休めばよかった・・・         n
# 21   22ja                              痰が出てるから熱計ってみたら、高熱だった。         n
# 22   23ja                       花粉症だと思っていたのにまさかの微熱。風邪かもしれない。         n
# 23   24ja                              朝から頭痛がやばい。昨日飲みすぎたのかな。         n
# 24   25ja                                   スペイン風邪ってのが昔流行った。         n
# 25   26ja                                    風邪と頭痛で頭がぼーっとする。         n
# 26   27ja  今年二回目のインフルになったんだけど、これって原発事故による放射能で体力落ちちゃったのが原因...         p
# 27   28ja                                         下痢ひどすぎで笑うわ         n
# 28   29ja                           きつい頭痛が襲っている僕は今どこにいるんだろう？         n
# 29   30ja                           この契約が上手くいかないのは頭痛の種でしかない。         n
# ..    ...                                                ...       ...
# 70   71ja                               うーん、このタイミングで風邪とか最悪だ。         n
# 71   72ja                                  担任がインフルという危機的な状況。         p
# 72   73ja                                  だるいと思ったけど、頭痛がしてきた         n
# 73   74ja                               指数関数的に風邪患者が増えているらしい。         n
# 74   75ja                                 朝起きて、いきなり頭痛はやばいだろ。         n
# 75   76ja                             今回風邪ひいたのは家族の中で私が最初だった。         n
# 76   77ja                         鼻風邪がつらかったから、柔らかいティッシュが嬉しい。         n
# 77   78ja                                   激しい頭痛だけど、医者に断られた         n
# 78   79ja                                 最近ちょっとお腹痛い、下痢気味です。         n
# 79   80ja                                       犬も鼻づまりになるんだ。         n
# 80   81ja                                痰を抑える食べ物って何？教えてくれー！         n
# 81   82ja                                 スペイン風邪という病気があるらしいぜ         n
# 82   83ja                                         インフルで部活休むー         p
# 83   84ja                                        朝から下痢とかやばい。         n
# 84   85ja                             ニュースで熱が高い人は病気知らずと言っていた         n
# 85   86ja        耳鼻科に行ったら副鼻腔炎だって。鼻風邪って副鼻腔炎？よくわからないけど薬の量がやばい。         n
# 86   87ja              鳥インフルの季節だってのに国内での検査の体制が整ってなくて全く御粗末だな。         n
# 87   88ja                       弁当を買ったら容器の熱が凄くてほっかほかにもほどがある。         n
# 88   89ja                                  寝すぎて背中痛い。インフルまじ勘弁         p
# 89   90ja                         携帯の熱を冷ますには涼しい場所に置くのがいいらしい。         n
# 90   91ja                                  風邪のせいで鼻づまりがひどすぎる。         n
# 91   92ja       昨日から急に涼しくなったせいか、今少し熱あるかもも。季節の変わり目は体調崩しやすいよね。         n
# 92   93ja                       久しぶりに朝から激しい頭痛がするから学校に行くのだるい。         n
# 93   94ja  この時期、アイドルの握手会で、インフルエンザ対策とかどうしてるんだろうな。集団感染の温床だろ...         n
# 94   95ja                             スペイン風邪だったら感染力が強いから大変だ。         n
# 95   96ja                                       鼻水も体液の一部なのか。         n
# 96   97ja               家に帰ると、娘が熱を出していたよ。リンパも腫れてるし。明日病院に行こう。         n
# 97   98ja                         また腹が痛くなってきて下痢になった悪夢を思い出すよ。         n
# 98   99ja                                   花粉症なると微熱も出るし疲れるぜ         n
# 99  100ja                                      頭痛がすると一日苦痛だよ。         n
#
#    Diarrhea Hayfever Cough Headache Fever Runnynose Cold
# 0         n        n     n        n     n         n    p
# 1         n        p     n        n     n         p    n
# 2         n        p     n        n     p         p    n
# 3         n        n     n        n     n         p    n
# 4         n        n     n        n     n         n    n
# 5         n        n     p        n     n         n    n
# 6         n        n     n        n     n         p    n
# 7         n        p     n        n     n         p    n
# 8         n        n     n        n     p         n    p
# 9         n        n     p        n     n         n    n
# 10        n        n     n        n     n         n    n
# 11        n        n     p        p     n         n    n
# 12        n        p     n        n     p         p    p
# 13        n        n     n        n     n         n    n
# 14        n        n     n        p     n         n    n
# 15        n        n     n        n     n         n    n
# 16        n        n     n        n     n         n    n
# 17        n        n     p        n     n         n    n
# 18        n        n     n        n     n         n    p
# 19        n        n     n        n     n         n    n
# 20        n        n     n        n     n         n    p
# 21        n        n     p        n     p         n    n
# 22        n        p     n        n     p         p    p
# 23        n        n     n        p     n         n    n
# 24        n        n     n        n     n         n    n
# 25        n        n     n        p     n         n    p
# 26        n        n     n        n     p         n    n
# 27        p        n     n        n     n         n    n
# 28        n        n     n        p     n         n    n
# 29        n        n     n        n     n         n    n
# ..      ...      ...   ...      ...   ...       ...  ...
# 70        n        n     n        n     n         n    p
# 71        n        n     n        n     p         n    n
# 72        n        n     n        p     n         n    n
# 73        n        n     n        n     n         n    n
# 74        n        n     n        p     n         n    n
# 75        n        n     n        n     n         n    p
# 76        n        n     n        n     n         p    p
# 77        n        n     n        p     n         n    n
# 78        p        n     n        n     n         n    n
# 79        n        n     n        n     n         n    n
# 80        n        n     p        n     n         n    n
# 81        n        n     n        n     n         n    n
# 82        n        n     n        n     p         n    n
# 83        p        n     n        n     n         n    n
# 84        n        n     n        n     n         n    n
# 85        n        n     n        n     n         p    p
# 86        n        n     n        n     n         n    n
# 87        n        n     n        n     n         n    n
# 88        n        n     n        n     p         n    n
# 89        n        n     n        n     n         n    n
# 90        n        n     n        n     n         p    p
# 91        n        n     n        n     p         n    n
# 92        n        n     n        p     n         n    n
# 93        n        n     n        n     n         n    n
# 94        n        n     n        n     n         n    n
# 95        n        n     n        n     n         p    n
# 96        n        n     n        n     p         n    n
# 97        p        n     n        n     n         n    n
# 98        n        p     n        n     p         p    n
# 99        n        n     n        p     n         n    n
#
# [100 rows x 10 columns]

# %%
# name of labels
lbl_names = trn.columns[2:]
lbl_names
# Out:
# Index(['Influenza', 'Diarrhea', 'Hayfever', 'Cough', 'Headache', 'Fever',
#        'Runnynose', 'Cold'],
#       dtype='object')

# %%
# save
pickle.dump(lbl_names, open('data/MedWeb/lbl_names.pkl','wb'))

# %% [markdown]
# 3列目以降がpの列名を列挙して、ラベルとする

# %% [markdown]
# trn_lbl = ['_'.join(row) for row in ((trn.iloc[:,2:] == 'p')*1).values.astype(str)]

# %% [markdown]
# trn_lbl = [','.join(row) for row in trn.columns[2:] + '_' +trn.iloc[:,2:]]

# %% [markdown]
# for i, row in trn.iterrows():
#     print(','.join(lbl_names[row[2:]=='p']))
#     if i > 5:
#         break

# %% [markdown]
# trn_lbl = []
# for i, row in trn.iterrows():
#     trn_lbl.append(lbl_idx[(row[2:]=='p').values])

# %%
lbl_idx = np.asarray([i for i in range(len(lbl_names))])

# %%
lbl_idx
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
trn_lbl = []
for i, row in trn.iterrows():
    trn_lbl.append(lbl_names[(row[2:]=='p')].tolist())

# %%
trn_lbl[:5]
# Out:
# [['Cold'],
#  ['Hayfever', 'Runnynose'],
#  ['Hayfever', 'Fever', 'Runnynose'],
#  ['Runnynose'],
#  []]

# %%
# put data into df and save
trn_df = pd.DataFrame({'text':trn['Tweet'].values, 'labels':trn_lbl},columns=['labels', 'text'])
trn_df.to_csv('data/MedWeb/train.csv', header=False, index=False)

# %%
trn_df
# Out:
#                                   labels  \
# 0                                 [Cold]
# 1                  [Hayfever, Runnynose]
# 2           [Hayfever, Fever, Runnynose]
# 3                            [Runnynose]
# 4                                     []
# 5                                [Cough]
# 6                            [Runnynose]
# 7                  [Hayfever, Runnynose]
# 8                          [Fever, Cold]
# 9                                [Cough]
# 10                                    []
# 11                     [Cough, Headache]
# 12    [Hayfever, Fever, Runnynose, Cold]
# 13                                    []
# 14                            [Headache]
# 15                                    []
# 16                                    []
# 17                               [Cough]
# 18                                [Cold]
# 19                                    []
# 20                                [Cold]
# 21                        [Cough, Fever]
# 22    [Hayfever, Fever, Runnynose, Cold]
# 23                            [Headache]
# 24                                    []
# 25                      [Headache, Cold]
# 26                    [Influenza, Fever]
# 27                            [Diarrhea]
# 28                            [Headache]
# 29                                    []
# ...                                  ...
# 1890                                  []
# 1891                             [Fever]
# 1892                          [Diarrhea]
# 1893                         [Runnynose]
# 1894                                  []
# 1895                   [Runnynose, Cold]
# 1896                          [Headache]
# 1897                             [Cough]
# 1898                          [Headache]
# 1899                             [Cough]
# 1900                             [Cough]
# 1901                             [Cough]
# 1902                                  []
# 1903                          [Diarrhea]
# 1904                          [Diarrhea]
# 1905                                  []
# 1906                             [Fever]
# 1907                         [Runnynose]
# 1908                                  []
# 1909                             [Cough]
# 1910                                  []
# 1911               [Hayfever, Runnynose]
# 1912                              [Cold]
# 1913                             [Cough]
# 1914                                  []
# 1915                                  []
# 1916                              [Cold]
# 1917                          [Diarrhea]
# 1918                                  []
# 1919                              [Cold]
#
#                                                    text
# 0                                       風邪を引くと全身がだるくなる。
# 1                                   花粉症の症状が出てきたのは久し振りだ。
# 2                              花粉症のせいでずっと微熱でぼーっとしてる。眠い。
# 3                                      薬飲んだけど鼻水おさまる気配なし
# 4                            ネパールに旅行に行った際に下痢になって大変だったよ。
# 5                   咳くらいで休むのはゆとりだけだろ。どんなときでも仕事にでるのは大事だ。
# 6                                          鼻づまりで今日は休むわー
# 7                                          まさか花粉症になるとは。
# 8                                 熱は出てるけどお腹に来る風邪じゃなさそう。
# 9                                           痰に血が混じってきもい
# 10                来春は花粉が少ないとか言われても、秋の花粉症のほうが重症な私には関係ない。
# 11                                 あかん。咳込みすぎて頭まで痛くなってきた
# 12             微熱が出たから風邪かなって思ったら花粉症だった、花粉症でも熱出るって知らんかった
# 13                                インフルエンザのワクチン打ちに行ってきた。
# 14                                      頭痛がやばいから帰宅して寝るー
# 15                                        風邪もりっぱな病気の１つ。
# 16                    サッカーの試合観戦のため、ネパールに行っている間中下痢に苦しんだ。
# 17                                          痰抑える方法ないかな。
# 18                                 最悪だー風邪ひいたー。頭がぼーっとする。
# 19    犬のブログを通じて知り合った人が鼻づまりで息ができず苦しいらしい。たかが鼻水だけの鼻風邪と侮...
# 20             風邪だから薬を飲んでいるけど、副作用のせいで眠い。休めるなら休めばよかった・・・
# 21                                痰が出てるから熱計ってみたら、高熱だった。
# 22                         花粉症だと思っていたのにまさかの微熱。風邪かもしれない。
# 23                                朝から頭痛がやばい。昨日飲みすぎたのかな。
# 24                                     スペイン風邪ってのが昔流行った。
# 25                                      風邪と頭痛で頭がぼーっとする。
# 26    今年二回目のインフルになったんだけど、これって原発事故による放射能で体力落ちちゃったのが原因...
# 27                                           下痢ひどすぎで笑うわ
# 28                             きつい頭痛が襲っている僕は今どこにいるんだろう？
# 29                             この契約が上手くいかないのは頭痛の種でしかない。
# ...                                                 ...
# 1890                                     薬を飲んだら鼻水止まったぜ！
# 1891                              熱でくらくらして日課のお弁当作れなかった。
# 1892                               下痢だしお腹痛いけど仕事に行けるかなあ。
# 1893                                鼻水を止める薬を飲んだら眠くてやばい。
# 1894                          この前会社で集団下痢事件があったんだけど。怖すぎ。
# 1895                                      誰か鼻風邪の薬持ってない？
# 1896                                       頭痛対策まだわからない！
# 1897                            咳をするとき口元を抑えるのはエチケットだよね。
# 1898                             頭痛が激しいから、今日はもう帰ることにした。
# 1899                                        咳を抑える薬が必要だ。
# 1900                                       咳を抑える薬買わなきゃ。
# 1901                                 痰が混じる咳がひどいと胸が痛くなる。
# 1902                            スペインの人って陽気だから風邪とかひかなそう！
# 1903                                      やばい、お腹痛い、下痢かも
# 1904                            朝起きたらお腹痛くて下ってる。下痢とかやばい。
# 1905                             おたふく風邪によく効く薬が開発されたらしいよ
# 1906                        熱出して今日はずっとテレビみてる。また東京行きたいな。
# 1907                            左右どちらかが鼻づまりしている自分が大好きだ。
# 1908                          もう既にインフルエンザワクチンが不足してるらしい。
# 1909                   電車で隣に座ってる人、手で抑えず痰が絡むような咳をしてる。迷惑。
# 1910                                   英語で下痢は何て言うか知ってる？
# 1911                           花粉症で鼻水が止まらなくて鼻かみすぎて鼻が痛い。
# 1912                              寒気がすごいんだけどこれって風邪ですかね？
# 1913                               女性が痰をはいている姿は見たくないなあ。
# 1914                    まとめブログ読んでたけど、犬も鼻風邪引くんだな。写真載ってた。
# 1915                            ネパール行って下痢が止まらなかったの思い出した
# 1916                             寒気でだるいし頭はぼーっとするし、風邪っぽい
# 1917                 何時もお腹痛いってトイレに行ってるけど、下痢をしてるわけじゃないよ。
# 1918                                        鳥インフルが流行する。
# 1919                                 風邪を引いたのはおたふく以来だ・・・
#
# [1920 rows x 2 columns]

# %% [markdown]
# ### test

# %%
tst = pd.read_excel('data/MedWeb/NTCIR-13_MedWeb_ja_test.xlsx',sheet_name='ja_test')

# %%
tst.head(100)
# Out:
#         ID                                              Tweet Influenza  \
# 0   1921ja                             旅行に行ったら、土産にインフルもらってきた。         p
# 1   1922ja                                         きつい上司、頭痛の種         n
# 2   1923ja         もう誰か翻訳してくれないときつい、宇宙の言葉ですかってくらい通じなくて頭痛してきた。         n
# 3   1924ja                                         インフル感染の危機。         p
# 4   1925ja                                 鼻づまりがひどいからスピーチは無理だ         n
# 5   1926ja                                  頭痛がしているので帰ることにする。         n
# 6   1927ja                          インフルエンザになって部活のみんなから爆笑されたよ         p
# 7   1928ja                                  下痢って英語でなんていうんだろう。         n
# 8   1929ja                       スペイン風邪、香港風邪っていうけど、日本風邪ってあるの？         n
# 9   1930ja                                    犬って鼻づまりとかするのかな？         n
# 10  1931ja                          起きると下痢、寝てても下痢、何時も下痢・・・つらい         n
# 11  1932ja                                     花粉症の時期はすごい疲れる。         n
# 12  1933ja                           おたふく風邪は感染力が強いらしいから、大変だね。         n
# 13  1934ja                         一人暮らしの風邪大変だって聞いてたけど想像超えてきた         n
# 14  1935ja             今日は突然の熱で仕事を休んだ。昨日は涼しいを越えて寒いところにいたからなぁ。         n
# 15  1936ja     花粉症で病院に行った時に処方された薬もちゃんと使ってるんだけど、効果があまり出ないんだよね。         n
# 16  1937ja                              寒気がする。本格的な風邪だ。これで休める。         n
# 17  1938ja                                      朝から寝るまでずっと頭痛だ         n
# 18  1939ja                                     誰が巫女に熱あげているって？         n
# 19  1940ja                                東京に来てから鼻水が止まらない・・・。         n
# 20  1941ja                               咳、痰がでたら、間もなく高熱でるかもね。         n
# 21  1942ja                                  頭痛以外は症状ないんだけどなあ〜。         n
# 22  1943ja                           公園で犬と戯れてたら、鼻水が止まらなくなったぜ。         n
# 23  1944ja                                  今年風邪にかかったのは君が最初だ。         n
# 24  1945ja                        ところで、頭痛持ちの人ってみんないつからそうなったの？         n
# 25  1946ja                         鼻づまりで深い度数満タンだから、炎で鼻燃やしてくる。         n
# 26  1947ja             甲高い女性の声を聴くだけで、頭痛が酷くなる。頼むから声落としてくれないかな。         n
# 27  1948ja                                       頭痛に対する対策が必要だ         n
# 28  1949ja  今朝、だるいし眠いし、おかしいなぁと思っていたら寒気も出てきて、どうも風邪のようだ。この時期...         n
# 29  1950ja                                  花粉症が再発してしまいましたとさ。         n
# ..     ...                                                ...       ...
# 70  1991ja                                 携帯が熱をもったから涼しい場所で冷却         n
# 71  1992ja                             鼻水もう無理だからから薬買ってきた。ねむい。         n
# 72  1993ja                                        なんか鼻風邪、薬ほしい         n
# 73  1994ja                                      朝起きたら下痢気味でやばい         n
# 74  1995ja                                        鼻づまり。呼吸無理だ！         n
# 75  1996ja                         ネパールの激辛料理を食べるとその後はいつも下痢だよ。         n
# 76  1997ja                      マスクしてる人が多いけど、そろそろインフルエンザの季節か。         n
# 77  1998ja                                    インフル薬飲んだら速攻回復した         p
# 78  1999ja                                        頭痛が苦痛だしきついぜ         n
# 79  2000ja                     スペインで風邪が流行ってるって聞いたけど、そっちは大丈夫？？         n
# 80  2001ja                                      また鳥インフルだって、怖い         n
# 81  2002ja                                       咳がひどくて、腹筋痛い。         n
# 82  2003ja                                   花粉症で学校休む奴は少ないよな。         n
# 83  2004ja                             兄貴がインフルになったから移されそうで怖い。         p
# 84  2005ja                            ボーっとしているし眠いし、完全に風邪だと思う。         n
# 85  2006ja                               鼻風邪をだれか止める魔法かけてくれー！！         n
# 86  2007ja     風邪を引いても解熱してもいちいちブログを更新してて、あそこまでいくともう病気だなーと思った。         n
# 87  2008ja                           朝から頭痛がやばい。こんなに痛いのは久し振りだ。         n
# 88  2009ja                               寒気するし完全に風邪っぽい。マジ最悪だ。         n
# 89  2010ja                           鼻水ダラダラに熱４０度。お腹は下すは体ボロボロ。         n
# 90  2011ja                                      鼻づまりが解消して嬉しいわ         n
# 91  2012ja                        ただの風邪だと思っていたらおたふく風邪だと診断された。         n
# 92  2013ja                                  兄が部活でインフルうつされて爆笑！         p
# 93  2014ja                                        疲れるせいか痰が絡む。         n
# 94  2015ja                                くしゃみが止まらない、まさか花粉症かも         n
# 95  2016ja                  咳と痰が止まる気配がないっぽいんだけどこれいつ止まるの誰か教えて。         n
# 96  2017ja                          下痢がひどい・・・昨日食った海鮮丼があたったかも。         n
# 97  2018ja                            咳を我慢してたら、腹筋がひきつって痛い・・・。         n
# 98  2019ja                                鼻づまり解消スプレーがすばらしすぎる。         n
# 99  2020ja                                 宇宙について考えすぎて頭痛がしてきた         n
#
#    Diarrhea Hayfever Cough Headache Fever Runnynose Cold
# 0         n        n     n        n     p         n    n
# 1         n        n     n        n     n         n    n
# 2         n        n     n        n     n         n    n
# 3         n        n     n        n     p         n    n
# 4         n        n     n        n     n         p    n
# 5         n        n     n        p     n         n    n
# 6         n        n     n        n     p         n    n
# 7         n        n     n        n     n         n    n
# 8         n        n     n        n     n         n    n
# 9         n        n     n        n     n         n    n
# 10        p        n     n        n     n         n    n
# 11        n        p     n        n     n         p    n
# 12        n        n     n        n     n         n    n
# 13        n        n     n        n     n         n    p
# 14        n        n     n        n     p         n    n
# 15        n        p     n        n     n         p    n
# 16        n        n     n        n     n         n    p
# 17        n        n     n        p     n         n    n
# 18        n        n     n        n     n         n    n
# 19        n        n     n        n     n         p    n
# 20        n        n     p        n     n         n    n
# 21        n        n     n        p     n         n    n
# 22        n        n     n        n     n         p    n
# 23        n        n     n        n     n         n    p
# 24        n        n     n        n     n         n    n
# 25        n        n     n        n     n         p    n
# 26        n        n     n        p     n         n    n
# 27        n        n     n        p     n         n    n
# 28        n        n     n        n     n         n    p
# 29        n        p     n        n     n         p    n
# ..      ...      ...   ...      ...   ...       ...  ...
# 70        n        n     n        n     n         n    n
# 71        n        n     n        n     n         p    n
# 72        n        n     n        n     n         p    p
# 73        p        n     n        n     n         n    n
# 74        n        n     n        n     n         p    n
# 75        n        n     n        n     n         n    n
# 76        n        n     n        n     n         n    n
# 77        n        n     n        n     p         n    n
# 78        n        n     n        p     n         n    n
# 79        n        n     n        n     n         n    n
# 80        n        n     n        n     n         n    n
# 81        n        n     p        n     n         n    n
# 82        n        n     n        n     n         n    n
# 83        n        n     n        n     p         n    n
# 84        n        n     n        n     n         n    p
# 85        n        n     n        n     n         p    p
# 86        n        n     n        n     n         n    n
# 87        n        n     n        p     n         n    n
# 88        n        n     n        n     n         n    p
# 89        p        n     n        n     p         p    n
# 90        n        n     n        n     n         n    n
# 91        n        n     n        n     n         n    n
# 92        n        n     n        n     p         n    n
# 93        n        n     p        n     n         n    n
# 94        n        p     n        n     n         p    n
# 95        n        n     p        n     n         n    n
# 96        p        n     n        n     n         n    n
# 97        n        n     p        n     n         n    n
# 98        n        n     n        n     n         p    n
# 99        n        n     n        n     n         n    n
#
# [100 rows x 10 columns]

# %%
tst_lbl = []
for i, row in tst.iterrows():
    tst_lbl.append(lbl_names[(row[2:]=='p')].tolist())

# %%
tst_lbl[:5]
# Out:
# [['Influenza', 'Fever'], [], [], ['Influenza', 'Fever'], ['Runnynose']]

# %%
# name of labels
lbl_names = tst.columns[2:]
lbl_names
# Out:
# Index(['Influenza', 'Diarrhea', 'Hayfever', 'Cough', 'Headache', 'Fever',
#        'Runnynose', 'Cold'],
#       dtype='object')

# %%
# put data into df and save
tst_df = pd.DataFrame({'text':tst['Tweet'].values, 'labels':tst_lbl},columns=['labels', 'text'])
# change name from test to valid (fastai lm expects valid)
tst_df.to_csv('data/MedWeb/valid.csv', header=False, index=False)

# %%
tst_df.head()
# Out:
#                labels                                        text
# 0  [Influenza, Fever]                      旅行に行ったら、土産にインフルもらってきた。
# 1                  []                                  きつい上司、頭痛の種
# 2                  []  もう誰か翻訳してくれないときつい、宇宙の言葉ですかってくらい通じなくて頭痛してきた。
# 3  [Influenza, Fever]                                  インフル感染の危機。
# 4         [Runnynose]                          鼻づまりがひどいからスピーチは無理だ

# %% [markdown]
# ## prepare data for lm fine tuning and classification
# basically copying from train_cls.py

# %%
data_dir='data'
lang='ja' 
cuda_id=0 
pretrain_name='wt-100' 
model_dir='data/wiki/ja-100/models'
max_vocab=8000
name='MedWeb-clas'
dataset='MedWeb' 
frac_ds=1.0
spm_dir = 'data/wiki/ja/'

# %%
data_dir = Path(data_dir)
assert data_dir.name == 'data',\
    f'Error: Name of data directory should be data, not {data_dir.name}.'
dataset_dir = data_dir / dataset
model_dir = Path(model_dir)

# %%
if not torch.cuda.is_available():
    print('CUDA not available. Setting device=-1.')
    cuda_id = -1
torch.cuda.set_device(cuda_id)

print(f'Dataset: {dataset}. Language: {lang}.')
# Out:
# Dataset: MedWeb. Language: ja.

# %%
# here we're just loading the trained spm model
sp = get_sentencepiece(spm_dir, None, 'wt-all', vocab_size=max_vocab)

# %%
# load train, valid in df
train_df = pd.read_csv(dataset_dir/'train.csv',header=None)
valid_df = pd.read_csv(dataset_dir/'valid.csv',header=None)

# %%
train_df.head()
# Out:
#                                     0                           1
# 0                            ['Cold']             風邪を引くと全身がだるくなる。
# 1           ['Hayfever', 'Runnynose']         花粉症の症状が出てきたのは久し振りだ。
# 2  ['Hayfever', 'Fever', 'Runnynose']    花粉症のせいでずっと微熱でぼーっとしてる。眠い。
# 3                       ['Runnynose']            薬飲んだけど鼻水おさまる気配なし
# 4                                  []  ネパールに旅行に行った際に下痢になって大変だったよ。

# %%
def strip_brackets(s):
    return s.strip('[]').replace("'","").replace(" ","")

# %%
train_df[0] = train_df[0].apply(strip_brackets)

# %%
valid_df[0] = valid_df[0].apply(strip_brackets)

# %%
train_df.head()
# Out:
#                           0                           1
# 0                      Cold             風邪を引くと全身がだるくなる。
# 1        Hayfever,Runnynose         花粉症の症状が出てきたのは久し振りだ。
# 2  Hayfever,Fever,Runnynose    花粉症のせいでずっと微熱でぼーっとしてる。眠い。
# 3                 Runnynose            薬飲んだけど鼻水おさまる気配なし
# 4                            ネパールに旅行に行った際に下痢になって大変だったよ。

# %% [markdown]
# ### lm data

# %%
# set label_delim for multilabel (MultiCategory) data
data_lm = TextLMDataBunch.from_df(path=dataset_dir,train_df=train_df,valid_df=valid_df,label_delim=',',**sp)

# %% [markdown]
# ### classification data

# %%
# set label_delim for multilabel (MultiCategory) data
data_clas = TextClasDataBunch.from_df(path=dataset_dir,train_df=train_df,valid_df=valid_df,label_delim=',',**sp)

# %%
data_clas.valid_ds.y.c2i
# Out:
# {'Cold': 0,
#  'Cough': 1,
#  'Diarrhea': 2,
#  'Fever': 3,
#  'Hayfever': 4,
#  'Headache': 5,
#  'Influenza': 6,
#  'Runnynose': 7}

# %% [markdown]
# # LM fine tuning & Classification

# %%
def set_deterministic(deterministic=True):
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        torch.manual_seed(0)
        np.random.seed(0)

# %%
def lm_fine_tuning( data_lm, lm_lr, bptt, emb_sz, nh, nl, qrnn,
                   pad_token,
                   pretrained_fnames, 
                   model_dir,
                   lm_enc_finetuned,
                   lm_drop_mult,
                   use_pretrained_lm,
                   fine_tune_lm,
                   deterministic,
                   lm_epochs=10,
                   lm_lr_discount=10**2
                  ):
    
    
    if not use_pretrained_lm:
        pretrained_fnames = None
    
    learn = language_model_learner(
        data_lm, bptt=bptt, emb_sz=emb_sz, nh=nh, nl=nl, qrnn=qrnn,
        pad_token=pad_token,
        pretrained_fnames=pretrained_fnames, 
        path=model_dir.parent, model_dir=model_dir.name,
        drop_mult=lm_drop_mult
    )
    
    set_deterministic(deterministic)
    
    if fine_tune_lm:
        print('Fine-tuning the language model...')
        learn.unfreeze()
        learn.fit(lm_epochs, slice(lm_lr/lm_lr_discount, lm_lr))
    #     learn.fit(10, slice(1e-3, 1e-1))
    else:
        print('Skipping fine tuning')

    # save fine tuned lm
    print(f"Saving models at {learn.path / learn.model_dir}")
    learn.save_encoder(lm_enc_finetuned)
    
    return learn

# %%
def classify_multilabel(data_clas, clas_lr, bptt, 
                        pad_token,
                        model_dir,
                        qrnn, emb_sz, nh, nl,
                        clas_drop_mult,
                        fine_tune_lm, use_lm,
                        cls_weights,
                        deterministic,
                        clas_lr_discount=2.6**4,
                        lin_ftrs=[50]
                       ):
    
    
    # change metric from accuracy to accuarcy_thresh and f1
    accuracy_multi =  partial(accuracy_thresh,thresh=0.5,sigmoid=True)
    f1 = partial(fbeta,thresh=0.5,beta=1,sigmoid=True) # corresponds to f1 score in sklearn with 'samples' option?

    print("Starting classifier training")
    learn = text_classifier_learner(data_clas, bptt=bptt, pad_token=pad_token,
                                  path=model_dir.parent, model_dir=model_dir.name,
                                  qrnn=qrnn, emb_sz=emb_sz, nh=nh, nl=nl,drop_mult=clas_drop_mult,
                                    lin_ftrs=lin_ftrs
                                    )
#     learn.model.reset()
    
    if use_lm:
        print('Loading language model')
        lm_enc = lm_enc_finetuned # if fine_tune_lm else lm_name
        learn.load_encoder(lm_enc)
    else:
        print('Training from scratch without language model')

    # change metric
    learn.metrics = [accuracy_multi,f1]

    # CRITICAL STEP
    #- need to adjust pos_weight of loss function to get the model working
    if cls_weights is not None:
        pos_weight = torch.cuda.FloatTensor(cls_weights[data_clas.train_ds.y.classes].values)
        bce_logits_weighted = partial(F.binary_cross_entropy_with_logits,  pos_weight=pos_weight)
        learn.loss_func = bce_logits_weighted

    # train
    set_deterministic(deterministic)
    
    learn.freeze_to(-1)
    learn.fit_one_cycle(1, clas_lr, moms=(0.8, 0.7), wd=1e-7)

    learn.freeze_to(-2)
    learn.fit_one_cycle(1, slice(clas_lr / clas_lr_discount, clas_lr), moms=(0.8, 0.7), wd=1e-7)

    learn.freeze_to(-3)
    learn.fit_one_cycle(1, slice(clas_lr / clas_lr_discount, clas_lr), moms=(0.8, 0.7), wd=1e-7)

    learn.unfreeze()
    learn.fit_one_cycle(2, slice(clas_lr /clas_lr_discount, clas_lr), moms=(0.8, 0.7), wd=1e-7)
    
    # results
    results={}
    results['accuracy_multi'] = learn.validate()[1]
    results['F1'] = learn.validate()[2]
    print(results)
    
    # save classifier
    print(f"Saving models at {learn.path / learn.model_dir}")
    learn.save(f'{model_name}_{name}')
    
    # prediction on validation data
    preds=learn.get_preds()

    # prediction
    p=preds[0]
    p = p.tolist()
    p = np.asarray(p)

    # binarize
    y_pred = (p>=0.5)*1.0


    # target
    t = preds[1].tolist()
    y_true = np.asarray(t)
    
    return y_true, y_pred

# %%
def evaluation(y_true,y_pred):
    ## metrics
    f1_micro = f1_score(y_true,y_pred,average='micro')
    f1_macro = f1_score(y_true,y_pred,average='macro')

    print('F1 score')
    print('micro: {}'.format(f1_micro))
    print('macro: {}'.format(f1_macro))

    precision_micro = precision_score(y_true,y_pred,average='micro')
    precision_macro = precision_score(y_true,y_pred,average='macro')

    print('\nPrecision score')
    print('micro: {}'.format(precision_micro))
    print('macro: {}'.format(precision_macro))

    recall_micro = recall_score(y_true,y_pred,average='micro')
    recall_macro = recall_score(y_true,y_pred,average='macro')

    print('\nRecall score')
    print('micro: {}'.format(recall_micro))
    print('macro: {}'.format(recall_macro))
    
    results = dict(
        f1_micro=f1_micro,
        f1_macro=f1_macro,
        precision_micro=precision_micro,
        precision_macro=precision_macro,
        recall_micro=recall_micro,
        recall_macro=recall_macro
    )
    
    return results

# %%
# Create Params dictionary
class Params(object):
    def __init__(self, qrnn,bs,bptt,emb_sz, nh, nl,fine_tune_lm,lm_lr,lm_drop_mult,
                 use_pretrained_lm,clas_lr,clas_drop_mult,use_lm,cls_weights,frac_ds,deterministic,lm_epochs,lm_lr_discount,clas_lr_discount,
                lin_ftrs):
        self.qrnn = qrnn
        self.fine_tune_lm = fine_tune_lm
        self.bs = bs
        self.bptt = bptt
        self.emb_sz = emb_sz
        self.nh = nh
        self.nl = nl
        self.lm_lr = lm_lr
        self.lm_drop_mult = lm_drop_mult
        self.use_pretrained_lm = use_pretrained_lm
        self.clas_lr = clas_lr
        self.clas_drop_mult = clas_drop_mult
        self.use_lm = use_lm
        self.cls_weights = cls_weights.values.tolist()
        self.frac_ds = frac_ds
        self.deterministic = deterministic 
        self.lm_epochs = lm_epochs 
        self.lm_lr_discount = lm_lr_discount     
        self.clas_lr_discount = clas_lr_discount 
        self.lin_ftrs = lin_ftrs

# %% [markdown]
# ###  Parameters

# %%
# common to lm fine tuning and classification
qrnn=True
bs=20 
bptt=70
pad_token=PAD_TOKEN_ID

if qrnn:
    emb_sz, nh, nl = 400, 1550, 3
else:
    emb_sz, nh, nl = 400, 1150, 3
    
# lm fine tuning
fine_tune_lm=True 
lm_lr=5e-3
lm_lr_discount=10**2
lm_drop_mult=0.5
use_pretrained_lm=True
lm_epochs=20

# classification
clas_lr=2e-2
clas_lr_discount=2.6**4
clas_drop_mult=0.1
use_lm=True
lin_ftrs=[50*2]

# reduction of training data
frac_ds = 1.0

# reduce fluctuation between runs
deterministic = True

# %%
# class weights for classification loss function
# cls_weights = trn.shape[0]/(trn.iloc[:,2:]=='p').sum()/5
cls_weights = pd.Series(np.ones(8,)*1.0,index=trn.columns[2:])
cls_weights
# Out:
# Influenza    1.0
# Diarrhea     1.0
# Hayfever     1.0
# Cough        1.0
# Headache     1.0
# Fever        1.0
# Runnynose    1.0
# Cold         1.0
# dtype: float64

# %%
mlflow.set_experiment('20181213_MedWeb_vocab8k')

# %%
with mlflow.start_run():
    set_deterministic(deterministic)
    
    ## Log our parameters into mlflow
    args = Params(qrnn,bs,bptt,emb_sz, nh, nl,fine_tune_lm,lm_lr,lm_drop_mult,
                 use_pretrained_lm,clas_lr,clas_drop_mult,use_lm,cls_weights,frac_ds,deterministic,lm_epochs,lm_lr_discount,clas_lr_discount,
                 lin_ftrs)
    for key, value in vars(args).items():
        mlflow.log_param(key, value)
    
    ## create data set
    data_lm = TextLMDataBunch.from_df(path=dataset_dir,train_df=train_df.sample(frac=frac_ds,random_state=42),
                                      valid_df=valid_df,label_delim=',',**sp)
    data_clas = TextClasDataBunch.from_df(path=dataset_dir,train_df=train_df.sample(frac=frac_ds,random_state=42),
                                          valid_df=valid_df,label_delim=',',**sp)
    
    ## preprocess
    if qrnn:
        print('Using QRNNs...')
    model_name = 'qrnn' if qrnn else 'lstm'
    lm_name = f'{model_name}_{pretrain_name}'
    pretrained_fnames = (lm_name, f'itos_{pretrain_name}')

    ensure_paths_exists(data_dir,
                        dataset_dir,
                        model_dir,
                        model_dir/f"{pretrained_fnames[0]}.pth",
                        model_dir/f"{pretrained_fnames[1]}.pkl")
    lm_enc_finetuned  = f"{lm_name}_{dataset}_enc"

    ## fine tune lm
    p = None
    if use_lm:
        lm=lm_fine_tuning( data_lm, lm_lr, bptt, emb_sz, nh, nl, qrnn,
                          pad_token,
                          pretrained_fnames, 
                          model_dir,
                          lm_enc_finetuned,
                          lm_drop_mult,
                          use_pretrained_lm,
                          fine_tune_lm,
                          deterministic,
                          lm_epochs,
                          lm_lr_discount
                         )
        # check lm quality by predicting words after some text
        os.makedirs('tmp',exist_ok=True)
        p = lm.predict('料金が高い',n_words=200,no_unk=False)
        print(p)
        with open('tmp/lm_predicted.txt','w') as f:
            f.write(p)


    ## create classifier
    set_deterministic(deterministic)
    y_true, y_pred = classify_multilabel(data_clas, clas_lr, bptt, 
                                         pad_token,
                                         model_dir,
                                         qrnn, 
                                         emb_sz, 
                                         nh, nl,
                                         clas_drop_mult,
                                         fine_tune_lm,
                                         use_lm,cls_weights,
                                         deterministic,
                                         clas_lr_discount,
                                         lin_ftrs
                                        )

    ## Evaluation
    results = evaluation(y_true,y_pred)
    
    ## Log metrics
    for key, value in results.items():
        mlflow.log_metric(key, value)
        
    ## Save artifacts
    # pretrained lm
    mlflow.log_artifact(model_dir/f"{pretrained_fnames[0]}.pth")
    mlflow.log_artifact(model_dir/f"{pretrained_fnames[1]}.pkl")
    
    # fine tuned lm
    if fine_tune_lm:
         mlflow.log_artifact(model_dir / f'{lm_enc_finetuned}.pth')
    
    # classifier
    mlflow.log_artifact(model_dir / f'{model_name}_{name}.pth')
    
    # predicted text
    if p:
        mlflow.log_artifact('tmp/lm_predicted.txt')
        print('\n'+p)
# Out:
# F1 score
# micro: 0.8941755537325677
# macro: 0.8828724925971921
#
# Precision score
# micro: 0.8762057877813505
# macro: 0.8639551825106716
#
# Recall score
# micro: 0.9128978224455612
# macro: 0.9100219738655966
#
# 料金が高い 事 買 え る ▁ 。 ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ 朝 、 微 妙 だ エ チ ク ク ジ ト パ し 、 内部 の 年 、 特に 養成 行 ませ ならない 。 ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ ▁ 部 活 に

# %%
data_lm.train_ds.x[:5]
# Out:
# LMTextList (5 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 朝 から 猛 烈 に 腹 が 痛 かった け ど 、 案 の 定 下 <unk> だった 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 軽 い 頭 痛 だ から 、 大 丈 夫 っ しょ 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 下 <unk> って 、 英語 で なん て 言う ?, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ お 腹 が 痛 く て 起きた ら 、 下 <unk> になっていた ・ ・ ・ 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ せ っ かく の スペイン な の に 風 邪 ひ いた ・ ・ ・ 。]...
# Path: data/MedWeb

# %%
data_lm.train_ds.x.get(1)
# Out:
# Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 軽 い 頭 痛 だ から 、 大 丈 夫 っ しょ 。

# %%
train_df.head()
# Out:
#                           0                           1
# 0                      Cold             風邪を引くと全身がだるくなる。
# 1        Hayfever,Runnynose         花粉症の症状が出てきたのは久し振りだ。
# 2  Hayfever,Fever,Runnynose    花粉症のせいでずっと微熱でぼーっとしてる。眠い。
# 3                 Runnynose            薬飲んだけど鼻水おさまる気配なし
# 4                            ネパールに旅行に行った際に下痢になって大変だったよ。

# %%
t=sp['tokenizer']

# %%
tok=t.process_all(train_df[1])

# %%
tok
# Out:
# [['▁', '風', '邪', 'を', '引', 'く', 'と', '全', '身', 'が', 'だ', 'る', 'くなる', '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '症状',
#   'が出',
#   'てきた',
#   'の',
#   'は',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'の',
#   'せい',
#   'で',
#   'ず',
#   'っと',
#   '微',
#   '熱',
#   'で',
#   'ぼ',
#   'ー',
#   'っ',
#   'として',
#   'る',
#   '。',
#   '眠',
#   'い',
#   '。'],
#  ['▁', '薬', '飲', 'ん', 'だけ', 'ど', '鼻', '水', 'お', 'さま', 'る', '気', '配', 'なし'],
#  ['▁',
#   'ネ',
#   'パー',
#   'ル',
#   'に',
#   '旅行',
#   'に',
#   '行った',
#   '際に',
#   '下',
#   '痢',
#   'になって',
#   '大',
#   '変',
#   'だった',
#   'よ',
#   '。'],
#  ['▁',
#   '咳',
#   'く',
#   'らい',
#   'で',
#   '休',
#   'む',
#   'の',
#   'は',
#   'ゆ',
#   'と',
#   'り',
#   'だけ',
#   'だ',
#   'ろ',
#   '。',
#   'ど',
#   'ん',
#   'な',
#   'とき',
#   'でも',
#   '仕事',
#   'に',
#   'で',
#   'る',
#   'の',
#   'は大',
#   '事',
#   'だ',
#   '。'],
#  ['▁', '鼻', 'づ', 'まり', 'で', '今日', 'は', '休', 'む', 'わ', 'ー'],
#  ['▁', 'まさ', 'か', '花', '粉', '症', 'になると', 'は', '。'],
#  ['▁',
#   '熱',
#   'は',
#   '出て',
#   'る',
#   'け',
#   'ど',
#   'お',
#   '腹',
#   'に',
#   '来',
#   'る',
#   '風',
#   '邪',
#   'じゃ',
#   'な',
#   'さ',
#   'そう',
#   '。'],
#  ['▁', '痰', 'に', '血', 'が', '混', 'じ', 'って', 'き', 'も', 'い'],
#  ['▁',
#   '来',
#   '春',
#   'は',
#   '花',
#   '粉',
#   'が',
#   '少ない',
#   'と',
#   'か',
#   '言われ',
#   'ても',
#   '、',
#   '秋',
#   'の',
#   '花',
#   '粉',
#   '症',
#   'の',
#   'ほう',
#   'が',
#   '重',
#   '症',
#   'な',
#   '私',
#   'には',
#   '関係',
#   'ない',
#   '。'],
#  ['▁', 'あ', 'かん', '。', '咳', '込み', 'すぎ', 'て', '頭', 'まで', '痛', 'く', 'な', 'ってきた'],
#  ['▁',
#   '微',
#   '熱',
#   'が',
#   '出た',
#   'から',
#   '風',
#   '邪',
#   'かな',
#   'って',
#   '思',
#   'った',
#   'ら',
#   '花',
#   '粉',
#   '症',
#   'だった',
#   '、',
#   '花',
#   '粉',
#   '症',
#   'でも',
#   '熱',
#   '出',
#   'る',
#   'って',
#   '知',
#   'ら',
#   'ん',
#   'かった'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   'ワ',
#   'ク',
#   'チン',
#   '打ち',
#   'に',
#   '行',
#   'ってきた',
#   '。'],
#  ['▁', '頭', '痛', 'が', 'や', 'ば', 'い', 'から', '帰', '宅', 'して', '寝', 'る', 'ー'],
#  ['▁', '風', '邪', 'も', 'り', 'っぱ', 'な', '病気', 'の', '1', 'つ', '。'],
#  ['▁',
#   'サッカー',
#   'の',
#   '試合',
#   '観',
#   '戦',
#   'のため',
#   '、',
#   'ネ',
#   'パー',
#   'ル',
#   'に',
#   '行',
#   'っている',
#   '間',
#   '中',
#   '下',
#   '痢',
#   'に',
#   '苦し',
#   'んだ',
#   '。'],
#  ['▁', '痰', '抑え', 'る', '方法', 'ない', 'かな', '。'],
#  ['▁',
#   '最',
#   '悪',
#   'だ',
#   'ー',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   'ー',
#   '。',
#   '頭',
#   'が',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。'],
#  ['▁',
#   '犬',
#   'の',
#   'ブログ',
#   'を通じて',
#   '知',
#   'り',
#   '合',
#   'った',
#   '人が',
#   '鼻',
#   'づ',
#   'まり',
#   'で',
#   '息',
#   'が',
#   'できず',
#   '苦し',
#   'い',
#   'らしい',
#   '。',
#   'たか',
#   'が',
#   '鼻',
#   '水',
#   'だけ',
#   'の',
#   '鼻',
#   '風',
#   '邪',
#   'と',
#   '侮',
#   'れない',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'だ',
#   'から',
#   '薬',
#   'を',
#   '飲',
#   'んでいる',
#   'け',
#   'ど',
#   '、',
#   '副',
#   '作用',
#   'の',
#   'せい',
#   'で',
#   '眠',
#   'い',
#   '。',
#   '休',
#   'める',
#   'なら',
#   '休',
#   'め',
#   'ば',
#   'よ',
#   'かった',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   '痰',
#   'が',
#   '出て',
#   'る',
#   'から',
#   '熱',
#   '計',
#   'って',
#   'み',
#   'た',
#   'ら',
#   '、',
#   '高',
#   '熱',
#   'だった',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'だと',
#   '思',
#   'っていた',
#   'の',
#   'に',
#   'まさ',
#   'か',
#   'の',
#   '微',
#   '熱',
#   '。',
#   '風',
#   '邪',
#   'かもしれない',
#   '。'],
#  ['▁',
#   '朝',
#   'から',
#   '頭',
#   '痛',
#   'が',
#   'や',
#   'ば',
#   'い',
#   '。',
#   '昨',
#   '日',
#   '飲',
#   'み',
#   'すぎ',
#   'た',
#   'の',
#   'かな',
#   '。'],
#  ['▁', 'スペイン', '風', '邪', 'って', 'の', 'が', '昔', '流行', 'った', '。'],
#  ['▁', '風', '邪', 'と', '頭', '痛', 'で', '頭', 'が', 'ぼ', 'ー', 'っと', 'する', '。'],
#  ['▁',
#   '今',
#   '年',
#   '二',
#   '回目の',
#   'イン',
#   'フル',
#   'になった',
#   'ん',
#   'だけ',
#   'ど',
#   '、',
#   'これ',
#   'って',
#   '原',
#   '発',
#   '事故',
#   'による',
#   '放射',
#   '能',
#   'で',
#   '体',
#   '力',
#   '落ち',
#   'ちゃ',
#   'った',
#   'の',
#   'が',
#   '原因',
#   'じゃ',
#   'ね',
#   'ぇ',
#   'の',
#   '?'],
#  ['▁', '下', '痢', 'ひ', 'ど', 'すぎ', 'で', '笑', 'う', 'わ'],
#  ['▁',
#   'き',
#   'つ',
#   'い',
#   '頭',
#   '痛',
#   'が',
#   '襲',
#   'っている',
#   '僕',
#   'は',
#   '今',
#   'どこ',
#   'に',
#   'いる',
#   'ん',
#   'だろう',
#   '?'],
#  ['▁この',
#   '契約',
#   'が',
#   '上',
#   '手',
#   'く',
#   'い',
#   'かない',
#   'の',
#   'は',
#   '頭',
#   '痛',
#   'の',
#   '種',
#   'で',
#   'し',
#   'かない',
#   '。'],
#  ['▁',
#   'まさ',
#   'か',
#   'イン',
#   'フル',
#   'に',
#   'かかる',
#   'と',
#   '思',
#   'わ',
#   'なかった',
#   'ぜ',
#   '。',
#   'ワ',
#   'ク',
#   'チン',
#   '打',
#   'った',
#   'の',
#   'に',
#   'な',
#   'ー'],
#  ['▁',
#   '頭',
#   '痛',
#   'ひ',
#   'ど',
#   'い',
#   'し',
#   '鼻',
#   '水',
#   '止ま',
#   'ん',
#   'ない',
#   'し',
#   '今日',
#   'は',
#   '休',
#   'む',
#   'ことに',
#   'する',
#   '。'],
#  ['▁',
#   '熱',
#   'が出',
#   'なく',
#   'ても',
#   'リン',
#   'パ',
#   'が',
#   '腫',
#   'れる',
#   'ことが',
#   'よく',
#   'ある',
#   '。'],
#  ['▁大', '人', 'になって', 'かかる', 'お', 'た', 'ふく', '風', '邪', 'つ', 'ら', 'すぎ'],
#  ['▁',
#   '風',
#   '呂',
#   'に入った',
#   'ら',
#   '頭',
#   '痛',
#   'が',
#   '大',
#   '分',
#   '良く',
#   'なった',
#   'な',
#   'ー',
#   '。'],
#  ['▁', '熱', 'がある', 'んで', 'まだ', '仕事', 'に復帰', 'でき', 'ね', 'え'],
#  ['▁',
#   '今',
#   '年',
#   'の',
#   '風',
#   '邪',
#   'は',
#   '熱',
#   'が出',
#   'る',
#   'って',
#   'ニュース',
#   'で',
#   'や',
#   'って',
#   'た',
#   'ー',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'による',
#   '熱',
#   'だと',
#   '思',
#   'って',
#   '強い',
#   '解',
#   '熱',
#   '剤',
#   'を',
#   '飲',
#   'んでいた',
#   'の',
#   'に',
#   '違う',
#   '病気',
#   'だった',
#   'らしい',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   '対策',
#   'に',
#   '外',
#   '出',
#   '時は',
#   '、',
#   'マス',
#   'ク',
#   'を',
#   'して',
#   'る',
#   'よ',
#   '。'],
#  ['▁',
#   'い',
#   'つ',
#   'の間に',
#   'か',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   '季',
#   '節',
#   'になった',
#   'わ',
#   '。'],
#  ['▁',
#   '妻',
#   'が',
#   '花',
#   '粉',
#   '症',
#   'で',
#   '微',
#   '熱',
#   'が',
#   '出て',
#   '水',
#   'も',
#   '飲',
#   'め',
#   'なく',
#   'な',
#   'ってしまった',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   '人の',
#   '前',
#   'で',
#   '咳',
#   'を',
#   'する',
#   'なん',
#   'て',
#   'わ',
#   'ざ',
#   'と',
#   'らしい',
#   'と',
#   '思',
#   'わない',
#   '?'],
#  ['▁',
#   '本格的に',
#   '風',
#   '邪',
#   'を',
#   '引',
#   'いた',
#   'ら',
#   'しく',
#   '、',
#   'だ',
#   'る',
#   'い',
#   'し',
#   '頭',
#   'が',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。'],
#  ['▁', 'ア', 'ト', 'ピー', 'と', '花', '粉', '症', 'が', '重', 'な', 'って', 'つ', 'らい'],
#  ['▁',
#   'さ',
#   'っ',
#   'さ',
#   'と',
#   '鼻',
#   'づ',
#   'まり',
#   'を',
#   '解消',
#   'した',
#   'い',
#   'よ',
#   'ー',
#   '。'],
#  ['▁',
#   'お',
#   '腹',
#   'の',
#   '具',
#   '合',
#   'が',
#   '悪',
#   'く',
#   'て',
#   '最近',
#   'ず',
#   'っと',
#   '下',
#   '痢',
#   'して',
#   'る',
#   'わ',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'の',
#   '時は',
#   '免',
#   '疫',
#   '力を',
#   '頼',
#   'って',
#   '、',
#   '出来る',
#   'だけ',
#   '解',
#   '熱',
#   '剤',
#   'を',
#   '使',
#   'わ',
#   'ないように',
#   'する',
#   'んだ',
#   'よ',
#   'ね',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'に',
#   '処',
#   '方',
#   'する',
#   'め',
#   'っ',
#   'ちゃ',
#   'き',
#   'く',
#   '薬',
#   '誰',
#   'かつ',
#   'く',
#   'って',
#   'ー',
#   '!'],
#  ['▁',
#   '咳',
#   'エ',
#   'チ',
#   'ケット',
#   '守',
#   'ら',
#   'ね',
#   'え',
#   'や',
#   'つ',
#   'は',
#   '電車',
#   '乗',
#   'ん',
#   'な',
#   '。'],
#  ['▁', '風', '邪', 'く', 'らい', 'で', '休', 'める', 'と', '思', 'う', 'な', 'よ'],
#  ['▁', '花', '粉', '症', '対策', 'に', '使う', '時間', 'が', 'も', 'った', 'いない'],
#  ['▁',
#   '風',
#   '邪',
#   'っぽ',
#   'い',
#   'と',
#   '思い',
#   '込んで',
#   'ると',
#   '本格的に',
#   '風',
#   '邪',
#   'ひ',
#   'いた'],
#  ['▁', '中国', 'だと', '花', '粉', '症', 'も', '悪化', 'する', 'み', 'たい', '。'],
#  ['▁', '風', '邪', '薬', 'を', '開発', 'する', '仕事', 'して', 'た', 'んだ', 'よ', 'ね', '。'],
#  ['▁', '私', '、', 'お', 'た', 'ふく', '風', '邪', 'になった', 'ことが', 'ない', '!'],
#  ['▁', '鼻', '水', 'が', 'ひ', 'ど', 'すぎ', 'て', '苦し', 'すぎ', 'て', '無', '理', 'だ'],
#  ['▁', '風', '邪', 'を', '治', 'す', '薬', 'って', '開発', 'されている', 'の', 'かな', '?'],
#  ['▁',
#   '熱',
#   'が',
#   'あ',
#   'って',
#   '出',
#   'かけ',
#   'られなかった',
#   'から',
#   '、',
#   'ず',
#   'っと',
#   'テレビ',
#   '見',
#   'て',
#   'た',
#   '。'],
#  ['▁', '家', 'に帰', 'ると', '、', '頭', '痛', 'が', 'する'],
#  ['▁', '鼻', 'づ', 'まり', 'なん', 'て', 'もう', '無', '理', 'だ', '。'],
#  ['▁',
#   '高',
#   '熱',
#   'が',
#   '出て',
#   '仕事',
#   '中',
#   '、',
#   '鼻',
#   '水',
#   'が',
#   '止ま',
#   'ら',
#   'なく',
#   'て',
#   '焦',
#   'った',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'の',
#   '時は',
#   '寄り',
#   '道',
#   'せず',
#   'に',
#   'すぐ',
#   '帰',
#   '宅',
#   'する',
#   'べき',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   '薬',
#   '飲',
#   'ん',
#   'だけ',
#   'ど',
#   '咳',
#   '止ま',
#   'らない',
#   '。',
#   '腹',
#   '筋',
#   'が',
#   '痛',
#   'い',
#   '。'],
#  ['▁', '早く', 'も', '花', '粉', '症', 'の', '季', '節', 'が', 'や', 'ってきた', '。'],
#  ['▁',
#   'や',
#   'っぱ',
#   'り',
#   '女性',
#   'の',
#   'エ',
#   'チ',
#   'ケット',
#   'として',
#   '咳',
#   'を',
#   'する',
#   '時は',
#   '口',
#   'を',
#   '抑え',
#   'る',
#   'べき',
#   '!'],
#  ['▁',
#   '今日',
#   'イン',
#   'フル',
#   'の',
#   '手術',
#   'じゃ',
#   'ない',
#   'ただ',
#   'の',
#   '注',
#   '射',
#   'な',
#   'の',
#   'に',
#   'ビ',
#   'ビ',
#   'る'],
#  ['▁',
#   '咳',
#   'の',
#   'ときに',
#   'は',
#   '、',
#   'マス',
#   'ク',
#   'する',
#   'の',
#   'が',
#   'エ',
#   'チ',
#   'ケット',
#   '。'],
#  ['▁', '鼻', 'づ', 'まり', '解消', '情報', '、', 'ブログ', 'に', 'ない', 'かな'],
#  ['▁',
#   '熱',
#   'がある',
#   'の',
#   'で',
#   '涼',
#   'しい',
#   'と',
#   'こ',
#   '行',
#   'って',
#   'いい',
#   'よ',
#   'ね',
#   '?'],
#  ['▁',
#   'こん',
#   'な',
#   '激しい',
#   '頭',
#   '痛',
#   'は',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。',
#   'もう',
#   '帰',
#   '宅',
#   'し',
#   'ます',
#   '。'],
#  ['▁',
#   'う',
#   'ー',
#   'ん',
#   '、',
#   'この',
#   'タイ',
#   'ミング',
#   'で',
#   '風',
#   '邪',
#   'と',
#   'か',
#   '最',
#   '悪',
#   'だ',
#   '。'],
#  ['▁', '担', '任', 'が', 'イン', 'フル', 'という', '危機', '的な', '状況', '。'],
#  ['▁', 'だ', 'る', 'い', 'と', '思', 'った', 'け', 'ど', '、', '頭', '痛', 'が', 'してきた'],
#  ['▁', '指', '数', '関数', '的に', '風', '邪', '患者', 'が増え', 'ている', 'らしい', '。'],
#  ['▁',
#   '朝',
#   '起き',
#   'て',
#   '、',
#   'い',
#   'き',
#   'なり',
#   '頭',
#   '痛',
#   'は',
#   'や',
#   'ば',
#   'いだ',
#   'ろ',
#   '。'],
#  ['▁',
#   '今',
#   '回',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   'の',
#   'は',
#   '家族',
#   'の中で',
#   '私',
#   'が',
#   '最初',
#   'だった',
#   '。'],
#  ['▁',
#   '鼻',
#   '風',
#   '邪',
#   'が',
#   'つ',
#   'ら',
#   'かった',
#   'から',
#   '、',
#   '柔',
#   'ら',
#   'かい',
#   'ティ',
#   'ッシュ',
#   'が',
#   '嬉',
#   'しい',
#   '。'],
#  ['▁', '激しい', '頭', '痛', 'だけ', 'ど', '、', '医', '者', 'に', '断', 'られた'],
#  ['▁',
#   '最近',
#   'ち',
#   'ょ',
#   'っと',
#   'お',
#   '腹',
#   '痛',
#   'い',
#   '、',
#   '下',
#   '痢',
#   '気',
#   '味',
#   'です',
#   '。'],
#  ['▁', '犬', 'も', '鼻', 'づ', 'まり', 'になる', 'んだ', '。'],
#  ['▁', '痰', 'を', '抑え', 'る', '食べ', '物', 'って', '何', '?', '教え', 'てくれ', 'ー', '!'],
#  ['▁', 'スペイン', '風', '邪', 'という', '病気', 'がある', 'らしい', 'ぜ'],
#  ['▁', 'イン', 'フル', 'で', '部', '活', '休', 'む', 'ー'],
#  ['▁', '朝', 'から', '下', '痢', 'と', 'か', 'や', 'ば', 'い', '。'],
#  ['▁', 'ニュース', 'で', '熱', 'が高い', '人は', '病気', '知', 'らず', 'と言って', 'いた'],
#  ['▁',
#   '耳',
#   '鼻',
#   '科',
#   'に',
#   '行った',
#   'ら',
#   '副',
#   '鼻',
#   '腔',
#   '炎',
#   'だ',
#   'って',
#   '。',
#   '鼻',
#   '風',
#   '邪',
#   'って',
#   '副',
#   '鼻',
#   '腔',
#   '炎',
#   '?',
#   'よく',
#   'わか',
#   'らない',
#   'け',
#   'ど',
#   '薬',
#   'の',
#   '量',
#   'が',
#   'や',
#   'ば',
#   'い',
#   '。'],
#  ['▁',
#   '鳥',
#   'イン',
#   'フル',
#   'の',
#   '季',
#   '節',
#   'だ',
#   'って',
#   'の',
#   'に',
#   '国内',
#   'で',
#   'の',
#   '検査',
#   'の',
#   '体制',
#   'が',
#   '整',
#   'って',
#   'なく',
#   'て',
#   '全く',
#   '御',
#   '粗',
#   '末',
#   'だ',
#   'な',
#   '。'],
#  ['▁',
#   '弁',
#   '当',
#   'を',
#   '買',
#   'った',
#   'ら',
#   '容',
#   '器',
#   'の',
#   '熱',
#   'が',
#   '凄',
#   'く',
#   'て',
#   'ほ',
#   'っ',
#   'か',
#   'ほか',
#   'にも',
#   'ほど',
#   'がある',
#   '。'],
#  ['▁',
#   '寝',
#   'すぎ',
#   'て',
#   '背',
#   '中',
#   '痛',
#   'い',
#   '。',
#   'イン',
#   'フル',
#   'ま',
#   'じ',
#   '勘',
#   '弁'],
#  ['▁',
#   '携',
#   '帯',
#   'の',
#   '熱',
#   'を',
#   '冷',
#   'ます',
#   'には',
#   '涼',
#   'しい',
#   '場所',
#   'に',
#   '置',
#   'く',
#   'の',
#   'が',
#   'いい',
#   'らしい',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'の',
#   'せい',
#   'で',
#   '鼻',
#   'づ',
#   'まり',
#   'が',
#   'ひ',
#   'ど',
#   'すぎ',
#   'る',
#   '。'],
#  ['▁',
#   '昨',
#   '日から',
#   '急',
#   'に',
#   '涼',
#   'しく',
#   'なった',
#   'せい',
#   'か',
#   '、',
#   '今',
#   '少し',
#   '熱',
#   'ある',
#   'か',
#   'も',
#   'も',
#   '。',
#   '季',
#   '節',
#   'の',
#   '変わり',
#   '目',
#   'は',
#   '体',
#   '調',
#   '崩',
#   'し',
#   'やすい',
#   'よ',
#   'ね',
#   '。'],
#  ['▁',
#   '久',
#   'し',
#   'ぶり',
#   'に',
#   '朝',
#   'から',
#   '激しい',
#   '頭',
#   '痛',
#   'が',
#   'する',
#   'から',
#   '学校',
#   'に',
#   '行く',
#   'の',
#   'だ',
#   'る',
#   'い',
#   '。'],
#  ['▁',
#   'この時期',
#   '、',
#   'アイドル',
#   'の',
#   '握',
#   '手',
#   '会',
#   'で',
#   '、',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   '対策',
#   'と',
#   'か',
#   'どう',
#   'して',
#   'る',
#   'ん',
#   'だろう',
#   'な',
#   '。',
#   '集団',
#   '感染',
#   'の',
#   '温',
#   '床',
#   'だ',
#   'ろ',
#   '、',
#   'あ',
#   'れ',
#   '。'],
#  ['▁',
#   'スペイン',
#   '風',
#   '邪',
#   'だった',
#   'ら',
#   '感染',
#   '力',
#   'が',
#   '強い',
#   'から',
#   '大',
#   '変',
#   'だ',
#   '。'],
#  ['▁', '鼻', '水', 'も', '体', '液', 'の一部', 'な', 'の', 'か', '。'],
#  ['▁',
#   '家',
#   'に帰',
#   'ると',
#   '、',
#   '娘',
#   'が',
#   '熱',
#   'を出',
#   'していた',
#   'よ',
#   '。',
#   'リン',
#   'パ',
#   'も',
#   '腫',
#   'れて',
#   'る',
#   'し',
#   '。',
#   '明',
#   '日',
#   '病院',
#   'に',
#   '行',
#   'こう',
#   '。'],
#  ['▁また',
#   '腹',
#   'が',
#   '痛',
#   'く',
#   'な',
#   'って',
#   'き',
#   'て',
#   '下',
#   '痢',
#   'になった',
#   '悪',
#   '夢',
#   'を',
#   '思い',
#   '出す',
#   'よ',
#   '。'],
#  ['▁', '花', '粉', '症', 'なる', 'と', '微', '熱', 'も', '出', 'る', 'し', '疲', 'れる', 'ぜ'],
#  ['▁', '頭', '痛', 'が', 'すると', '一', '日', '苦', '痛', 'だ', 'よ', '。'],
#  ['▁この',
#   '季',
#   '節',
#   '、',
#   '咳',
#   'や',
#   '痰',
#   'には',
#   '悩',
#   'ま',
#   'される',
#   'よ',
#   'ね',
#   '。',
#   '手',
#   '洗',
#   'い',
#   '、',
#   'う',
#   'が',
#   'い',
#   'は大',
#   '事',
#   'だ',
#   'よ',
#   '。'],
#  ['▁', '花', '粉', '症', 'で', '頭', 'が', 'ぼ', 'ん', 'や', 'り', 'して', '疲', 'れる', '。'],
#  ['▁', '契約', 'の', 'ことを', '考え', 'ると', '頭', '痛', 'が', 'し', 'てくる', '。'],
#  ['▁',
#   '風',
#   '邪',
#   '、',
#   '高',
#   '熱',
#   '、',
#   '痰',
#   'で',
#   '死',
#   'に',
#   'そう',
#   'だ',
#   'よ',
#   '。',
#   '助け',
#   'て'],
#  ['▁',
#   '朝',
#   '、',
#   '頭',
#   '痛',
#   'が',
#   'して',
#   'だ',
#   'る',
#   'い',
#   'の',
#   'は',
#   'や',
#   'ば',
#   'い',
#   '。'],
#  ['▁',
#   '鼻',
#   'づ',
#   'まり',
#   'は',
#   '風',
#   '邪',
#   'な',
#   'の',
#   'か',
#   '鼻',
#   '炎',
#   'な',
#   'の',
#   'かわ',
#   'から',
#   'ない',
#   '。'],
#  ['▁',
#   '相手',
#   'の',
#   'ブログ',
#   'を見',
#   'た',
#   'ら',
#   '風',
#   '邪',
#   'と',
#   'か',
#   '病気',
#   'と',
#   'か',
#   'で',
#   '大',
#   '変',
#   'そう',
#   'だ',
#   '・',
#   '・',
#   '・'],
#  ['▁', '遂', 'に', '花', '粉', '症', 'になった', 'っぽ', 'い', '。'],
#  ['▁', 'お', 'た', 'ふく', '風', '邪', 'って', '、', '感染', '力', '強い', '?'],
#  ['▁', '頭', '痛', '対策', 'に', 'コー', 'ヒー', 'が', '効', 'く', 'らしい', '。'],
#  ['▁', '赤', 'ちゃん', 'と', '戯', 'れて', 'た', 'ら', '鼻', '水', 'つけられ', 'た', '。'],
#  ['▁',
#   'パソコン',
#   'の',
#   '使い',
#   'すぎ',
#   'で',
#   '頭',
#   '痛',
#   'が',
#   '起きた',
#   'から',
#   '対策',
#   'メガ',
#   'ネ',
#   'を',
#   '装着',
#   'して',
#   '見',
#   'た',
#   '。',
#   'ま',
#   'し',
#   'になると',
#   'いい',
#   'な'],
#  ['▁',
#   '頭',
#   '痛',
#   'の',
#   'ときに',
#   '大きな',
#   '音',
#   'を',
#   '聞',
#   'く',
#   'の',
#   'は',
#   '苦',
#   '痛',
#   'で',
#   'し',
#   'かない',
#   '。'],
#  ['▁', '寒', '気', 'があり', '風', '邪', 'だと', '確', '信', 'した', 'んだ', '。'],
#  ['▁', 'イン', 'フル', '危機', 'や', 'ば', 'し', '!'],
#  ['▁',
#   '痰',
#   'に',
#   '血',
#   'が',
#   '混',
#   'じ',
#   'る',
#   'の',
#   'は',
#   'や',
#   'ば',
#   'い',
#   'んだ',
#   'っ',
#   'け',
#   '?'],
#  ['▁', '咳', 'の', 'し', 'すぎ', 'で', '腹', '筋', 'が', '割', 'れた', '。'],
#  ['▁',
#   '鼻',
#   '水',
#   'が',
#   'た',
#   'え',
#   'ず',
#   '垂',
#   'れて',
#   'き',
#   'て',
#   'や',
#   'ば',
#   'い',
#   'よ',
#   '。'],
#  ['▁', '朝', 'から', '頭', '痛', 'が', '激しく', 'て', '身体', 'が', 'だ', 'る', 'い', '。'],
#  ['▁', '下', '痢', 'で', '仕事', '休', 'ん', 'じゃ', 'った', '。'],
#  ['▁', '巫', '女', 'への', '熱', 'は', '覚', 'める', 'ことを', '知', 'らない'],
#  ['▁',
#   '今日',
#   '学校',
#   'だけ',
#   'ど',
#   '軽',
#   'い',
#   '頭',
#   '痛',
#   'が',
#   'する',
#   'から',
#   'この',
#   'まま',
#   '寝',
#   'る',
#   'ー'],
#  ['▁', '集団', 'で', '下', '痢', 'と', 'か', 'ヤ', 'バイ', 'で', 'しょ'],
#  ['▁', 'や', 'ば', 'い', '下', '痢', 'が', '止ま', 'らない', '。'],
#  ['▁', '下', '痢', 'っぽ', 'い', '症状', 'で', '起きた', 'よ'],
#  ['▁',
#   '鼻',
#   'づ',
#   'まり',
#   '解消',
#   'には',
#   '鼻',
#   '洗',
#   '浄',
#   'が',
#   '効',
#   'く',
#   'らしい',
#   'け',
#   'ど',
#   '、',
#   '試',
#   'す',
#   '勇',
#   '気',
#   'がない',
#   '。'],
#  ['▁', '女性', 'の', '咳', 'って', 'いろ', 'ん', 'な', 'パターン', 'ある', 'よ', 'ね', '。'],
#  ['▁', 'や', 'っと', '兄', 'が', 'イン', 'フル', 'エン', 'ザ', 'から', '回復', '!'],
#  ['▁',
#   '朝',
#   '起きた',
#   '頭',
#   '痛',
#   'が',
#   'ひ',
#   'ど',
#   'い',
#   '。',
#   '会社',
#   '休',
#   'もう',
#   'かな',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'から',
#   'の',
#   'ア',
#   'ト',
#   'ピー',
#   '。',
#   'なん',
#   'か',
#   '効果',
#   'のある',
#   'もの',
#   'あり',
#   'ます',
#   'か',
#   '?'],
#  ['▁', '犬', 'は大', '好きな', 'の', 'に', '触', 'ると', 'すぐ', '鼻', 'づ', 'まり', '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'の',
#   '時',
#   'って',
#   '、',
#   'お',
#   '風',
#   '呂',
#   '入',
#   'って',
#   'も',
#   'いい',
#   'の',
#   'かな',
#   '?'],
#  ['▁', '朝', 'から', '頭', '痛', 'が', '激しく', 'や', 'ば', 'い'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'に',
#   '効果',
#   'ある',
#   'コス',
#   'パ',
#   'いい',
#   '薬',
#   'あり',
#   'ま',
#   'せん',
#   'か',
#   '?'],
#  ['▁', '風', '邪', 'で', '鼻', 'づ', 'まり', 'が', 'や', 'ば', 'い', '。'],
#  ['▁', '咳', 'で', '腹', '筋', 'つ', 'り', 'そう', '、', '、'],
#  ['▁',
#   '頭',
#   'が',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   'し',
#   '、',
#   'だ',
#   'る',
#   'い',
#   '。',
#   '風',
#   '邪',
#   'かな',
#   'ぁ',
#   '。'],
#  ['▁', '中国', 'に', '行く', 'と', '万', '年', '花', '粉', '症', 'のような', '症状', 'が出', 'る'],
#  ['▁', 'リン', 'パ', 'が', '腫', 'れて', '高', '熱', '出た'],
#  ['▁',
#   'ヘル',
#   'メ',
#   'ット',
#   '装着',
#   'して',
#   'ると',
#   '頭',
#   '痛',
#   'になる',
#   'んだ',
#   'よ',
#   'ね',
#   '。'],
#  ['▁', '風', '邪', 'は', '病気', 'に入', 'らない', 'らしい', '。', '大', '変', 'だ', '。'],
#  ['▁', '痰', 'が', 'ひ', 'ど', 'い', 'の', 'で', '、', '薬', 'を', '飲', 'んだ', 'よ', '。'],
#  ['▁', '風', '邪', '治', 'ら', 'なく', 'て', 'め', 'っ', 'ちゃ', 'だ', 'る', 'い'],
#  ['▁', '薬', '飲', 'んだ', 'ら', '咳', 'と', 'まった', '!'],
#  ['▁',
#   'ネ',
#   'パー',
#   'ル',
#   'の',
#   'ニュース',
#   '見',
#   'て',
#   'た',
#   'ら',
#   '旅行',
#   'で',
#   '行った',
#   'とき',
#   'ひ',
#   'ど',
#   'い',
#   '下',
#   '痢',
#   'になった',
#   'ことを',
#   '思い',
#   '出した',
#   '。'],
#  ['▁', '鳥', 'イン', 'フル', 'エン', 'ザ', 'や', 'ば', 'い', 'よ', 'ー', '。'],
#  ['▁', 'スペイン', '風', '邪', '調べ', 'た', 'け', 'ど', 'や', 'ば', 'い', 'な'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'で',
#   '鼻',
#   '水',
#   'と',
#   'まん',
#   'ない',
#   'と',
#   'か',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。'],
#  ['▁', '風', '邪', '薬', '飲', 'んで', 'から', '眠', 'い'],
#  ['▁',
#   'や',
#   'ば',
#   'い',
#   '、',
#   '頭',
#   '痛',
#   'が',
#   'ひ',
#   'ど',
#   'い',
#   'から',
#   '速',
#   '攻',
#   '寝',
#   'る',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'の',
#   'とき',
#   'も',
#   'お',
#   '風',
#   '呂',
#   'に入って',
#   'いい',
#   'んだ',
#   'っ',
#   'け',
#   '?'],
#  ['▁',
#   'や',
#   'ば',
#   'い',
#   '。',
#   '鼻',
#   '風',
#   '邪',
#   '、',
#   'から',
#   'の',
#   '頭',
#   '痛',
#   '。',
#   '薬',
#   '飲',
#   'んで',
#   '学校',
#   '休',
#   'んで',
#   'る',
#   '。'],
#  ['▁', '鼻', 'づ', 'まり', 'が', '解消', 'でき', 'て', 'す', 'ごく', '嬉', 'しい', '。'],
#  ['▁この', '季', '節', 'は', '風', 'っ', 'ぴ', 'き', 'も', '熱', '出す', '子', 'も多い', 'ね'],
#  ['▁', '花', '粉', '症', '数', '年ぶりに', '再', '発', 'だ', 'ー', '。'],
#  ['▁',
#   '手術',
#   '控え',
#   'て',
#   'る',
#   'の',
#   'に',
#   'イン',
#   'フル',
#   'になった',
#   '、',
#   'どう',
#   'し',
#   'よう'],
#  ['▁',
#   '熱',
#   'ある',
#   'け',
#   'ど',
#   '休',
#   'む',
#   'わけ',
#   'には',
#   'い',
#   'かない',
#   '。',
#   '最近',
#   '仕事',
#   '忙',
#   'しい',
#   'し',
#   'な',
#   '。'],
#  ['▁',
#   '熱',
#   'が',
#   '出て',
#   '、',
#   'リン',
#   'パ',
#   'が',
#   'め',
#   'っ',
#   'ちゃ',
#   '腫',
#   'れて',
#   'る',
#   '・',
#   '・',
#   '・',
#   '。'],
#  ['▁', '花', '粉', '症', '、', '今', '年', 'は', '万', '全', 'の', '対策', 'する', '。'],
#  ['▁',
#   '下',
#   '痢',
#   'って',
#   '英語',
#   'で',
#   'なん',
#   'て',
#   'いう',
#   'かわ',
#   'から',
#   'ない',
#   '。',
#   '知',
#   'り',
#   'た',
#   'く',
#   'もない',
#   '。'],
#  ['▁',
#   'こん',
#   'な',
#   'に',
#   '激しい',
#   '頭',
#   '痛',
#   'は',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   'し',
#   'だ',
#   'る',
#   'い',
#   'し',
#   'かなり',
#   'や',
#   'ば',
#   'い',
#   '。'],
#  ['▁',
#   'まさ',
#   'か',
#   'の',
#   '花',
#   '粉',
#   '症',
#   'に',
#   '、',
#   '自分',
#   'でも',
#   '驚',
#   'いて',
#   'ます',
#   '。'],
#  ['▁', '花', '粉', '症', '、', 'まさ', 'か', 'の', '突然', '回復'],
#  ['▁', '花', '粉', '症', 'は', '蜂', 'も', 'なる', 'の', 'かな'],
#  ['▁',
#   '熱',
#   'ある',
#   'し',
#   'リン',
#   'パ',
#   '腺',
#   'め',
#   'ちゃ',
#   '腫',
#   'れて',
#   'る',
#   'け',
#   'ど',
#   '、',
#   '今日',
#   'は',
#   '休',
#   'む',
#   '訳',
#   'に',
#   'い',
#   'かない',
#   '、',
#   'が',
#   'ん',
#   'ば',
#   'れ',
#   '俺'],
#  ['▁', '東京', 'に帰', 'って', '来た', 'ら', '鼻', '水', '止ま', 'ら', 'ね', '〜'],
#  ['▁',
#   '娘',
#   'は',
#   '熱',
#   'がある',
#   'の',
#   'で',
#   '仕事',
#   'を',
#   '休',
#   'む',
#   '連絡',
#   'を',
#   'した',
#   '。'],
#  ['▁',
#   '咳',
#   'を',
#   'する',
#   '時は',
#   '手',
#   '当て',
#   'る',
#   'の',
#   'が',
#   'エ',
#   'チ',
#   'ケット',
#   'だ',
#   'よ',
#   '!'],
#  ['▁', '下', '痢', 'で', '仕事', 'に', '集中', 'できない', '。'],
#  ['▁', 'スペイン', 'の', '風', '邪', 'は', 'す', 'ご', 'い', 'らしい', 'よ', 'ー', '。'],
#  ['▁', '朝', '起きた', 'ら', '、', 'マ', 'ジ', '下', '痢', 'で', 'や', 'ば', 'い', '。'],
#  ['▁また', '中国', 'で', '鳥', 'イン', 'フル', 'だ', 'って', 'さ'],
#  ['▁', '嫁', 'さん', 'が', '熱', 'を', 'だ', 'した', '。', '早く', '帰', 'ろう', '。'],
#  ['▁', '早く', 'も', '花', '粉', '症', 'の', '症状', 'に', '疲', 'れる', '。'],
#  ['▁',
#   'や',
#   'ば',
#   'い',
#   '、',
#   '今日',
#   '鼻',
#   '水',
#   'と',
#   '頭',
#   '痛',
#   'が',
#   '酷',
#   'い',
#   'から',
#   '風',
#   '邪',
#   'かもしれない',
#   '。'],
#  ['▁',
#   '今',
#   '一',
#   'パフォーマンス',
#   'が',
#   '微',
#   '妙',
#   'になって',
#   'しま',
#   'っている',
#   '。',
#   'お',
#   'れ',
#   'さま',
#   'が',
#   '風',
#   '邪',
#   'に',
#   '参',
#   'って',
#   'なん',
#   'かい',
#   'られない',
#   '。'],
#  ['▁',
#   '鼻',
#   '風',
#   '邪',
#   'が',
#   '治',
#   'って',
#   '犬',
#   'と',
#   '戯',
#   'れる',
#   'ことが',
#   '出来',
#   'た',
#   'から',
#   'ホン',
#   'ト',
#   '嬉',
#   'しい',
#   '!',
#   '写真',
#   '撮',
#   'って',
#   'ブログ',
#   'に',
#   'アップ',
#   'した',
#   'から',
#   '読',
#   'んで',
#   'ね',
#   '!'],
#  ['▁', '感染', 'して', '熱', 'が出', 'る', 'ケース', 'は', '少なく', 'ない', 'らしい', '。'],
#  ['▁', '風', '邪', 'で', '寒', '気', 'と', '頭', '痛', 'が', 'する', '、', '最', '悪', 'だ'],
#  ['▁', '無', '理', 'だ', '、', '鼻', '水', 'が', '止ま', 'ら', 'ん', '。'],
#  ['▁', '早く', 'も', '花', '粉', '症', 'になった', 'の', 'は', '私', 'です', '。'],
#  ['▁', '痰', 'に', '血', 'が', '混', 'じ', 'る', 'の', 'って', 'ヤ', 'バ', 'く', 'ない', '?'],
#  ['▁', '風', '邪', 'って', 'いう', '名前', 'の', '病気', 'は', '無い', 'らしい', 'ね'],
#  ['▁',
#   'ひ',
#   'ど',
#   'い',
#   '咳',
#   'は',
#   '出て',
#   '疲',
#   'れる',
#   '。',
#   '痰',
#   'が',
#   '絡',
#   'まって',
#   'る',
#   'し',
#   '頭',
#   'も',
#   '痛',
#   'い',
#   '。'],
#  ['▁',
#   '外',
#   '出',
#   'する',
#   'とき',
#   'は',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   '予',
#   '防',
#   'を兼ね',
#   'て',
#   'マス',
#   'ク',
#   'を',
#   'して',
#   'い',
#   'ます',
#   '。'],
#  ['▁', '花', '粉', '症', 'に', '早く', 'も', '悩', 'ま', 'されている', '。'],
#  ['▁',
#   '熱',
#   'が',
#   '出て',
#   'る',
#   'け',
#   'ど',
#   '、',
#   'テレビ',
#   'で',
#   '見',
#   'た',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'か',
#   'も',
#   'ね',
#   '。'],
#  ['▁',
#   '風',
#   'で',
#   '花',
#   '粉',
#   'が',
#   '飛',
#   'んで',
#   'る',
#   'から',
#   '、',
#   '花',
#   '粉',
#   '症',
#   'が',
#   '再',
#   '発',
#   'した',
#   'わ',
#   '。'],
#  ['▁', '熱', 'が', '出て', '仕事', '明', '日', 'も', '休', 'む', 'か', 'も', '。'],
#  ['▁',
#   '咳',
#   'も',
#   '痰',
#   'も',
#   'ひ',
#   'ど',
#   'い',
#   'し',
#   '、',
#   '熱',
#   'っぽ',
#   'い',
#   'し',
#   '、',
#   '体',
#   '調',
#   'も',
#   '微',
#   '妙',
#   'だ',
#   '。'],
#  ['▁',
#   '水',
#   '疱瘡',
#   'って',
#   '感染',
#   'しても',
#   '熱',
#   'が出',
#   'ない',
#   'ケース',
#   'もある',
#   'らしい',
#   '。'],
#  ['▁', '一', '日', '中', '咳', 'を', 'して', 'た', 'ら', 'す', 'ごく', '疲', 'れた', '。'],
#  ['▁', '痰', 'が', '混', 'じ', 'る', 'から', '医', '者', 'に', 'い', 'ってくる', '。'],
#  ['▁',
#   '風',
#   '邪',
#   'で',
#   '頭',
#   'が',
#   'ぼ',
#   'ー',
#   'っ',
#   'として',
#   'る',
#   '。',
#   '休',
#   'める',
#   'なら',
#   '休',
#   'み',
#   'たい',
#   'が',
#   'この時期',
#   '休',
#   'め',
#   'ず',
#   '最',
#   '悪',
#   'だ',
#   '。'],
#  ['▁', 'これは', '本格的に', '風', '邪', 'ひ', 'いた', 'な'],
#  ['▁',
#   '内',
#   '科',
#   '行',
#   'って',
#   'から',
#   '熱',
#   'っぽ',
#   'い',
#   '。',
#   '院',
#   '内',
#   '感染',
#   'した',
#   'かな',
#   '?'],
#  ['▁',
#   '中国',
#   'でも',
#   '同様に',
#   '鳥',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'が',
#   '流行',
#   'っている',
#   'んだ',
#   'って',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'に',
#   'かかる',
#   '前に',
#   'ワ',
#   'ク',
#   'チン',
#   '受け',
#   'に',
#   'い',
#   'かない',
#   'と',
#   'な',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'で',
#   'だ',
#   'る',
#   'い',
#   'し',
#   '頭',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。',
#   'これ',
#   'で',
#   '明',
#   '日',
#   '学校',
#   '休',
#   'める',
#   'わ',
#   '。'],
#  ['▁', '頭', '痛', '対策', '誰', 'か', '教え', 'て', '!'],
#  ['▁',
#   '最近',
#   '急',
#   'に',
#   '東京',
#   '涼',
#   'しく',
#   'なった',
#   'から',
#   'か',
#   '、',
#   '風',
#   '邪',
#   'ひ',
#   'いて',
#   '熱',
#   '。'],
#  ['▁大',
#   '人',
#   'になって',
#   'から',
#   'の',
#   'お',
#   'た',
#   'ふく',
#   '風',
#   '邪',
#   'って',
#   'や',
#   'ば',
#   'い',
#   'らしい',
#   'よ',
#   '。'],
#  ['▁', '花', '粉', '症', 'は', '時間', 'が', '解決', 'し', 'てくれ', 'る', 'よ', 'ね'],
#  ['▁', 'ブログ', 'に', '咳', 'について', 'の', 'エ', 'チ', 'ケット', '記事', 'を', '書いた', '。'],
#  ['▁', 'ようやく', '鼻', 'づ', 'まり', '解消', 'した', 'ぞ', '!'],
#  ['▁', '熱', 'で', 'リン', 'パ', 'が', '腫', 'れて', 'て', 'つ', 'らい', 'よ'],
#  ['▁',
#   '家族',
#   '全員',
#   '、',
#   '集団',
#   '食',
#   '中',
#   '毒',
#   'み',
#   'たい',
#   'で',
#   '、',
#   'み',
#   'ん',
#   'な',
#   '下',
#   '痢',
#   'です',
#   '。'],
#  ['▁', 'サッカー', '見', 'て', 'た', 'ら', '、', 'マ', 'ジ', '下', '痢', 'ピー', 'きた', '。'],
#  ['▁', '頭', '痛', 'が', 'き', 'つ', 'い', 'とき', 'の', '対策', 'が', 'わか', 'らない', '。'],
#  ['▁',
#   '来',
#   '春',
#   'を見',
#   '通',
#   'して',
#   '花',
#   '粉',
#   '症',
#   '対策',
#   'の',
#   'アイテム',
#   'を',
#   '買',
#   'った',
#   '。'],
#  ['▁',
#   '微',
#   '熱',
#   'が',
#   '続いて',
#   'た',
#   'け',
#   'ど',
#   '、',
#   '原因',
#   'が',
#   'まさ',
#   'か',
#   '花',
#   '粉',
#   '症',
#   'だと',
#   'は',
#   '思',
#   'って',
#   'なかった',
#   'よ',
#   '。'],
#  ['▁',
#   '昨',
#   '日から',
#   '熱',
#   'が',
#   '出て',
#   '、',
#   'の',
#   'ど',
#   'も',
#   '腫',
#   'れている',
#   '。',
#   'いく',
#   'ら',
#   'でも',
#   '眠',
#   'れる',
#   '。',
#   '明',
#   '日',
#   'も',
#   '仕事',
#   'は',
#   '休',
#   'む',
#   'ことに',
#   'する',
#   '。'],
#  ['▁',
#   'ブログ',
#   'に',
#   '書',
#   'く',
#   'ことが',
#   '鼻',
#   '水',
#   'が',
#   'ひ',
#   'ど',
#   'い',
#   'こと',
#   'く',
#   'らい',
#   'し',
#   'かない',
#   '。'],
#  ['▁',
#   '薬',
#   'の',
#   'ん',
#   'だけ',
#   'ど',
#   '熱',
#   'が',
#   '下',
#   'が',
#   'らず',
#   '咳',
#   'も',
#   '止ま',
#   'らない',
#   '。',
#   '早く',
#   '治',
#   'まって',
#   'く',
#   'れ',
#   'ー'],
#  ['▁',
#   'こん',
#   'な',
#   'に',
#   '激しい',
#   '頭',
#   '痛',
#   'は',
#   '久',
#   'し',
#   'ぶり',
#   'だ',
#   '。',
#   'や',
#   'ば',
#   'い',
#   '。'],
#  ['▁', 'まさ', 'か', '、', '花', '粉', '症', 'が', '再', '発', '?', 'や', 'だ', 'な', '。'],
#  ['▁', '下', '痢', 'って', '英語', 'で', '何', 'て', '言う', 'の', 'かな', '。'],
#  ['▁',
#   '最近',
#   '寒',
#   'い',
#   'し',
#   '、',
#   '具',
#   '合',
#   'が',
#   '悪',
#   'い',
#   'ことが',
#   '続いて',
#   'ます',
#   '。',
#   '今日',
#   'は',
#   '下',
#   '痢',
#   '。'],
#  ['▁',
#   'し',
#   'ら',
#   'す',
#   '丼',
#   'を',
#   '食べ',
#   'て',
#   '下',
#   '痢',
#   'になった',
#   'ことを',
#   '思い',
#   '出す',
#   'よ',
#   '。'],
#  ['▁',
#   '鼻',
#   '風',
#   '邪',
#   '、',
#   'や',
#   'ば',
#   'い',
#   '。',
#   '早く',
#   '薬',
#   'の',
#   'んで',
#   '休',
#   'む',
#   '。'],
#  ['▁',
#   'うち',
#   'で',
#   '働',
#   'いて',
#   'る',
#   '女性',
#   'が',
#   '、',
#   '高',
#   '熱',
#   'で',
#   '休',
#   'む',
#   'と',
#   'わ',
#   'ざ',
#   'と',
#   'らしい',
#   '咳',
#   'を',
#   'しながら',
#   '電話',
#   'してきた',
#   'ん',
#   'だけ',
#   'ど',
#   'ブログ',
#   'で',
#   '遊',
#   '園',
#   '地に',
#   '行',
#   'って',
#   'る',
#   'って',
#   '書',
#   'いて',
#   'て',
#   '笑',
#   'った',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'を',
#   'ひ',
#   'か',
#   'ないように',
#   'する',
#   '薬',
#   'と',
#   'か',
#   '開発',
#   'しない',
#   'かな'],
#  ['▁', '咳', '込み', '過ぎ', 'て', 'ブログ', 'が', '書', 'け', 'ない', '・', '・', '・'],
#  ['▁', 'そ', 'ろ', 'そ', 'ろ', '花', '粉', '症', '対策', 'はじめ', 'なければ', '。'],
#  ['▁',
#   '寒',
#   '気',
#   'も',
#   'する',
#   'し',
#   'だ',
#   'る',
#   'い',
#   'し',
#   '、',
#   '完全に',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   'よ',
#   '。'],
#  ['▁', 'こん', 'な', '激しい', '頭', '痛', 'は', '久', 'し', '振り', 'だ'],
#  ['▁', '東京', 'で', '感染', 'して', '熱', 'が', 'で', 'た', '。'],
#  ['▁',
#   '東京',
#   'では',
#   '自動車',
#   'や',
#   'エア',
#   'コン',
#   'から',
#   '排',
#   '出',
#   'される',
#   '熱',
#   'が',
#   '暑',
#   'さ',
#   'を',
#   '助',
#   '長',
#   'している',
#   '。'],
#  ['▁',
#   'ネ',
#   'パー',
#   'ル',
#   '料理',
#   'を',
#   '食べ',
#   'た',
#   '後に',
#   'し',
#   'っ',
#   'かり',
#   '手',
#   'を',
#   '洗',
#   'わない',
#   'と',
#   '下',
#   '痢',
#   'になる',
#   'らしい',
#   'ね',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'っぽ',
#   'い',
#   'け',
#   'ど',
#   '、',
#   '仕事',
#   '休',
#   'める',
#   'かな',
#   'ー',
#   '。',
#   '今日',
#   '休',
#   'んだ',
#   'ら',
#   '明',
#   '日',
#   '以降',
#   '辛',
#   'い',
#   'の',
#   'は',
#   '分',
#   'か',
#   'って',
#   'る',
#   'け',
#   'ど',
#   '。',
#   '。',
#   '。'],
#  ['▁',
#   '兄',
#   'が',
#   'イン',
#   'フル',
#   'になった',
#   'から',
#   '家',
#   'でも',
#   'マス',
#   'ク',
#   '生活',
#   'し',
#   'な',
#   'き',
#   'ゃ',
#   '。'],
#  ['▁',
#   '鼻',
#   '水',
#   'が',
#   'や',
#   'ば',
#   'いった',
#   'らない',
#   '。',
#   '薬',
#   '飲',
#   'め',
#   'ば',
#   '止ま',
#   'る',
#   'かな',
#   '。'],
#  ['▁',
#   'テレビ',
#   'の',
#   'ニュース',
#   'で',
#   '携',
#   '帯',
#   'が',
#   '熱',
#   'も',
#   'って',
#   'ると',
#   'や',
#   'ば',
#   'い',
#   'って',
#   '見',
#   'た',
#   '。'],
#  ['▁', 'その', '咳', '、', 'め', 'っ', 'ちゃ', 'わ', 'ざ', 'と', 'らしい', 'ぜ'],
#  ['▁', '娘', 'が', '熱', 'を', '出した', 'の', 'で', 'お', '休', 'み', 'して', 'ます'],
#  ['▁', '犬', 'でも', '鼻', '風', '邪', 'って', 'なる', 'の', 'かな', '。'],
#  ['▁',
#   'スペイン',
#   '風',
#   '邪',
#   'って',
#   '病気',
#   'が',
#   '日本',
#   'でも',
#   '大',
#   '流行',
#   'した',
#   'んだ',
#   'って',
#   '。'],
#  ['▁',
#   '最',
#   '悪',
#   'だ',
#   '、',
#   '明',
#   '日',
#   '出',
#   'かける',
#   'の',
#   'に',
#   'ここ',
#   'に',
#   '来',
#   'て',
#   '風',
#   '邪',
#   'か',
#   '?'],
#  ['▁', '来', '春', 'は', '花', '粉', '症', 'の', '人', 'が増え', 'る', 'み', 'たい', '。'],
#  ['▁',
#   '3',
#   '月',
#   'になって',
#   'から',
#   '喉',
#   'が',
#   '痛',
#   'む',
#   '。',
#   '花',
#   '粉',
#   '症',
#   'で',
#   '今',
#   'まで',
#   '喉',
#   'は',
#   '痛',
#   'ま',
#   'なかった',
#   'け',
#   'ど',
#   '、',
#   'これ',
#   '絶対',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '症状',
#   'だ',
#   'よ',
#   'な',
#   '。'],
#  ['▁',
#   'だ',
#   'る',
#   'い',
#   'し',
#   '頭',
#   '痛',
#   'が',
#   'ひ',
#   'ど',
#   'い',
#   'し',
#   'で',
#   '早',
#   'め',
#   'に帰',
#   '宅',
#   '中',
#   '。'],
#  ['▁',
#   '咳',
#   'が',
#   'ひ',
#   'ど',
#   'い',
#   '。',
#   '手',
#   '洗',
#   'いう',
#   'が',
#   'い',
#   'が',
#   '大',
#   '事',
#   'だ',
#   'な',
#   'あ',
#   '。'],
#  ['▁',
#   '熱',
#   'が',
#   '明',
#   '日まで',
#   'に',
#   '下',
#   'が',
#   'って',
#   '仕事',
#   'に',
#   '行',
#   'ける',
#   'か',
#   '危',
#   'ない'],
#  ['▁', 'き', 'れ', 'い', 'な', '女性', 'でも', '痰', 'が出', 'る', 'ものである', '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '人',
#   'と',
#   'ア',
#   'ト',
#   'ピー',
#   'の',
#   '人',
#   'って',
#   'ど',
#   'っ',
#   'ち',
#   'の',
#   '患者',
#   'が',
#   '少ない',
#   'の',
#   'かな',
#   '?'],
#  ['▁', '鼻', 'づ', 'まり', '解消', '方法', '、', 'だ', 'れ', 'か', '教え', 'て', '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'が',
#   'ひ',
#   'ど',
#   'く',
#   'て',
#   '、',
#   '薬',
#   'が必要',
#   'だ',
#   '・',
#   '・',
#   '・',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'が',
#   'ち',
#   'ょ',
#   'っと',
#   'ひ',
#   'ど',
#   'く',
#   'な',
#   'ってきた',
#   'の',
#   'で',
#   'お',
#   'と',
#   'な',
#   'しく',
#   '寝',
#   'る',
#   'よ'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'で',
#   '死亡',
#   'の',
#   '話',
#   'を',
#   '聞',
#   'く',
#   'と',
#   '危機',
#   '感',
#   'を',
#   '覚',
#   'える',
#   'な',
#   '。'],
#  ['▁', '痰', 'が出', 'なく', 'な', 'ってきた', 'から', '治', 'った', 'っぽ', 'い', 'ぞ', '!'],
#  ['▁', '風', '邪', 'からなる', '病気', 'もある', 'らしい', 'から', '気', 'を', '付け', 'よう', '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'つ',
#   'らい',
#   '。',
#   '檜',
#   'なん',
#   'て',
#   '絶滅',
#   'すれば',
#   'いい',
#   'の',
#   'に',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   '朝',
#   'から',
#   '頭',
#   '痛',
#   'が',
#   'する',
#   'し',
#   '、',
#   'だ',
#   'る',
#   'い',
#   'から',
#   '、',
#   '早',
#   '退',
#   'して',
#   '今',
#   '帰',
#   '宅',
#   'した',
#   '。'],
#  ['▁', '風', '邪', 'ひ', 'ど', 'い', 'ぼ', 'ー', 'っと', 'してきた', '。'],
#  ['▁',
#   '謎',
#   'の',
#   '発',
#   '熱',
#   '。',
#   '他',
#   'は',
#   '元',
#   '気',
#   'なん',
#   'だけ',
#   'ど',
#   'な',
#   '〜',
#   '。',
#   '病院',
#   'い',
#   'っと',
#   'いた',
#   'ほう',
#   'が',
#   'いい',
#   'の',
#   'かな',
#   '。'],
#  ['▁', '花', '粉', '症', 'の', '薬', '処', '方', 'してきた'],
#  ['▁',
#   'こ',
#   'ど',
#   'も',
#   'が',
#   '小さい',
#   'から',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   'ワ',
#   'ク',
#   'チン',
#   'を',
#   '打ち',
#   'に',
#   '行',
#   'こう',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   'ワ',
#   'ク',
#   'チン',
#   'を受け',
#   'に',
#   '行',
#   'か',
#   'なく',
#   'ちゃ',
#   '。'],
#  ['▁',
#   '東京',
#   'の',
#   '実',
#   '家',
#   'から',
#   '送',
#   'られ',
#   'てきた',
#   '写真',
#   'には',
#   '愛',
#   '犬',
#   'の',
#   '姿',
#   'があった',
#   '。',
#   '鼻',
#   '風',
#   '邪',
#   'を',
#   'ひ',
#   'いて',
#   'す',
#   'っ',
#   'き',
#   'り',
#   'しなかった',
#   'け',
#   'ど',
#   '、',
#   'なん',
#   'か',
#   '元',
#   '気',
#   'を',
#   'も',
#   'ら',
#   'って',
#   '嬉',
#   'し',
#   'かった',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'には',
#   '、',
#   'ト',
#   'マ',
#   'ト',
#   'を',
#   '食べる',
#   '療法',
#   'がある',
#   'って',
#   '本',
#   '当',
#   'かな',
#   '。'],
#  ['▁',
#   '季',
#   '節',
#   '外',
#   'れ',
#   'の',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   '感染',
#   'して',
#   'い',
#   'ま',
#   '高',
#   '熱',
#   '出て',
#   'ます',
#   '。'],
#  ['▁',
#   '激しい',
#   '頭',
#   '痛',
#   'が',
#   'する',
#   '。',
#   'こん',
#   'な',
#   'の',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。'],
#  ['▁',
#   'の',
#   'ど',
#   'の',
#   '痛',
#   'み',
#   '、',
#   '鼻',
#   '水',
#   '、',
#   '熱',
#   '、',
#   'せ',
#   'き',
#   '、',
#   'でも',
#   '仕事',
#   '休',
#   'め',
#   'ない',
#   '。'],
#  ['▁',
#   '科学',
#   'の',
#   '進',
#   '歩',
#   'で',
#   '薬',
#   '品',
#   'は',
#   '世',
#   'の中に',
#   'た',
#   'く',
#   'さん',
#   'ある',
#   'け',
#   'ど',
#   '、',
#   '風',
#   '邪',
#   'の',
#   'ウイルス',
#   'は',
#   '種類',
#   'が',
#   'た',
#   'く',
#   'さん',
#   'ある',
#   'から',
#   '個',
#   '々',
#   'の',
#   'ウイルス',
#   'の',
#   '特',
#   '効',
#   '薬',
#   'の研究',
#   'や',
#   '開発',
#   'は',
#   'あまり',
#   '進',
#   'んで',
#   'いない',
#   'んだ',
#   'って',
#   '。'],
#  ['▁',
#   '咳',
#   'が',
#   '治',
#   'まる',
#   'よう',
#   '薬',
#   'を',
#   '飲',
#   'んだ',
#   'よ',
#   'ー',
#   '、',
#   '治',
#   'れば',
#   'いい',
#   'な',
#   '。'],
#  ['▁',
#   '咳',
#   'や',
#   '痰',
#   'に',
#   '赤',
#   'っぽ',
#   'い',
#   'ものが',
#   '混',
#   'じ',
#   'る',
#   'の',
#   'は',
#   '本',
#   '当',
#   'に',
#   'まず',
#   'い',
#   'と',
#   '思',
#   'う',
#   'よ',
#   '?'],
#  ['▁', '熱', 'が出', 'やすい', '季', '節', 'になった', 'な', '。'],
#  ['▁',
#   '頭',
#   '痛',
#   '以外にも',
#   '関',
#   '節',
#   'が',
#   '痛',
#   'い',
#   'し',
#   '、',
#   '熱',
#   'もある',
#   'し',
#   '、',
#   'と',
#   'り',
#   'あ',
#   'え',
#   'ず',
#   '色',
#   '々',
#   'と',
#   '苦',
#   '痛',
#   '。'],
#  ['▁',
#   '高',
#   '齢',
#   '者が',
#   '風',
#   '邪',
#   'に',
#   'かかる',
#   'と',
#   '重',
#   '症',
#   '化',
#   'する',
#   'とき',
#   'もある',
#   'から',
#   '大',
#   '変',
#   'だ',
#   'よ',
#   'ね',
#   '。'],
#  ['▁',
#   '痰',
#   '抑え',
#   'る',
#   '薬',
#   'が',
#   'まず',
#   'く',
#   'て',
#   '小',
#   '一',
#   '時間',
#   '格闘',
#   'して',
#   'る',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   'わ',
#   'ざ',
#   'と',
#   'ら',
#   'しく',
#   '咳',
#   'して',
#   'た',
#   'ら',
#   '頭',
#   'まで',
#   '痛',
#   'く',
#   'な',
#   'ってきた'],
#  ['▁この', 'タイ', 'ミング', 'で', '風', '邪', 'と', 'か', '最', '悪', 'だ', 'ろ'],
#  ['▁', '宇宙', 'について', '考え', 'ると', '頭', '痛', 'が', 'する'],
#  ['▁', 'イン', 'フル', 'の', 'ワ', 'ク', 'チン', 'を', '打ち', 'に', '行った', 'よ', '!'],
#  ['▁', '下', '痢', 'が', '止ま', 'らなかった', 'あ', 'の', '日', 'を', '思い', '出す'],
#  ['▁',
#   'この時期',
#   'は',
#   '鼻',
#   '水',
#   'に',
#   '悩',
#   'ま',
#   'されること',
#   'がない',
#   'から',
#   '大',
#   '好き',
#   'だ',
#   '。'],
#  ['▁',
#   '鳥',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'は',
#   'ず',
#   'さん',
#   'な',
#   '管理',
#   'で',
#   'なる',
#   'わけ',
#   'じゃ',
#   'ない',
#   'み',
#   'た',
#   'いだ',
#   '。'],
#  ['▁', '風', '邪', 'ひ', 'いて', '鼻', 'づ', 'まり', 'や', 'ば', 'い'],
#  ['▁',
#   '頭',
#   '痛',
#   'が',
#   '治',
#   'らない',
#   'の',
#   'は',
#   '苦',
#   '痛',
#   'で',
#   'し',
#   'かない',
#   '。',
#   '原因',
#   'が',
#   '分',
#   'から',
#   'ない',
#   'から',
#   '対策',
#   'も',
#   'でき',
#   'なく',
#   'て',
#   '辛',
#   'い',
#   '。'],
#  ['▁', '今日', 'の', '朝', 'から', '鼻', '水', '止ま', 'ら', 'ん'],
#  ['▁',
#   '犬',
#   'と',
#   '戯',
#   'れる',
#   'と',
#   '、',
#   '鼻',
#   '風',
#   '邪',
#   'になる',
#   '。',
#   '何',
#   'で',
#   'だ',
#   '?'],
#  ['▁', '鼻', 'づ', 'まり', 'で', '頭', '痛', 'まで', 'してきた', '感じ', 'だ'],
#  ['▁', 'イン', 'フル', 'エン', 'ザ', 'だ', 'し', '、', '部', '活', '休', 'む', 'わ', '。'],
#  ['▁',
#   '鼻',
#   '風',
#   '邪',
#   'の',
#   '薬',
#   '飲',
#   'んだ',
#   'ら',
#   'め',
#   'っ',
#   'ちゃ',
#   '喉',
#   '乾',
#   'く',
#   '。'],
#  ['▁',
#   '本格的な',
#   '風',
#   '邪',
#   'の',
#   'せい',
#   'で',
#   '、',
#   'い',
#   'つ',
#   'も',
#   'は',
#   '完',
#   '璧',
#   'だ',
#   'と言われる',
#   '仕事',
#   'が',
#   '今',
#   '一',
#   'だ',
#   'と言われる',
#   '始',
#   '末',
#   'で',
#   '最',
#   '悪',
#   'だ',
#   'よ',
#   '。'],
#  ['▁', '風', '邪', '薬', '飲', 'んだ', 'ら', '眠', 'く', 'な', 'ってきた', '。'],
#  ['▁', 'まさ', 'か', '妻', 'が', '花', '粉', '症', 'になる', 'なん', 'て', '!'],
#  ['▁', '鼻', '水', 'が', 'や', 'ば', 'い', '。', 'や', 'ば', 'すぎ', 'る', '。'],
#  ['▁', 'や', 'ば', 'い', '、', '今日', 'テスト', 'な', 'の', 'に', '下', '痢', 'になった', '。'],
#  ['▁', '花', '粉', '症', 'で', '微', '熱', 'が', '続く', 'の', 'もある', 'よう', 'だ', '。'],
#  ['▁',
#   'なん',
#   'か',
#   '熱',
#   'ある',
#   '気',
#   'する',
#   'け',
#   'ど',
#   '気',
#   'の',
#   'せい',
#   'だと',
#   '思',
#   'って',
#   'テレビ',
#   '見',
#   'て',
#   'る'],
#  ['▁',
#   'あ',
#   'の',
#   '女性',
#   'の',
#   '咳',
#   '、',
#   'いく',
#   'ら',
#   'なん',
#   'でも',
#   'わ',
#   'ざ',
#   'と',
#   'らしい',
#   'よ',
#   'ね',
#   '。'],
#  ['▁', '鼻', '水', '出', 'すぎ', '。', 'ど', 'れ', 'だけ', '体', '液', 'ある', 'んだ', '。'],
#  ['▁', '英語', 'で', '下', '痢', 'だと', '伝えられ', 'ず', '困', 'った'],
#  ['▁',
#   '中国',
#   'で',
#   '、',
#   '鳥',
#   'から',
#   '新',
#   '型の',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   '感染',
#   'して',
#   '死',
#   'んだ',
#   '人が',
#   '出て',
#   'た',
#   '筈',
#   'だけ',
#   'れ',
#   'ど',
#   '、',
#   '日本では',
#   '検査',
#   'キ',
#   'ット',
#   'と',
#   'か',
#   'ちゃん',
#   'と',
#   'ある',
#   'ん',
#   'だろう',
#   'か',
#   '?',
#   'ニュース',
#   'や',
#   'って',
#   'る',
#   '割',
#   'に',
#   '管理',
#   'の',
#   '体制',
#   'どう',
#   'な',
#   'って',
#   'ん',
#   'の',
#   'か',
#   '全',
#   '然',
#   'わ',
#   'かん',
#   'ない',
#   '。'],
#  ['▁', '鼻', '水', '止ま', 'る', '風', '邪', '薬', 'は', 'ど', 'れ', '?'],
#  ['▁',
#   '頭',
#   'も',
#   '痛',
#   'い',
#   'し',
#   '痰',
#   'も',
#   'ひ',
#   'ど',
#   'い',
#   '。',
#   '完全に',
#   '風',
#   '邪',
#   'だ',
#   '。'],
#  ['▁',
#   '高',
#   '熱',
#   'が',
#   '出て',
#   '咳',
#   'と',
#   'ま',
#   'らない',
#   '。',
#   'だ',
#   'れ',
#   'か',
#   '家',
#   '事',
#   'や',
#   'って',
#   '。',
#   '家',
#   '政',
#   '婦',
#   'が必要',
#   'だ',
#   'ー',
#   '。'],
#  ['▁', 'リン', 'パ', 'マッ', 'サー', 'ジ', '行った', 'ら', '熱', '出', 'てきた'],
#  ['▁', '寒', 'く', 'て', '毎日', '下', '痢', 'だ', 'ー', '。'],
#  ['▁',
#   '子供',
#   'の',
#   '頃',
#   'の',
#   '写真',
#   'で',
#   'てきた',
#   'ん',
#   'だけ',
#   'ど',
#   '俺',
#   'ほとんど',
#   'の',
#   '写真',
#   'で',
#   '鼻',
#   '水',
#   'た',
#   'ら',
#   'して',
#   'る',
#   '。',
#   'どう',
#   'な',
#   'って',
#   'んだ',
#   '。'],
#  ['▁',
#   '喉',
#   'の',
#   '痛',
#   'み',
#   'が',
#   '治',
#   'まった',
#   'け',
#   'ど',
#   '、',
#   '痰',
#   'が',
#   'まだ',
#   '続く'],
#  ['▁',
#   '翻訳',
#   '業務',
#   '頼',
#   'まれた',
#   'け',
#   'ど',
#   '全',
#   '然',
#   'わか',
#   'らない',
#   '、',
#   '頭',
#   '痛',
#   'してきた',
#   '。'],
#  ['▁', '鼻', '風', '邪', 'を', '引', 'い', 'てしまった', '。'],
#  ['▁',
#   '契約',
#   'して',
#   '欲',
#   'しい',
#   'け',
#   'ど',
#   '、',
#   '相手',
#   'に対して',
#   '聴',
#   'く',
#   '以外',
#   'に',
#   '対策',
#   'が',
#   '無',
#   'さ',
#   'すぎ',
#   'て',
#   '頭',
#   '痛',
#   'が',
#   'ひ',
#   'ど',
#   'い',
#   '。'],
#  ['▁',
#   'ところ',
#   'で',
#   '頭',
#   '痛',
#   'は',
#   'まだ',
#   'き',
#   'つ',
#   'い',
#   'です',
#   'か',
#   '、',
#   '私',
#   'さん',
#   '?'],
#  ['▁',
#   '部',
#   '活',
#   'の',
#   'あ',
#   'と',
#   '熱',
#   'が',
#   '出て',
#   '慌',
#   'て',
#   'て',
#   '病院',
#   '行った',
#   'ら',
#   'イン',
#   'フル',
#   'だった',
#   '。',
#   'つ',
#   'らい',
#   '。'],
#  ['▁', '咳', 'と同時に', '頭', 'が', '痛', 'い', '。'],
#  ['▁', '下', '痢', 'って', '英語', 'で', 'なん', 'て', '言う', 'んだ', 'ろ', '。'],
#  ['▁',
#   '秋',
#   'の',
#   '花',
#   '粉',
#   '症',
#   'の',
#   'つ',
#   'らい',
#   '。',
#   '対策',
#   'に',
#   '時間',
#   'が',
#   '取',
#   'られる'],
#  ['▁', '携', '帯', 'の', '熱', 'が', 'ハン', 'パ', 'ない', '!'],
#  ['▁',
#   'お',
#   '腹',
#   'を',
#   '壊',
#   'したが',
#   '食べる',
#   'の大',
#   '好きな',
#   '私',
#   'は',
#   'まだ',
#   '今日',
#   'の',
#   '弁',
#   '当',
#   'への',
#   '愛',
#   'と',
#   '熱',
#   'は',
#   '冷',
#   'める',
#   '事',
#   'を',
#   '知',
#   'らない',
#   '。'],
#  ['▁',
#   '鳥',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'が',
#   '中国',
#   'で',
#   '猛',
#   '威',
#   'を',
#   '奮',
#   'っている',
#   '。'],
#  ['▁',
#   '生',
#   '姜',
#   '湯',
#   'を',
#   '飲',
#   'んで',
#   'い',
#   'れば',
#   '咳',
#   'が',
#   '止ま',
#   'る',
#   'っぽ',
#   'い',
#   '。'],
#  ['▁',
#   'まさ',
#   'か',
#   '、',
#   '自分',
#   'が',
#   '花',
#   '粉',
#   '症',
#   'になる',
#   'なん',
#   'て',
#   'び',
#   'っ',
#   'く',
#   'り',
#   '。'],
#  ['▁',
#   '来',
#   '春',
#   'の',
#   'ス',
#   'ギ',
#   '花',
#   '粉',
#   'は',
#   '量',
#   'が多い',
#   'らしい',
#   '。',
#   '花',
#   '粉',
#   '症',
#   'な',
#   'の',
#   'で',
#   '先',
#   'が',
#   '思い',
#   'や',
#   'られる',
#   '〜',
#   '。'],
#  ['▁', '女性', 'が', '痰', 'の', '症状', 'を', '抑え', 'る', '。'],
#  ['▁',
#   '兄',
#   'が',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'な',
#   'の',
#   'で',
#   'う',
#   'つ',
#   'らない',
#   'か',
#   '不',
#   '安',
#   'だ',
#   'よ',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'っぽ',
#   'い',
#   '。',
#   '頭',
#   'が',
#   '痛',
#   'い',
#   'し',
#   '、',
#   '咳',
#   'が',
#   '止ま',
#   'らない',
#   '。'],
#  ['▁',
#   '久',
#   'し',
#   'ぶり',
#   'に',
#   '東京',
#   'に',
#   '行',
#   'って',
#   '遊び',
#   'すぎ',
#   'た',
#   '。',
#   '楽',
#   'し',
#   'かった',
#   'け',
#   'ど',
#   '鼻',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   '。'],
#  ['▁',
#   'そ',
#   'ろ',
#   'そ',
#   'ろ',
#   '朝',
#   'だ',
#   'し',
#   '軽',
#   'い',
#   '頭',
#   '痛',
#   'もある',
#   'から',
#   '風',
#   '呂',
#   '入',
#   'って',
#   '寝',
#   'る',
#   '。'],
#  ['▁', 'まだ', '熱', '。', 'も', 'ち', 'ろ', 'ん', '、', '今日', 'も', '休', 'む', '!'],
#  ['▁', '薬', '飲', 'んで', '、', 'や', 'っと', '鼻', '水', 'が', 'ひ', 'い', 'てきた', '。'],
#  ['▁', '秋', 'にも', '花', '粉', '症', 'の', '治療', 'が必要', 'だ', '。'],
#  ['▁',
#   'ネ',
#   'パー',
#   'ル',
#   'に',
#   'サッカー',
#   '観',
#   '戦',
#   'に',
#   '行った',
#   '時に',
#   '、',
#   '集団',
#   'で',
#   '下',
#   '痢',
#   'になって',
#   '大',
#   '変',
#   'だった',
#   'よ',
#   '。'],
#  ['▁', '下', '痢', 'だと', '集中', 'できない', 'から', '仕事', 'に', 'なら', 'ん', '。'],
#  ['▁',
#   'これ',
#   '誰',
#   'の',
#   '携',
#   '帯',
#   '?',
#   '熱',
#   'が',
#   '熱',
#   'すぎ',
#   'て',
#   'や',
#   'ば',
#   'そう',
#   '。'],
#  ['▁', '花', '粉', '症', 'に', '効果', 'がある', '薬', 'なん', 'て', 'ある', 'の', 'かね', 'ぇ'],
#  ['▁', 'まさ', 'か', 'この', '年に', '花', '粉', '症', 'になる', 'なん', 'て'],
#  ['▁',
#   '来',
#   '春',
#   'こそ',
#   '花',
#   '粉',
#   '症',
#   'に',
#   '効果',
#   'がある',
#   '療法',
#   'を見つけ',
#   'たい',
#   'よ',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   '対策',
#   '、',
#   '何',
#   'か',
#   'ご',
#   '存',
#   '知',
#   'で',
#   'した',
#   'ら',
#   '教え',
#   'て',
#   '頂',
#   'け',
#   'ない',
#   'で',
#   'しょう',
#   'か',
#   '。'],
#  ['▁', '今日', 'の', '鼻', '水', 'や', 'ば', 'い', '止ま', 'る', '気', '配', 'ない'],
#  ['▁',
#   '風',
#   '邪',
#   'の',
#   'とき',
#   'は',
#   '科学',
#   '的に',
#   '寝',
#   'れば',
#   '良い',
#   'と',
#   '証明',
#   'されている',
#   '。'],
#  ['▁',
#   '朝',
#   'から',
#   '頭',
#   '痛',
#   'も',
#   'する',
#   'し',
#   '体',
#   'だ',
#   'る',
#   'い',
#   'し',
#   'まだ',
#   '寝',
#   'て',
#   'た',
#   '方',
#   'が',
#   'よ',
#   'かった',
#   'か',
#   'も',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   '対策',
#   'の',
#   '薬',
#   'も',
#   'ら',
#   'った',
#   'け',
#   'ど',
#   '全',
#   '然',
#   '効',
#   'かない',
#   '。'],
#  ['▁', '咳', 'し', 'すぎ', 'て', '腹', '筋', '痛', 'い', '。'],
#  ['▁',
#   '今',
#   '年',
#   'は',
#   '花',
#   '粉',
#   'が',
#   '少ない',
#   'み',
#   'たい',
#   'だけ',
#   'ど',
#   '、',
#   '重',
#   '度の',
#   '花',
#   '粉',
#   '症',
#   '患者',
#   'から',
#   'すれば',
#   '花',
#   '粉',
#   '量',
#   'の',
#   '多',
#   '少',
#   'の',
#   '増',
#   '減',
#   'なん',
#   'て',
#   'たい',
#   'して',
#   '意味',
#   'ない',
#   'よ',
#   'ね',
#   '。'],
#  ['▁',
#   '仕事',
#   'を',
#   'しようと',
#   'パソコン',
#   '前に',
#   '向',
#   'か',
#   'う',
#   'が',
#   '、',
#   'と',
#   'んだ',
#   '熱',
#   '暴',
#   '走',
#   'で',
#   '仕事',
#   'に',
#   'ならない',
#   '。'],
#  ['▁',
#   'お',
#   'た',
#   'ふく',
#   '流行',
#   'って',
#   'る',
#   'け',
#   'ど',
#   'ただ',
#   'の',
#   '風',
#   '邪',
#   'だと',
#   'いい',
#   'な',
#   'あ',
#   '。'],
#  ['▁',
#   '定期',
#   '的に',
#   '頭',
#   '痛',
#   'が',
#   'する',
#   'の',
#   'で',
#   '常',
#   '備',
#   '薬',
#   'が',
#   '必要な',
#   'んだ',
#   'よ',
#   'ね'],
#  ['▁', 'わ', 'ざ', 'と', 'らしい', '咳', 'を', 'している', '女性', 'がいる', '。'],
#  ['▁',
#   '熱',
#   'が',
#   '下',
#   'が',
#   'らない',
#   'から',
#   '、',
#   '今日',
#   '行',
#   'ける',
#   'か',
#   '微',
#   '妙',
#   'だ',
#   '。'],
#  ['▁', '犬', 'と', '戯', 'れる', 'と', '鼻', '水', 'が', '止ま', 'ら', 'なくなる', '。'],
#  ['▁',
#   '最近',
#   '寒',
#   'い',
#   'から',
#   'お',
#   '腹',
#   '冷',
#   'えた',
#   'かな',
#   '〜',
#   '。',
#   '昨',
#   '日から',
#   '下',
#   '痢',
#   'や',
#   'ば',
#   'い',
#   '。'],
#  ['▁', '昨', '晩', 'から', 'イン', 'フル', 'エン', 'ザ', 'に', 'か', 'かった', 'み', 'たい', '。'],
#  ['▁',
#   '最近',
#   'お',
#   '店',
#   'の',
#   '仕事',
#   'が',
#   '忙',
#   'しく',
#   'て',
#   '疲',
#   'れる',
#   '毎日',
#   'だ',
#   '。',
#   '疲',
#   'れる',
#   'と',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '症状',
#   'も',
#   'ひ',
#   'ど',
#   'くなる',
#   '。',
#   'そして',
#   '遂',
#   'に',
#   '妻',
#   'も',
#   '花',
#   '粉',
#   '症',
#   'が',
#   '発',
#   '症',
#   'した',
#   '。'],
#  ['▁',
#   '本格的に',
#   '風',
#   '邪',
#   '引',
#   'いた',
#   '、',
#   '頭',
#   '痛',
#   'い',
#   'し',
#   'だ',
#   'る',
#   'い',
#   'し',
#   '寒',
#   '気',
#   'する',
#   'し',
#   '最',
#   '悪',
#   'だ',
#   'よ',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   '咳',
#   '止め',
#   '飲',
#   'ん',
#   'だけ',
#   'ど',
#   '全',
#   '然',
#   '治',
#   'まり',
#   'そう',
#   'に',
#   'なく',
#   'って',
#   '、',
#   '痰',
#   'も',
#   '混',
#   'ざ',
#   'って',
#   'き',
#   'て',
#   'る',
#   '。'],
#  ['▁', '下', '痢', 'って', '英語', 'で', '何', 'て', 'いう', 'んだ', 'っ', 'け'],
#  ['▁', '来', '春', 'の', '花', '粉', '症', 'は', '軽', 'い', 'と', 'いい', 'な', 'ぁ', '。'],
#  ['▁',
#   '熱',
#   'で',
#   '仕事',
#   '休',
#   'む',
#   'わけ',
#   'に',
#   'い',
#   'かない',
#   'から',
#   '解',
#   '熱',
#   '剤',
#   '飲',
#   'む',
#   '。'],
#  ['▁', '携', '帯', '熱', 'い', '、', '誰', 'か', '助け', 'て', '!'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   '対策',
#   'いろ',
#   'いろ',
#   'ある',
#   'け',
#   'ど',
#   'ど',
#   'れ',
#   'が',
#   '一番',
#   '効果',
#   'ある',
#   'の',
#   'かな',
#   '。'],
#  ['▁', '風', '邪', 'の', '方', 'は', 'どう', 'ぞ', 'お', '休', 'み', 'く', 'だ', 'さい', '。'],
#  ['▁',
#   '早く',
#   '下',
#   '痢',
#   '直',
#   'した',
#   'い',
#   'け',
#   'ど',
#   '出',
#   'さ',
#   'な',
#   'き',
#   'ゃ',
#   '毒',
#   '素',
#   'で',
#   'ね',
#   'え',
#   'し',
#   'な',
#   'あ'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   'か',
#   'から',
#   'ないため',
#   'に',
#   '自分',
#   'を',
#   '管理',
#   'を',
#   'し',
#   'っ',
#   'かり',
#   'する',
#   'べ',
#   'し',
#   '。'],
#  ['▁', '鼻', '風', '邪', 'や', 'ば', 'い', 'から', '今日', '休', 'む', '。'],
#  ['▁',
#   '完',
#   '治',
#   'した',
#   'と',
#   '思',
#   'った',
#   'ら',
#   'まさ',
#   'か',
#   'の',
#   '花',
#   '粉',
#   '症',
#   '再',
#   '発',
#   '。',
#   '久',
#   'し',
#   '振り',
#   'に',
#   '鼻',
#   '水',
#   'と',
#   'の戦い',
#   'が',
#   '始まる',
#   '。'],
#  ['▁',
#   'い',
#   'つ',
#   'も',
#   '読',
#   'んで',
#   'る',
#   'ブログ',
#   'の',
#   '子が',
#   '風',
#   '邪',
#   'ら',
#   'しく',
#   'て',
#   '大',
#   '変',
#   'だ',
#   '。'],
#  ['▁',
#   '兄',
#   'が',
#   '久',
#   '々',
#   'に帰',
#   'ってきた',
#   'ら',
#   'イン',
#   'フル',
#   'か',
#   'か',
#   'って',
#   'た',
#   '。',
#   '笑',
#   'えない',
#   '。'],
#  ['▁',
#   '微',
#   '熱',
#   'もある',
#   'し',
#   '花',
#   '粉',
#   '症',
#   'も',
#   'ひ',
#   'ど',
#   'い',
#   'し',
#   '、',
#   'もう',
#   '疲',
#   'れた',
#   '。'],
#  ['▁',
#   '昨',
#   '晩',
#   'から',
#   'イン',
#   'フル',
#   'で',
#   '発',
#   '熱',
#   'して',
#   'る',
#   'よ',
#   '、',
#   '喉',
#   'が',
#   '乾',
#   'く',
#   '。'],
#  ['▁',
#   'ヨー',
#   'グル',
#   'ト',
#   'が',
#   '花',
#   '粉',
#   '症',
#   'に',
#   '効果',
#   'ある',
#   'って',
#   'いう',
#   '話',
#   '、',
#   'ほん',
#   'と',
#   'な',
#   'の',
#   'かな',
#   '。'],
#  ['▁', 'イン', 'フル', 'に', 'か', 'かった', 'ら', '兄', 'ちゃん', '来', 'てくれ', 'た', '!'],
#  ['▁', '誰', 'か', 'この', '熱', 'から', '助け', 'てくれ', '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   'ワ',
#   'ク',
#   'チン',
#   'を',
#   '打',
#   'って',
#   'き',
#   'ま',
#   'した',
#   '。'],
#  ['▁',
#   'リン',
#   'パ',
#   '腫',
#   'れて',
#   'る',
#   'し',
#   '、',
#   '熱',
#   'もある',
#   'し',
#   '完',
#   '璧',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   '。'],
#  ['▁',
#   '鼻',
#   '風',
#   '邪',
#   'で',
#   '頭',
#   'も',
#   'や',
#   'ば',
#   'く',
#   'な',
#   'ってきた',
#   '。',
#   '今日',
#   'は',
#   '休',
#   'む',
#   '予定だった',
#   'んだ',
#   'が',
#   '、',
#   'なん',
#   'か',
#   '惰',
#   '性',
#   'で',
#   '出',
#   '社',
#   'してしまった',
#   '。'],
#  ['▁', '下', '痢', 'だけ', 'ど', '仕事', 'には', '行', 'かない', 'と', 'い', 'け', 'ない', '。'],
#  ['▁',
#   '咳',
#   'ぐ',
#   'らい',
#   'で',
#   '済',
#   'んで',
#   'る',
#   'うち',
#   'に',
#   '対',
#   '処',
#   'する',
#   'の',
#   'が',
#   '大',
#   '事',
#   'だ',
#   'よ',
#   'ね'],
#  ['▁', 'ひ', 'ど', 'い', '頭', '痛', 'には', '対策', 'が必要', 'だ', '。'],
#  ['▁',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   'ー',
#   '。',
#   '薬',
#   '飲',
#   'んだ',
#   'ら',
#   '頭',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。'],
#  ['▁', '咳', 'で', '胸', 'ヒュー', 'ヒュー', '言', 'って', 'る', 'わ'],
#  ['▁', '熱', 'がある', 'が', '仕事', 'は', '休', 'め', 'ない', '。'],
#  ['▁',
#   'ヘル',
#   'メ',
#   'ット',
#   'を',
#   'ず',
#   'っと',
#   '装着',
#   'していた',
#   'ら',
#   '頭',
#   '痛',
#   'が',
#   'してきた',
#   '。'],
#  ['▁', '食', '中', '毒', 'の', 'とき', 'は', '下', '痢', 'が', '一番', 'つ', 'らい', '。'],
#  ['▁',
#   'く',
#   'しゃ',
#   'み',
#   'だけ',
#   'じゃ',
#   'なく',
#   '寒',
#   '気',
#   'も',
#   'してきた',
#   'から',
#   '風',
#   '邪',
#   'か',
#   'も',
#   '。'],
#  ['▁', 'なん', 'か', 'が', 'ん', 'ば', 'った', 'ら', '鼻', 'づ', 'まり', '止', 'んだ', '。'],
#  ['▁',
#   '今日',
#   'は',
#   '薬',
#   'の',
#   'おか',
#   'げ',
#   'で',
#   '、',
#   'なん',
#   'か',
#   '鼻',
#   'づ',
#   'まり',
#   'も',
#   '止ま',
#   'る',
#   '気',
#   '配',
#   'が',
#   'する',
#   '。'],
#  ['▁', '風', '邪', 'で', '頭', 'が', 'ぼ', 'ー', 'っと', 'してきた', '。'],
#  ['▁', '本格的に', '風', '邪', '引', 'いた', 'か', 'も', '知', 'れない'],
#  ['▁',
#   '軽',
#   'く',
#   '鼻',
#   '風',
#   '邪',
#   'ひ',
#   'いて',
#   'る',
#   'け',
#   'ど',
#   '東京',
#   '行き',
#   'は',
#   '決',
#   '行',
#   '!'],
#  ['▁',
#   '熱',
#   'は',
#   '引',
#   'いた',
#   'け',
#   'ど',
#   '鼻',
#   '水',
#   'だ',
#   'ら',
#   'だ',
#   'ら',
#   '・',
#   '・',
#   '・',
#   '今日',
#   'は',
#   '家',
#   'で',
#   'ゆ',
#   'っ',
#   'く',
#   'り',
#   '休',
#   'もう'],
#  ['▁', 'まさ', 'か', 'この', '歳で', '花', '粉', '症', '発', '症', 'すると', 'は', '。'],
#  ['▁',
#   '今',
#   '年',
#   'の',
#   '風',
#   '邪',
#   'は',
#   '熱',
#   'が',
#   '上がる',
#   'って',
#   'ニュース',
#   'で',
#   '言',
#   'って',
#   'た',
#   '。',
#   '気',
#   'をつけ',
#   'よ',
#   '。'],
#  ['▁',
#   '最近',
#   'お',
#   '腹',
#   'が',
#   '痛',
#   'い',
#   'ことが多く',
#   'て',
#   '、',
#   '下',
#   '痢',
#   'にも',
#   'よく',
#   'な',
#   'るようになった',
#   '。',
#   'ち',
#   'ょ',
#   'っと',
#   'や',
#   'ば',
#   'い',
#   'かもしれない',
#   '。'],
#  ['▁', '下', '痢', '止ま', 'ら', 'なく', 'て', '笑', 'う'],
#  ['▁', '娘', 'の', '熱', 'と', '鼻', '水', 'が', 'ひ', 'ど', 'い'],
#  ['▁',
#   'ア',
#   'ト',
#   'ピー',
#   'だと',
#   '花',
#   '粉',
#   '症',
#   'も',
#   '重',
#   '症',
#   'になる',
#   'の',
#   'か',
#   'も',
#   '。'],
#  ['▁', '花', '粉', '症', '対策', 'に', '薬', 'を', '飲', 'もう', '。'],
#  ['▁',
#   '妻',
#   'が',
#   '花',
#   '粉',
#   '症',
#   'で',
#   '毎年',
#   '春',
#   'は大',
#   '変',
#   'だ',
#   'な',
#   'あ',
#   'と',
#   '思',
#   'って',
#   '見',
#   'てい',
#   'ます',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   'か',
#   'か',
#   'ってしまった',
#   'の',
#   'で',
#   '外',
#   '出す',
#   'ら',
#   'できない',
#   '。'],
#  ['▁',
#   'あ',
#   'の',
#   '人',
#   'さ',
#   '、',
#   '痰',
#   'が',
#   '絡',
#   'んだ',
#   'とき',
#   'わ',
#   'ざ',
#   'と',
#   'ら',
#   'しく',
#   '咳',
#   '払い',
#   'する',
#   'の',
#   '本',
#   '当',
#   'に',
#   'や',
#   'めて',
#   'ほ',
#   'しい',
#   'ん',
#   'だけ',
#   'ど'],
#  ['▁', 'こん', 'な', '季', '節', 'に', '熱', 'が', '出た', '、', 'だ', 'る', 'い', '。'],
#  ['▁', '頭', '痛', 'で', 'だ', 'る', 'い', 'から', 'もう', 'や', 'だ', 'よ', 'ー', '。'],
#  ['▁この', '微', '熱', 'も', '花', '粉', '症', '由来', 'かな', 'あ'],
#  ['▁',
#   '痰',
#   'が',
#   'から',
#   'んで',
#   'ひ',
#   'ど',
#   '過ぎ',
#   'る',
#   'プレ',
#   'ゼン',
#   'した',
#   'から',
#   '、',
#   '単位',
#   '微',
#   '妙',
#   'だ',
#   '。'],
#  ['▁',
#   '鼻',
#   '水',
#   'が',
#   '今日',
#   'や',
#   'ば',
#   'い',
#   'の',
#   'で',
#   '休',
#   'む',
#   'か',
#   'も',
#   'し',
#   'れ',
#   'ま',
#   'せん',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'の',
#   'か',
#   'かり',
#   'や',
#   'す',
#   'さ',
#   'って',
#   '性',
#   'によって',
#   'ち',
#   'が',
#   'う',
#   'の',
#   'かな',
#   '。',
#   'うち',
#   'では',
#   '女性',
#   '陣',
#   'だけ',
#   '罹',
#   '患',
#   'した',
#   '。'],
#  ['▁', 'イン', 'フル', 'エン', 'ザ', 'の', 'ワ', 'ク', 'チン', 'を', '打', 'ってきた', '。'],
#  ['▁',
#   '風',
#   '邪',
#   'な',
#   'の',
#   'か',
#   '何',
#   'な',
#   'の',
#   'か',
#   '、',
#   '今日',
#   'の',
#   '頭',
#   '痛',
#   'は',
#   'や',
#   'ば',
#   'い'],
#  ['▁', '頭', '痛', 'に', '効', 'く', '特', '効', '薬', 'が必要', 'だ', 'わ', '。'],
#  ['▁',
#   'ゆ',
#   'と',
#   'り',
#   'は',
#   '口',
#   'を',
#   '抑え',
#   'て',
#   '咳',
#   'も',
#   '出来ない',
#   'の',
#   'か',
#   'よ',
#   '。'],
#  ['▁', 'や', 'ば', 'い', '!', '超', '下', '痢', 'なん', 'だけ', 'ど', '!'],
#  ['▁', 'わ', 'ざ', 'と', 'らしい', '咳', 'を', 'している', 'や', 'つ', '嫌', 'い', '。'],
#  ['▁', '春', 'だけ', 'じゃ', 'なく', '秋', 'にも', '花', '粉', '症', 'がある', 'らしい', '。'],
#  ['▁', 'イン', 'フル', 'エン', 'ザ', 'の', '検査', '、', '行', 'って', 'こ', 'よう', 'かな', '。'],
#  ['▁', '今日', '起き', 'ると', '下', '痢', 'になっていた', '。', 'や', 'ば', 'い', '。'],
#  ['▁',
#   'や',
#   'ば',
#   'り',
#   '、',
#   'お',
#   '腹',
#   'が',
#   '痛',
#   'く',
#   'て',
#   '下',
#   '痢',
#   'か',
#   'も',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'で',
#   '、',
#   '帰',
#   'る',
#   'の',
#   'も',
#   'だ',
#   'る',
#   'いく',
#   'らい',
#   '。',
#   'や',
#   'だ',
#   'な',
#   '。',
#   'こん',
#   'な',
#   'の',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。'],
#  ['▁', '咳', 'い', 'っぱ', 'い', 'すると', '疲', 'れる', 'な', 'ー'],
#  ['▁', '咳', 'で', '寝', '不足', 'で', '疲', 'れる', '。'],
#  ['▁', 'ところ', 'で', '頭', '痛', 'は', 'お', 'さ', 'まった', 'の', '?'],
#  ['▁',
#   'せ',
#   'っ',
#   'かく',
#   'の',
#   'スペイン',
#   'な',
#   'の',
#   'に',
#   '風',
#   '邪',
#   'ひ',
#   'いた',
#   '・',
#   '・',
#   '・',
#   '。'],
#  ['▁', '契約', 'を', '取', 'れない', 'と', '頭', '痛', 'が', '・', '・', '・'],
#  ['▁',
#   '鼻',
#   '水',
#   '出',
#   'る',
#   'し',
#   '、',
#   'お',
#   '腹',
#   'く',
#   'だ',
#   'る',
#   'し',
#   '、',
#   '仕事',
#   '無',
#   '理',
#   'して',
#   '行った',
#   'ら',
#   '熱',
#   'まで',
#   '出',
#   'てきた',
#   '。'],
#  ['▁',
#   '友',
#   '達',
#   'で',
#   '一',
#   '生',
#   '懸',
#   '命',
#   '巫',
#   '女',
#   'の',
#   'バイ',
#   'ト',
#   'した',
#   'ら',
#   '熱',
#   '出した',
#   '子',
#   'いる',
#   'ん',
#   'だけ',
#   'ど',
#   '、',
#   '何',
#   'か',
#   '素',
#   '質',
#   'ある',
#   'かもしれない'],
#  ['▁',
#   '寒',
#   'い',
#   'し',
#   '下',
#   '痢',
#   'だ',
#   'し',
#   '仕事',
#   'が',
#   'は',
#   'か',
#   'ど',
# ...
#   '強い',
#   '体',
#   'を',
#   '作',
#   'って',
#   'お',
#   'く',
#   'の',
#   'が',
#   '大',
#   '事',
#   'だ',
#   'よ',
#   '。'],
#  ['▁',
#   '娘',
#   'が',
#   'まだ',
#   '熱',
#   'が',
#   '下',
#   'が',
#   'らない',
#   'の',
#   'で',
#   '、',
#   '会社',
#   '休',
#   'み',
#   'ます',
#   '。'],
#  ['▁', '熱', 'は', 'ど', 'の', '季', '節', 'が', 'いち', 'ば', 'ん', 'つ', 'らい', '?'],
#  ['▁',
#   '受験',
#   '生',
#   'の',
#   '兄',
#   'が',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   'か',
#   'か',
#   'ってしまった',
#   'らしい',
#   '。'],
#  ['▁', '今日', 'は', '特に', '鼻', '水', 'が', 'や', 'ば', 'い', '。'],
#  ['▁', '翻訳', '作業', 'が', '苦', '痛', 'だ', 'ぁ', '。', '頭', '痛', 'が', 'してきた', '。'],
#  ['▁', '熱', 'が', '出た', 'け', 'ど', '鼻', '水', 'は', '垂', 'れて', 'ない', 'よ', '。'],
#  ['▁',
#   'ブログ',
#   '更新',
#   'しま',
#   'した',
#   '!',
#   '風',
#   '邪',
#   'の',
#   '予',
#   '防',
#   'には',
#   'アレ',
#   'が',
#   '一番',
#   '!'],
#  ['▁', '下', '痢', 'が', 'や', 'ば', 'く', 'て', 'お', '腹', 'が', '超', '痛', 'い', '。'],
#  ['▁', 'ヘッド', 'セット', 'を', '装着', 'すると', '、', '頭', '痛', 'が', 'する', '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'で',
#   '寝',
#   'て',
#   'た',
#   'から',
#   '背',
#   '中',
#   'が',
#   '痛',
#   'く',
#   'て',
#   'たま',
#   'ら',
#   'ん',
#   '。',
#   'だ',
#   'れ',
#   'か',
#   'マッ',
#   'サー',
#   'ジ',
#   'して',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'ワ',
#   'ク',
#   'チン',
#   'の',
#   '注',
#   '射',
#   'を',
#   '打',
#   'った',
#   'よ'],
#  ['▁', 'お', 'た', 'ふく', '風', '邪', 'が', 'ブーム', 'になる', 'らしい', '?'],
#  ['▁', '花', '粉', '症', 'から', 'まさ', 'か', 'の', '微', '熱', '。'],
#  ['▁', '秋', 'にも', '花', '粉', '症', 'って', 'ある', 'の', 'かな', '?'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   'か',
#   'か',
#   'っている',
#   '人',
#   '、',
#   '職',
#   '場',
#   'に',
#   'も多い',
#   '。',
#   '体',
#   '調',
#   '管理',
#   'し',
#   'っ',
#   'かり',
#   'し',
#   'なければ',
#   '。'],
#  ['▁',
#   '東京',
#   '遊び',
#   'に',
#   '来た',
#   'け',
#   'ど',
#   '鼻',
#   '風',
#   '邪',
#   'ひ',
#   'いて',
#   'しん',
#   'ど',
#   'い'],
#  ['▁',
#   '鼻',
#   '水',
#   '出',
#   'る',
#   'け',
#   'ど',
#   '風',
#   '邪',
#   'な',
#   'の',
#   'か',
#   'アレ',
#   'ル',
#   'ギー',
#   'な',
#   'の',
#   'か',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   '患者',
#   '喜',
#   'べ',
#   '、',
#   '来',
#   '春',
#   'は',
#   '花',
#   '粉',
#   'は',
#   '少ない',
#   'らしい',
#   '!'],
#  ['▁', '咳', 'し', 'すぎ', 'て', '、', '腹', '筋', 'バ', 'キ', 'バ', 'キ', '。'],
#  ['▁',
#   '嫁',
#   'が',
#   '熱',
#   'で',
#   '休',
#   'んでいる',
#   'んで',
#   'す',
#   'が',
#   '、',
#   '鼻',
#   '水',
#   'が',
#   '詰',
#   'まって',
#   '眠',
#   'れない',
#   'と',
#   '言い',
#   '出し',
#   'ま',
#   'して',
#   '。'],
#  ['▁',
#   '早',
#   'め',
#   'に',
#   '頭',
#   '痛',
#   '薬',
#   'を',
#   '飲',
#   'む',
#   'ことが',
#   '必要',
#   'だ',
#   '。',
#   'タイ',
#   'ミング',
#   'を',
#   '逸',
#   'すると',
#   '苦',
#   '痛',
#   'が',
#   '続く',
#   '。'],
#  ['▁',
#   '熱',
#   'が',
#   '出た',
#   'の',
#   'で',
#   '一',
#   '日',
#   '中',
#   'ベ',
#   'ッド',
#   'の',
#   '上で',
#   'テレビ',
#   'を見て',
#   '過ごし',
#   'た',
#   '。'],
#  ['▁', '痰', 'は', '人', '前', 'では', 'かない', 'の', 'が', 'エ', 'チ', 'ケット', '!'],
#  ['▁',
#   '兄',
#   'が',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'と',
#   'か',
#   '言い',
#   '出',
#   'して',
#   '昨',
#   '晩',
#   'から',
#   '吐',
#   'いて',
#   'る',
#   'んで',
#   'す',
#   'が'],
#  ['▁',
#   '寒',
#   '気',
#   'が',
#   'して',
#   'だ',
#   'る',
#   'い',
#   '。',
#   '本格的に',
#   '風',
#   '邪',
#   'を',
#   '引',
#   'いた',
#   'かもしれない',
#   '。'],
#  ['▁',
#   '朝',
#   '起きた',
#   'ら',
#   '下',
#   '痢',
#   'が',
#   'や',
#   'ば',
#   'いで',
#   '御',
#   '座',
#   'る',
#   'の',
#   '巻',
#   '。',
#   '今日',
#   'は',
#   '仕事',
#   '行',
#   'け',
#   'ない',
#   'か',
#   'も',
#   '。'],
#  ['▁',
#   'お',
#   'た',
#   'ふく',
#   '風',
#   '邪',
#   'って',
#   'み',
#   'ん',
#   'な',
#   '小さい',
#   '時に',
#   'や',
#   'っている',
#   'の',
#   'かな',
#   '?',
#   '俺',
#   'は',
#   'な',
#   'っていない',
#   'から',
#   '大',
#   '人',
#   'になって',
#   'か',
#   'かった',
#   'ら',
#   '大',
#   '変',
#   'だと',
#   '聞',
#   'いた',
#   '。'],
#  ['▁',
#   '朝',
#   'や',
#   'ば',
#   'い',
#   '頭',
#   '痛',
#   'に',
#   '襲',
#   'われ',
#   'て',
#   'から',
#   '体',
#   'が',
#   'だ',
#   'る',
#   'く',
#   'て',
#   'しょう',
#   'がない'],
#  ['▁', '風', '邪', '最', '悪', 'だけ', 'ど', '、', '休', 'める', '訳', 'もない', '。'],
#  ['▁', '季', '節', '外', 'れ', 'の', '熱', '風', '邪', '中', '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'の',
#   '熱',
#   'で',
#   '兄',
#   'の',
#   '背',
#   '中',
#   'が',
#   '真',
#   'っ',
#   '赤',
#   'になっていた',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'で',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。',
#   '今日',
#   'は',
#   '今',
#   '一',
#   'だ',
#   '。',
#   '本格的に',
#   'だ',
#   'る',
#   'い',
#   '。'],
#  ['▁',
#   '娘',
#   'が',
#   '熱',
#   'を',
#   'だ',
#   'した',
#   'と',
#   '聞',
#   'いて',
#   '急',
#   'いで',
#   '帰',
#   'ってきた',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'っぽ',
#   'い',
#   'の',
#   'は',
#   '昨',
#   '晩',
#   '外',
#   '出した',
#   'の',
#   'が',
#   '原因',
#   'か',
#   'も',
#   '。'],
#  ['▁',
#   'ヘッド',
#   'セット',
#   'が',
#   'き',
#   'つ',
#   'い',
#   'から',
#   'か',
#   '頭',
#   '痛',
#   'が',
#   '酷',
#   'い',
#   '。'],
#  ['▁', '来', '春', 'は', '花', '粉', '症', '患者', 'が増え', 'そう', 'だ', '。'],
#  ['▁この',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'は',
#   '感染',
#   'しても',
#   'そこ',
#   'まで',
#   '高い',
#   '熱',
#   'が出',
#   'ない',
#   'らしい',
#   'ね'],
#  ['▁',
#   '翻訳',
#   'の',
#   '契約',
#   'が',
#   'できた',
#   'が',
#   '仕事',
#   'が',
#   'き',
#   'つ',
#   'い',
#   'の',
#   'ことが',
#   '頭',
#   '痛',
#   'の',
#   'タ',
#   'ネ',
#   'だ',
#   '。'],
#  ['▁', '咳', 'が', '止ま', 'らず', 'に', '本', '当', 'に', '疲', 'れる'],
#  ['▁',
#   '今',
#   '回',
#   'に',
#   '頭',
#   '痛',
#   'が',
#   '激しい',
#   'の',
#   'は',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。'],
#  ['▁', '頭', '痛', 'が', '続いて', '毎日', 'が', '苦', '痛', 'です', '。'],
#  ['▁',
#   'や',
#   'ば',
#   'いく',
#   'らい',
#   '寒',
#   'く',
#   'て',
#   '腹',
#   '冷',
#   'えて',
#   '下',
#   '痢',
#   'だ',
#   'ー'],
#  ['▁',
#   '咳',
#   'の',
#   'とき',
#   'は',
#   'ちゃん',
#   'と',
#   '口',
#   'を',
#   '抑え',
#   'る',
#   'の',
#   'が',
#   'エ',
#   'チ',
#   'ケット',
#   'だ',
#   'ろ'],
#  ['▁', 'イン', 'フル', 'エン', 'ザ', 'が', '流行', 'る', '季', '節', 'になった', '。'],
#  ['▁',
#   'バイ',
#   'ト',
#   '先',
#   'から',
#   '帰',
#   'る',
#   '途中',
#   'に',
#   '頭',
#   '痛',
#   'が',
#   'して',
#   'い',
#   'ます',
#   '。'],
#  ['▁', '高', '熱', 'でも', 'よく', '眠', 'れる', '薬', 'って', '何', '?'],
#  ['▁',
#   'ところ',
#   'で',
#   '頭',
#   '痛',
#   'が',
#   '痛',
#   'い',
#   'は',
#   '痛',
#   'い',
#   'が',
#   'だ',
#   'ぶ',
#   'って',
#   'る',
#   'から',
#   'アウト',
#   'です',
#   'よ'],
#  ['▁',
#   '鼻',
#   '水',
#   'が',
#   '少し',
#   '垂',
#   'れ',
#   'てきた',
#   'だけで',
#   '会社',
#   'を',
#   '休',
#   'む',
#   '、',
#   '俺',
#   'の',
#   '妻',
#   '。'],
#  ['▁',
#   'リン',
#   'パ',
#   '腫',
#   'れて',
#   '熱',
#   '出',
#   'てきた',
#   '。',
#   '明',
#   '日',
#   '仕事',
#   '行',
#   'ける',
#   'か',
#   '微',
#   '妙',
#   'だ',
#   'な',
#   '。'],
#  ['▁', '風', '邪', 'で', '寒', '気', 'が', '止ま', 'らない', '。'],
#  ['▁', '今日', 'こそ', '鼻', '水', 'が', '止ま', 'って', 'ほ', 'しい', '。'],
#  ['▁',
#   '最近',
#   '微',
#   '熱',
#   '続き',
#   'なん',
#   'だけ',
#   'ど',
#   '、',
#   'これ',
#   'も',
#   '花',
#   '粉',
#   '症',
#   'の',
#   'せい',
#   '?'],
#  ['▁', '下', '痢', 'って', '英語', 'で', 'なん', 'て', '言う', 'んだ'],
#  ['▁', 'イン', 'フル', 'エン', 'ザ', 'って', '鳥', 'にも', 'かかる', 'んだ', 'ね', '。'],
#  ['▁', 'リン', 'パ', 'が', '腫', 'れる', 'と', '熱', 'が出', 'る', 'んだ', 'っ', 'け', '?'],
#  ['▁', '咳', 'より', '痰', 'の方が', 'ひ', 'ど', 'い', 'から', '薬', '飲', 'む', '。'],
#  ['▁',
#   '鼻',
#   'づ',
#   'まり',
#   'が',
#   'や',
#   'ば',
#   'い',
#   'から',
#   'なん',
#   'か',
#   '今日',
#   '行く',
#   'の',
#   'や',
#   'めた',
#   '。'],
#  ['▁',
#   'だ',
#   'から',
#   '咳',
#   'する',
#   'とき',
#   'は',
#   '手',
#   'で',
#   '覆',
#   'う',
#   'の',
#   'が',
#   'エ',
#   'チ',
#   'ケット',
#   'だ',
#   'って',
#   '何',
#   '度',
#   '言',
#   'わ',
#   'せん',
#   'の',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   '長',
#   '風',
#   '呂',
#   'した',
#   'ら',
#   '頭',
#   '痛',
#   'なお',
#   'った',
#   '!',
#   'リ',
#   'ラ',
#   'ックス',
#   '大',
#   '事',
#   'だ',
#   'な',
#   '〜'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '療法',
#   'が',
#   '発達',
#   'して',
#   'だい',
#   'ぶ',
#   '楽',
#   'になった',
#   'よ',
#   'ね',
#   'ー',
#   '。'],
#  ['▁',
#   '咳',
#   'が出',
#   'る',
#   '人は',
#   'マス',
#   'ク',
#   'する',
#   'の',
#   'が',
#   'エ',
#   'チ',
#   'ケット',
#   'だ',
#   'よ',
#   'な',
#   '。'],
#  ['▁', '最', '悪', 'だ', '・', '・', '・', '。', '絶対', 'コ', 'レ', '風', '邪', 'だ', '。'],
#  ['▁',
#   '最',
#   '悪',
#   'だ',
#   '。',
#   'これ',
#   'から',
#   '大',
#   '切',
#   'な',
#   '会議',
#   'な',
#   'の',
#   'に',
#   '、',
#   '風',
#   '邪',
#   '引',
#   'いて',
#   '頭',
#   'が',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。'],
#  ['▁', '鼻', '水', 'が', 'ひ', 'ど', 'く', 'て', '寝', 'る', 'の', '無', '理', 'だ', '。'],
#  ['▁', 'こん', 'な', 'に', '激しい', '頭', '痛', '久', 'し', '振り', 'だ', 'ぜ'],
#  ['▁', 'イン', 'フル', 'で', '検査', '。', '混', 'んで', 'る'],
#  ['▁',
#   '眠',
#   'く',
#   'て',
#   'だ',
#   'る',
#   'く',
#   'て',
#   '参',
#   'った',
#   '。',
#   '風',
#   '邪',
#   'だ',
#   '、',
#   '最',
#   '悪',
#   'だ',
#   '。',
#   '頭',
#   '痛',
#   'っぽ',
#   'い',
#   '。'],
#  ['▁',
#   '頭',
#   '痛',
#   'き',
#   'つ',
#   'い',
#   '、',
#   '病院',
#   'で',
#   '処',
#   '方',
#   'された',
#   '薬',
#   'が必要',
#   'だ',
#   '。'],
#  ['▁',
#   '朝',
#   'から',
#   'こん',
#   'な',
#   'に',
#   '頭',
#   '痛',
#   'が',
#   'する',
#   'の',
#   'は',
#   '久',
#   'し',
#   '振り',
#   'だ',
#   '。'],
#  ['▁',
#   '咳',
#   '止ま',
#   'らない',
#   'の',
#   'に',
#   'マス',
#   'ク',
#   'を',
#   'しない',
#   '奴',
#   'は',
#   'エ',
#   'チ',
#   'ケット',
#   'が',
#   'な',
#   'っていない'],
#  ['▁',
#   'や',
#   'ば',
#   'い',
#   'ものを',
#   '食',
#   'う',
#   'と',
#   '何',
#   '時',
#   'も',
#   '下',
#   '痢',
#   'を',
#   'する',
#   '。'],
#  ['▁', '海', '鮮', '丼', '食べ', 'た', 'ら', '下', '痢', 'になった', '・', '・', '・'],
#  ['▁',
#   '頭',
#   '痛',
#   'の',
#   'とき',
#   'って',
#   '痛',
#   'く',
#   'ならない',
#   'ように',
#   'ソロ',
#   'ソロ',
#   '動',
#   'く',
#   '。'],
#  ['▁',
#   'どう',
#   'も',
#   '熱',
#   'がある',
#   '気',
#   'が',
#   'する',
#   '、',
#   '季',
#   '節',
#   'の',
#   '変わり',
#   '目',
#   'だ',
#   'し',
#   '、',
#   '早く',
#   '帰',
#   'って',
#   '寝',
#   'よう',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'に',
#   'か',
#   'か',
#   'って',
#   'ご',
#   '飯',
#   '作',
#   'ること',
#   'が',
#   'できない',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'が',
#   '治',
#   'らない',
#   'の',
#   'で',
#   '、',
#   '明',
#   '日の',
#   'ブログ',
#   'の',
#   '更新',
#   'は',
#   '延',
#   '期',
#   'し',
#   'ます',
#   '。',
#   'す',
#   'み',
#   'ま',
#   'せん',
#   '!'],
#  ['▁',
#   '寒',
#   '気',
#   'と',
#   'だ',
#   'る',
#   'さ',
#   'と',
#   '頭',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。',
#   '風',
#   '邪',
#   'かな',
#   'こ',
#   'り',
#   'ゃ',
#   '・',
#   '・',
#   '・',
#   '。'],
#  ['▁',
#   '熱',
#   'だ',
#   'し',
#   '鼻',
#   '水',
#   'だ',
#   'し',
#   '。',
#   'い',
#   'き',
#   'なり',
#   'ビ',
#   'ック',
#   'リ',
#   'して',
#   '怖',
#   'いわ'],
#  ['▁',
#   'スペイン',
#   '風',
#   '邪',
#   'と',
#   'お',
#   'た',
#   'ふく',
#   '風',
#   '邪',
#   'の',
#   '違い',
#   'を',
#   '教え',
#   'てくれ'],
#  ['▁',
#   '今日',
#   '朝',
#   'から',
#   '何',
#   'も',
#   '食べ',
#   'て',
#   'ない',
#   'の',
#   'に',
#   '下',
#   '痢',
#   '。',
#   'や',
#   'ば',
#   'い',
#   '。'],
#  ['▁', 'スペイン', '行', 'って', 'から', '、', '風', '邪', '気', '味', 'だ', '。'],
#  ['▁', '兄', 'が', 'や', 'っと', 'イン', 'フル', 'から', '回復', 'した', '。'],
#  ['▁', '部', '活', '内で', 'イン', 'フル', 'が', '流行', 'している', '。'],
#  ['▁',
#   '風',
#   '邪',
#   '対策',
#   'は',
#   '完',
#   '璧',
#   'だと',
#   '思',
#   'って',
#   'た',
#   'の',
#   'に',
#   '、',
#   '眠',
#   'い',
#   'から',
#   'って',
#   '炬燵',
#   'で',
#   'う',
#   'た',
#   'た',
#   '寝',
#   'して',
#   'から',
#   '調',
#   '子が',
#   '微',
#   '妙',
#   'だ',
#   '。'],
#  ['▁', 'イン', 'フル', 'の', '奴', 'って', '沢', '山', '居', 'る', 'よ', 'な'],
#  ['▁',
#   'や',
#   'ば',
#   'い',
#   '、',
#   'お',
#   '腹',
#   '痛',
#   'い',
#   '。',
#   '下',
#   '痢',
#   'と',
#   'ま',
#   'ら',
#   'ん',
#   '。'],
#  ['▁',
#   '昨',
#   '晩',
#   'の',
#   'テレビ',
#   'の',
#   'イン',
#   'フル',
#   '特',
#   '集',
#   '見',
#   'た',
#   'ら',
#   '、',
#   'マス',
#   'ク',
#   '買い',
#   'に',
#   '行き',
#   'た',
#   'く',
#   'なった',
#   'わ',
#   'ー'],
#  ['▁', '風', '邪', 'の', 'せい', 'で', '体', '調', 'が', '微', '妙', 'だ'],
#  ['▁',
#   '中国',
#   'で',
#   '鳥',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'が',
#   '流行',
#   'って',
#   'る',
#   'って',
#   '本',
#   '当',
#   'かな',
#   '?'],
#  ['▁', 'ア', 'ト', 'ピー', 'だと', '花', '粉', '症', 'も', 'つ', 'らい', 'んだ', 'よ', 'ー'],
#  ['▁',
#   '咳',
#   'が',
#   '止ま',
#   'らない',
#   'から',
#   '腹',
#   '筋',
#   'も',
#   '痛',
#   'く',
#   'な',
#   'ってきた',
#   'し',
#   '、',
#   'さ',
#   'っ',
#   'き',
#   '飲',
#   'んだ',
#   '薬',
#   'も',
#   '効',
#   'いて',
#   'こ',
#   'ない',
#   '。'],
#  ['▁',
#   '嬉',
#   'しい',
#   '!',
#   'フォ',
#   'ロ',
#   'ワー',
#   'さん',
#   'の',
#   '優',
#   'し',
#   'さ',
#   'に',
#   '鼻',
#   '水',
#   '噴',
#   'く',
#   'わ',
#   '〜',
#   '〜'],
#  ['▁', '今日', 'も', '下', '痢', 'が', '続いて', 'る', 'な', 'ー'],
#  ['▁',
#   '今',
#   '朝',
#   'の',
#   '通勤',
#   '電車',
#   'で',
#   '咳',
#   'エ',
#   'チ',
#   'ケット',
#   'が',
#   'でき',
#   'ていない',
#   '女性',
#   'が',
#   'いて',
#   'す',
#   'ごく',
#   '嫌',
#   'な',
#   '気',
#   '持ち',
#   'になった'],
#  ['▁',
#   '頭',
#   '痛',
#   'の',
#   '症状',
#   'が',
#   'ど',
#   'ん',
#   'なか',
#   'を',
#   '相手',
#   'に',
#   '伝え',
#   'る',
#   'の',
#   'って',
#   '難しい',
#   '。'],
#  ['▁この',
#   '前',
#   '、',
#   '近く',
#   'の',
#   'サッカー',
#   'チーム',
#   'で',
#   '集団',
#   'で',
#   '食',
#   '中',
#   '毒',
#   '起き',
#   'て',
#   'み',
#   'ん',
#   'な',
#   '下',
#   '痢',
#   'に',
#   'な',
#   'っ',
#   'ちゃ',
#   'った',
#   'らしい',
#   '。',
#   '昔',
#   'な',
#   'って',
#   'キ',
#   'ツ',
#   'かった',
#   'の',
#   '思い',
#   '出した',
#   'わ',
#   '。'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '予',
#   '防',
#   '注',
#   '射',
#   '打',
#   'った',
#   'ん',
#   'だけ',
#   'ど',
#   '効果',
#   'なし',
#   '。'],
#  ['▁',
#   '咳',
#   'を',
#   'し',
#   '過ぎ',
#   'ると',
#   '腹',
#   '筋',
#   '痛',
#   'くなる',
#   'し',
#   '頭',
#   'まで',
#   '痛',
#   'くなる',
#   'で',
#   'しょう',
#   '?'],
#  ['▁',
#   '今日',
#   'デー',
#   'ト',
#   'な',
#   'の',
#   'に',
#   '風',
#   '邪',
#   'と',
#   'か',
#   '最',
#   '悪',
#   'だ',
#   '・',
#   '・',
#   '・'],
#  ['▁',
#   '花',
#   '粉',
#   '症',
#   'だと',
#   '思',
#   'って',
#   'た',
#   'ら',
#   '、',
#   '微',
#   '熱',
#   'が',
#   '出て',
#   'き',
#   'て',
#   '風',
#   '邪',
#   'だと',
#   '判明',
#   '!',
#   '間',
#   '違',
#   'える',
#   'こともある',
#   'んで',
#   'す',
#   'ね',
#   '。'],
#  ['▁', 'ひ', 'ど', 'い', '頭', '痛', 'が', '続く', '。', '休', '息', 'が必要', 'だ', '。'],
#  ['▁',
#   'ようやく',
#   'イン',
#   'フル',
#   'エン',
#   'ザ',
#   'から',
#   '回復',
#   'してきた',
#   'け',
#   'ど',
#   'まだ',
#   '本',
#   '調',
#   '子',
#   'じゃ',
#   'ない',
#   '。'],
#  ['▁',
#   '朝',
#   '下',
#   '痢',
#   '止ま',
#   'ら',
#   'なく',
#   'て',
#   '仕事',
#   '行',
#   'け',
#   'ない',
#   'か',
#   'と',
#   '思',
#   'った'],
#  ['▁',
#   'デン',
#   'グ',
#   '熱',
#   'の',
#   '感染',
#   'について',
#   'テレビ',
#   'ニュース',
#   'で',
#   '報道',
#   'があった',
#   '。'],
#  ['▁',
#   'イン',
#   'フル',
#   'の',
#   'ワ',
#   'ク',
#   'チン',
#   '朝',
#   'から',
#   '接',
#   '種',
#   'してきた',
#   'から',
#   'な',
#   'んだ',
#   'か',
#   '体',
#   'が',
#   'だ',
#   'る',
#   'お',
#   'も',
#   'い',
#   'な',
#   '。'],
#  ['▁', '下', '痢', 'が', '止ま', 'ら', 'なく', 'て', 'や', 'ば', 'い', '。'],
#  ['▁',
#   '鼻',
#   'づ',
#   'まり',
#   'って',
#   'もう',
#   'なん',
#   'も',
#   '感じ',
#   'なく',
#   'て',
#   '無',
#   '理',
#   'だ',
#   '。'],
#  ['▁', '熱', 'の', 'せい', 'か', 'リン', 'パ', 'が', '腫', 'れている', '。'],
#  ['▁',
#   '熱',
#   'が',
#   '出た',
#   'ん',
#   'け',
#   'ど',
#   '、',
#   'ウイルス',
#   'に',
#   '感染',
#   'した',
#   'かな',
#   '・',
#   '・',
#   '・',
#   '?'],
#  ['▁', '寒', 'い', 'せい', 'か', '朝', 'から', '下', '痢', 'が', 'や', 'ば', 'い', '!'],
#  ['▁日本', 'に帰', 'って', 'き', 'て', 'から', '下', '痢', 'が', 'と', 'ま', 'ら', 'ん', '。'],
#  ['▁',
#   '宇宙',
#   'の',
#   'ことを',
#   '考え',
#   '始めた',
#   'ら',
#   '止ま',
#   'ら',
#   'なく',
#   'な',
#   'って',
#   '頭',
#   '痛',
#   '。'],
#  ['▁', '鼻', '風', '邪', 'と', '頭', '痛', 'が', 'や', 'ば', 'い', '。'],
#  ['▁',
#   '科学',
#   'が',
#   '発達',
#   'しても',
#   '風',
#   '邪',
#   'は',
#   '中',
#   '々',
#   'なく',
#   'ならない',
#   'ね',
#   'ぇ',
#   '。'],
#  ['▁',
#   '寒',
#   '気',
#   'が',
#   'する',
#   '。',
#   'しか',
#   'も',
#   'ぼ',
#   'ー',
#   'っと',
#   'する',
#   '。',
#   'これは',
#   '風',
#   '邪',
#   'か',
#   'も',
#   '。'],
#  ['▁',
#   '妻',
#   'の',
#   '憂鬱',
#   'そう',
#   'な',
#   'マス',
#   'ク',
#   '姿',
#   '。',
#   '早く',
#   'も',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '季',
#   '節',
#   'が',
#   '来た',
#   'らしい',
#   '。'],
#  ['▁', 'イン', 'フル', 'エン', 'ザ', 'から', '回復', 'した', 'の', 'で', '外', '出した', '。'],
#  ['▁',
#   '外',
#   'で',
#   '痰',
#   'を',
#   '吐',
#   'く',
#   '人',
#   'には',
#   '叱',
#   'ること',
#   'が必要',
#   'だと',
#   '思',
#   'う',
#   'け',
#   'ど'],
#  ['▁',
#   '風',
#   '邪',
#   'を',
#   'ひ',
#   'いた',
#   'ら',
#   'しく',
#   '寒',
#   '気',
#   'が',
#   'する',
#   'し',
#   'だ',
#   'る',
#   'い',
#   '。'],
#  ['▁',
#   '咳',
#   'を',
#   '止め',
#   'る',
#   '薬',
#   'を',
#   '飲',
#   'む',
#   'と',
#   '副',
#   '作用',
#   'で',
#   '頭',
#   'が',
#   'ぼ',
#   'ー',
#   'っと',
#   'し',
#   'てくる',
#   'から',
#   'この',
#   '状況',
#   'で',
#   '飲',
#   'む',
#   'という',
#   'の',
#   'は',
#   '微',
#   '妙',
#   'だ',
#   '。'],
#  ['▁', '祖', '母', 'の', '作った', '親', '子', '丼', 'で', '下', '痢', 'になった', '死', 'んだ'],
#  ['▁', '鼻', 'づ', 'まり', 'の', '解消', '方法', '、', '誰', 'か', '教え', 'て', '。'],
#  ['▁',
#   '今日',
#   'は',
#   '風',
#   '邪',
#   'で',
#   '寒',
#   '気',
#   'が',
#   'して',
#   'だ',
#   'る',
#   'い',
#   'し',
#   '、',
#   '眠',
#   'い',
#   'し',
#   '、',
#   'ぼ',
#   'ー',
#   'っ',
#   'として',
#   'る',
#   'し',
#   '、',
#   '外',
#   '出',
#   'する',
#   'か',
#   'も',
#   '微',
#   '妙',
#   'だ',
#   'な',
#   '。'],
#  ['▁', '粗', '熱', 'を', 'と', 'って', 'から', '涼', 'しい', 'ところ', 'に', '置', 'く', '。'],
#  ['▁',
#   '痰',
#   'が',
#   'で',
#   'る',
#   'とき',
#   'は',
#   '特に',
#   '手',
#   '洗',
#   'い',
#   'とう',
#   'が',
#   'い',
#   'を',
#   'し',
#   'よう',
#   'よ',
#   '。'],
#  ['▁', 'イン', 'フル', '蔓', '延', 'して', 'て', '部', '活', '中止', 'になった'],
#  ['▁',
#   '朝',
#   '目',
#   'が',
#   '覚',
#   'めた',
#   '途',
#   '端',
#   'に',
#   '頭',
#   '痛',
#   'が',
#   'く',
#   'ると',
#   'か',
#   '、',
#   '最',
#   '悪',
#   'です',
#   'わ'],
#  ['▁',
#   'ブログ',
#   'には',
#   '高',
#   '熱',
#   'が',
#   '出て',
#   '痰',
#   'も',
#   '出',
#   'ると',
#   '書',
#   'いていた',
#   '。'],
#  ['▁', '頭', '痛', 'なん', 'て', '苦', '痛', '以外の', '何', '物', 'で', 'もない', '。'],
#  ['▁',
#   '微',
#   '熱',
#   'がある',
#   'ん',
#   'だけ',
#   'ど',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '症状',
#   'じゃ',
#   'ない',
#   'よ',
#   'ね',
#   '?'],
#  ['▁',
#   '秋',
#   'でも',
#   '花',
#   '粉',
#   '症',
#   'の',
#   '患者',
#   'さん',
#   'は',
#   'いる',
#   'み',
#   'た',
#   'いだ',
#   'し'],
#  ['▁',
#   '最近',
#   'ち',
#   'ょ',
#   'っと',
#   '腹',
#   'が',
#   '痛',
#   'い',
#   'と',
#   'い',
#   'つ',
#   'も',
#   '下',
#   '痢',
#   'だ',
#   '。'],
#  ['▁',
#   '風',
#   '邪',
#   'と',
#   '言',
#   'えば',
#   'スペイン',
#   '、',
#   'お',
#   'た',
#   'ふく',
#   '、',
#   'ど',
#   'っ',
#   'ち',
#   'が',
#   '強い',
#   '?'],
#  ['▁',
#   '朝',
#   'から',
#   '猛',
#   '烈',
#   'に',
#   '腹',
#   'が',
#   '痛',
#   'かった',
#   'け',
#   'ど',
#   '、',
#   '案',
#   'の',
#   '定',
#   '下',
#   '痢',
#   'だった',
#   '。'],
#  ['▁', 'こん', 'な', 'に', 'つ', 'らい', '頭', '痛', '久', 'し', '振り', 'だ', 'わ'],
#  ...]

# %%
tok_v = t.process_all(valid_df[1])

# %%
data_lm = TextLMDataBunch.from_tokens(path=dataset_dir,trn_tok=tok,val_tok=tok_v,trn_lbls=[],val_lbls=[],vocab=sp['vocab'])

# %%
data_lm
# Out:
# TextLMDataBunch;
# Train: LabelList
# y: LMLabel (1920 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/MedWeb
# x: LMTextList (1920 items)
# [Text ▁ 風 邪 を 引 く と 全 身 が だ る くなる 。, Text ▁ 花 粉 症 の 症状 が出 てきた の は 久 し 振り だ 。, Text ▁ 花 粉 症 の せい で ず っと 微 熱 で ぼ ー っ として る 。 眠 い 。, Text ▁ 薬 飲 ん だけ ど 鼻 水 お さま る 気 配 なし, Text ▁ ネ パー ル に 旅行 に 行った 際に 下 <unk> になって 大 変 だった よ 。]...
# Path: data/MedWeb;
# Valid: LabelList
# y: LMLabel (640 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/MedWeb
# x: LMTextList (640 items)
# [Text ▁ 旅行 に 行った ら 、 土 産 に イン フル も ら ってきた 。, Text ▁ き つ い 上 司 、 頭 痛 の 種, Text ▁ もう 誰 か 翻訳 し てくれ ない とき つ い 、 宇宙 の 言葉 です か って く らい 通じ なく て 頭 痛 してきた 。, Text ▁ イン フル 感染 の 危機 。, Text ▁ 鼻 づ まり が ひ ど い から ス ピー チ は 無 理 だ]...
# Path: data/MedWeb;
# Test: None

# %%
data_lm = TextLMDataBunch.from_df(path=dataset_dir,train_df=train_df.sample(frac=frac_ds,random_state=42),
                                      valid_df=valid_df,label_delim=',',**sp)

# %%
data_lm
# Out:
# TextLMDataBunch;
# Train: LabelList
# y: LMLabel (1920 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/MedWeb
# x: LMTextList (1920 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 朝 から 猛 烈 に 腹 が 痛 かった け ど 、 案 の 定 下 <unk> だった 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 軽 い 頭 痛 だ から 、 大 丈 夫 っ しょ 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 下 <unk> って 、 英語 で なん て 言う ?, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ お 腹 が 痛 く て 起きた ら 、 下 <unk> になっていた ・ ・ ・ 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ せ っ かく の スペイン な の に 風 邪 ひ いた ・ ・ ・ 。]...
# Path: data/MedWeb;
# Valid: LabelList
# y: LMLabel (640 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: data/MedWeb
# x: LMTextList (640 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 旅行 に 行った ら 、 土 産 に イン フル も ら ってきた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ き つ い 上 司 、 頭 痛 の 種, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ もう 誰 か 翻訳 し てくれ ない とき つ い 、 宇宙 の 言葉 です か って く らい 通じ なく て 頭 痛 してきた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ イン フル 感染 の 危機 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 鼻 づ まり が ひ ど い から ス ピー チ は 無 理 だ]...
# Path: data/MedWeb;
# Test: None

# %%
# load train, valid in df
train_df = pd.read_csv(dataset_dir/'train.csv',header=None)
valid_df = pd.read_csv(dataset_dir/'valid.csv',header=None)

# %%
train_df[0].apply(eval).head()
# Out:
# 0                          [Cold]
# 1           [Hayfever, Runnynose]
# 2    [Hayfever, Fever, Runnynose]
# 3                     [Runnynose]
# 4                              []
# Name: 0, dtype: object

# %%
train_df[0].apply(eval).values
# Out:
# array([list(['Cold']), list(['Hayfever', 'Runnynose']), list(['Hayfever', 'Fever', 'Runnynose']), list(['Runnynose']),
#        ..., list(['Cold']), list(['Diarrhea']), list([]), list(['Cold'])], dtype=object)

# %%
data_clas_new = TextClasDataBunch.from_tokens(path=dataset_dir,trn_tok=tok,val_tok=tok_v,
                                              trn_lbls=train_df[0].apply(eval).values,
                                              val_lbls=valid_df[0].apply(eval).values,vocab=sp['vocab'])

# %%
data_clas_new
# Out:
# TextClasDataBunch;
# Train: LabelList
# y: MultiCategoryList (1920 items)
# [MultiCategory Cold, MultiCategory Hayfever;Runnynose, MultiCategory Hayfever;Fever;Runnynose, MultiCategory Runnynose, MultiCategory ]...
# Path: .
# x: TextList (1920 items)
# [Text ▁ 風 邪 を 引 く と 全 身 が だ る くなる 。, Text ▁ 花 粉 症 の 症状 が出 てきた の は 久 し 振り だ 。, Text ▁ 花 粉 症 の せい で ず っと 微 熱 で ぼ ー っ として る 。 眠 い 。, Text ▁ 薬 飲 ん だけ ど 鼻 水 お さま る 気 配 なし, Text ▁ ネ パー ル に 旅行 に 行った 際に 下 <unk> になって 大 変 だった よ 。]...
# Path: data/MedWeb;
# Valid: LabelList
# y: MultiCategoryList (640 items)
# [MultiCategory Influenza;Fever, MultiCategory , MultiCategory , MultiCategory Influenza;Fever, MultiCategory Runnynose]...
# Path: .
# x: TextList (640 items)
# [Text ▁ 旅行 に 行った ら 、 土 産 に イン フル も ら ってきた 。, Text ▁ き つ い 上 司 、 頭 痛 の 種, Text ▁ もう 誰 か 翻訳 し てくれ ない とき つ い 、 宇宙 の 言葉 です か って く らい 通じ なく て 頭 痛 してきた 。, Text ▁ イン フル 感染 の 危機 。, Text ▁ 鼻 づ まり が ひ ど い から ス ピー チ は 無 理 だ]...
# Path: data/MedWeb;
# Test: None

# %%
data_clas_new.train_ds.y.c2i
# Out:
# {'Cold': 0,
#  'Cough': 1,
#  'Diarrhea': 2,
#  'Fever': 3,
#  'Hayfever': 4,
#  'Headache': 5,
#  'Influenza': 6,
#  'Runnynose': 7}

# %%
data_clas_new.train_ds.x.vocab.itos
# Out:
# ['<unk>',
#  '<pad>',
#  'xxbos',
#  'xxfld',
#  'xxunk',
#  'xxpad',
#  'の',
#  '、',
#  '。',
#  '▁',
#  'は',
#  'が',
#  'を',
#  'に',
#  '・',
#  ')',
#  '年',
#  '(',
#  'で',
#  'と',
#  '.',
#  '」',
#  'した',
#  '「',
#  '月',
#  '▁"',
#  'し',
#  'から',
#  '1',
#  'である',
#  '2',
#  'する',
#  'も',
#  'や',
#  '日',
#  'ス',
#  '3',
#  'として',
#  'た',
#  'では',
#  'る',
#  '4',
#  'された',
#  '』',
#  '大',
#  'な',
#  '『',
#  '人',
#  'ア',
#  'い',
#  'り',
#  '5',
#  'ク',
#  'ト',
#  'には',
#  'している',
#  'この',
#  '7',
#  'して',
#  'という',
#  '8',
#  'リ',
#  'ラ',
#  'か',
#  '6',
#  '9',
#  '中',
#  '10',
#  'その',
#  '年に',
#  'く',
#  'また',
#  'など',
#  'て',
#  '本',
#  'ル',
#  '市',
#  '山',
#  '-',
#  '第',
#  'され',
#  'カ',
#  'ド',
#  '一',
#  '上',
#  '田',
#  '国',
#  'マ',
#  '者',
#  'ズ',
#  '長',
#  '地',
#  'ている',
#  'される',
#  '下',
#  'ら',
#  'コ',
#  '▁-',
#  'タ',
#  '川',
#  'ナ',
#  '日本',
#  'されている',
#  '12',
#  '18',
#  'フ',
#  '家',
#  '""',
#  '名',
#  'み',
#  'ロ',
#  'き',
#  '線',
#  '町',
#  'エ',
#  '戦',
#  '水',
#  '後',
#  'となった',
#  '回',
#  '同',
#  'によって',
#  ',',
#  'った',
#  '法',
#  '11',
#  '部',
#  '日に',
#  '高',
#  'ミ',
#  'ム',
#  '新',
#  '子',
#  'オ',
#  'バ',
#  '駅',
#  'による',
#  '前',
#  'C',
#  'ッ',
#  ':',
#  '生',
#  '内',
#  'ブ',
#  '三',
#  'レ',
#  '化',
#  'シ',
#  'イ',
#  'により',
#  '数',
#  'e',
#  '小',
#  '位',
#  '分',
#  'M',
#  'であった',
#  'S',
#  'ン',
#  'す',
#  '出',
#  '体',
#  'D',
#  'ウ',
#  'つ',
#  'リー',
#  'A',
#  'であり',
#  '島',
#  's',
#  'B',
#  'キ',
#  '▁(',
#  'がある',
#  '野',
#  '手',
#  'へ',
#  'していた',
#  'まで',
#  '東',
#  'ニ',
#  '会',
#  'ため',
#  '大学',
#  '道',
#  'サ',
#  'T',
#  'う',
#  '性',
#  'って',
#  'ん',
#  '学',
#  'となる',
#  'P',
#  '軍',
#  'ノ',
#  'チ',
#  '南',
#  'F',
#  '用',
#  '行',
#  '州',
#  '的',
#  '事',
#  '北',
#  'さ',
#  '車',
#  'グ',
#  '的な',
#  '元',
#  '所',
#  'より',
#  '15',
#  '20',
#  '原',
#  'ジ',
#  '語',
#  '、「',
#  'への',
#  '西',
#  '村',
#  'a',
#  '物',
#  'L',
#  '機',
#  '見',
#  'お',
#  'デ',
#  '作品',
#  '立',
#  '放送',
#  'プ',
#  'ダ',
#  'メ',
#  '金',
#  'E',
#  '号',
#  '16',
#  '正',
#  '方',
#  '形',
#  '目',
#  '全',
#  'ハ',
#  '点',
#  '社',
#  'ない',
#  '面',
#  '区',
#  'パ',
#  '場',
#  'ター',
#  'にも',
#  '王',
#  '昭和',
#  'ティ',
#  '二',
#  '不',
#  'ネ',
#  'でも',
#  'だった',
#  '時',
#  'G',
#  '郡',
#  '作',
#  'いた',
#  '神',
#  '平',
#  'ツ',
#  'R',
#  'テ',
#  'ガ',
#  '17',
#  '型',
#  '約',
#  '石',
#  'm',
#  'ー',
#  '城',
#  '発',
#  '力',
#  '公',
#  '代',
#  '文',
#  '世界',
#  '外',
#  '海',
#  'o',
#  '式',
#  'などの',
#  'ま',
#  'イン',
#  'ていた',
#  'モ',
#  'しかし',
#  'セ',
#  '等',
#  '▁/',
#  '19',
#  'H',
#  '入',
#  'y',
#  '木',
#  '曲',
#  'マン',
#  '重',
#  'ック',
#  'i',
#  'にある',
#  'ビ',
#  '書',
#  '映画',
#  '30',
#  'その後',
#  'ット',
#  '主',
#  'において',
#  '月に',
#  '天',
#  '東京',
#  '間',
#  'ラー',
#  'め',
#  '実',
#  'スト',
#  'じ',
#  'れ',
#  'N',
#  'あ',
#  'U',
#  'W',
#  '0',
#  '役',
#  '明',
#  '日本の',
#  'こと',
#  '13',
#  'ディ',
#  '県',
#  't',
#  'わ',
#  'こ',
#  '無',
#  'K',
#  '的に',
#  '▁概要',
#  '次',
#  'られた',
#  'アル',
#  '14',
#  'および',
#  '系',
#  '世',
#  '台',
#  '初',
#  '期',
#  'え',
#  'ボ',
#  '流',
#  'ロー',
#  '番組',
#  'バー',
#  '版',
#  'となり',
#  'ピ',
#  '後に',
#  '地域',
#  'だ',
#  '井',
#  'ザ',
#  '度',
#  'アン',
#  'とは',
#  '和',
#  '知',
#  'V',
#  'J',
#  'r',
#  '種',
#  '通',
#  '活動',
#  '合',
#  '局',
#  'ず',
#  '』(',
#  'ち',
#  '安',
#  'における',
#  '口',
#  'アメリカ',
#  '気',
#  '信',
#  'ゴ',
#  '光',
#  'ール',
#  '旧',
#  '官',
#  '同年',
#  'っている',
#  'O',
#  '定',
#  '理',
#  'I',
#  '話',
#  'ベ',
#  '年には',
#  '成',
#  'ゲーム',
#  'er',
#  '対',
#  '橋',
#  'カー',
#  '寺',
#  '鉄道',
#  '馬',
#  '有',
#  'ソ',
#  '各',
#  '船',
#  'ケ',
#  '現',
#  'チーム',
#  '総',
#  '動',
#  '多',
#  'n',
#  'け',
#  '=',
#  '平成',
#  'できる',
#  'バス',
#  '別',
#  'さらに',
#  '先',
#  '電',
#  '科',
#  'u',
#  '勝',
#  'ば',
#  '集',
#  '番',
#  '両',
#  '白',
#  '党',
#  '土',
#  'サン',
#  'について',
#  'となっている',
#  '風',
#  'シリーズ',
#  'とする',
#  '政',
#  '死',
#  '制',
#  '直',
#  '色',
#  '年から',
#  '賞',
#  'む',
#  '氏',
#  'ワ',
#  '▁『',
#  '開',
#  '進',
#  '万',
#  '々',
#  'リン',
#  '着',
#  'ラン',
#  '隊',
#  '義',
#  '代表',
#  '25',
#  '選手',
#  '記',
#  'シュ',
#  '頭',
#  '大会',
#  '級',
#  '音楽',
#  '開発',
#  '松',
#  '院',
#  'ヒ',
#  '人の',
#  '宮',
#  '時間',
#  'コン',
#  '時代',
#  'とも',
#  '学校',
#  'p',
#  'ペ',
#  'せ',
#  '員',
#  'っ',
#  'b',
#  '問題',
#  '歌',
#  '明治',
#  '朝',
#  'l',
#  'X',
#  'シーズン',
#  'ある',
#  '研究',
#  'k',
#  'プロ',
#  'ポ',
#  'のみ',
#  '艦',
#  '取',
#  '音',
#  '館',
#  '教',
#  '兵',
#  '監督',
#  '民',
#  'レン',
#  '21',
#  'リーグ',
#  'なかった',
#  'ギ',
#  '再',
#  '心',
#  '屋',
#  'ヤ',
#  '女',
#  '50',
#  '権',
#  '当',
#  '会社',
#  '真',
#  '試合',
#  'g',
#  '谷',
#  'があり',
#  '現在',
#  '武',
#  '中国',
#  '%',
#  '美',
#  'ど',
#  'al',
#  '門',
#  'マー',
#  'ホ',
#  'レー',
#  '側',
#  'これは',
#  '地方',
#  'ダー',
#  'テレビ',
#  '派',
#  '津',
#  'なお',
#  '関係',
#  '組',
#  '校',
#  '産',
#  'in',
#  '」(',
#  '24',
#  'ぶ',
#  'ar',
#  '教育',
#  'んだ',
#  'に対して',
#  'すること',
#  '▁S',
#  'd',
#  '量',
#  '論',
#  'よう',
#  '食',
#  '使用',
#  '店',
#  'ヴィ',
#  'c',
#  'にて',
#  'すると',
#  '国際',
#  '四',
#  '空',
#  '室',
#  '自',
#  '計画',
#  'ナー',
#  '調',
#  '父',
#  'されていた',
#  '省',
#  'られ',
#  'ており',
#  '十',
#  'Y',
#  'ソン',
#  '都市',
#  '現在の',
#  '母',
#  '22',
#  'アルバム',
#  'トン',
#  '多くの',
#  '古',
#  '相',
#  '年代',
#  '星',
#  'それ',
#  'or',
#  'になる',
#  '領',
#  'アー',
#  '他',
#  '▁M',
#  '23',
#  '例',
#  '広',
#  'になった',
#  '戦争',
#  '花',
#  '最',
#  'っていた',
#  '士',
#  '任',
#  'リア',
#  '付',
#  '当時',
#  '条',
#  'パー',
#  '特',
#  'しており',
#  'ドイツ',
#  '異',
#  'ね',
#  '事件',
#  '変',
#  '政府',
#  'られる',
#  'シー',
#  '達',
#  'フランス',
#  '座',
#  '吉',
#  '強',
#  '優勝',
#  '事業',
#  'とともに',
#  '連',
#  'ライ',
#  '藤',
#  'ことを',
#  '中央',
#  '品',
#  '黒',
#  'び',
#  '及び',
#  '00',
#  '太',
#  'ること',
#  '特に',
#  '情報',
#  '、『',
#  '身',
#  'そして',
#  '社会',
#  'フェ',
#  '反',
#  'これ',
#  '28',
#  '加',
#  'f',
#  'ニー',
#  'フィ',
#  'なく',
#  '来',
#  '伝',
#  'on',
#  '26',
#  'ッド',
#  '務',
#  '常',
#  '路線',
#  '赤',
#  '親',
#  '岡',
#  '文化',
#  '愛',
#  '波',
#  '場合',
#  '40',
#  'an',
#  '造',
#  '尾',
#  '以降',
#  '開始',
#  '27',
#  '業',
#  '族',
#  '職',
#  '利用',
#  '」「',
#  'ジェ',
#  '▁""',
#  'を持つ',
#  '販売',
#  'だが',
#  'スター',
#  '撃',
#  'w',
#  'とした',
#  '治',
#  '他の',
#  'もある',
#  '増',
#  '路',
#  '今',
#  '火',
#  'カル',
#  'サー',
#  'ひ',
#  'イギリス',
#  '男',
#  '歳',
#  'があった',
#  '河',
#  'グループ',
#  'レイ',
#  'ックス',
#  '類',
#  'つの',
#  '女性',
#  '楽',
#  '器',
#  '地区',
#  'en',
#  '発売',
#  '団',
#  '表',
#  '29',
#  '米',
#  '渡',
#  'と呼ばれる',
#  'もの',
#  'ことから',
#  'システム',
#  '在',
#  'ことが',
#  '八',
#  '退',
#  '久',
#  '年間',
#  '向',
#  '春',
#  'リング',
#  '▁B',
#  '攻撃',
#  '所属',
#  '後の',
#  '100',
#  '好',
#  '青',
#  'と共に',
#  'ーン',
#  'ヌ',
#  '京',
#  '技術',
#  'ファ',
#  '出演',
#  '基',
#  'ヘ',
#  '説',
#  '住',
#  'だけ',
#  '記録',
#  'については',
#  'ように',
#  '言',
#  '戸',
#  'オー',
#  '▁また',
#  '切',
#  'ルー',
#  '半',
#  'を受け',
#  '利',
#  '施設',
#  '師',
#  '薬',
#  '命',
#  '破',
#  '断',
#  '宗',
#  '弾',
#  '五',
#  '起',
#  '近',
#  '製',
#  'タイ',
#  'ジャ',
#  '通り',
#  '関',
#  '清',
#  'としては',
#  'ゲ',
#  'よ',
#  '字',
#  '夫',
#  'したが',
#  'ガー',
#  'エル',
#  '経済',
#  'ビー',
#  '車両',
#  'デビュー',
#  '江',
#  'ゼ',
#  '都',
#  '藩',
#  'ほか',
#  '福',
#  '部分',
#  '志',
#  '▁A',
#  '画',
#  '製造',
#  '機関',
#  '走',
#  '!',
#  '単',
#  '制作',
#  '世紀',
#  '解',
#  '聖',
#  '参加',
#  'シャ',
#  'ただし',
#  '円',
#  're',
#  '工',
#  '砲',
#  '組織',
#  'ノー',
#  '沢',
#  '史',
#  '堂',
#  '日の',
#  '〜',
#  '出身',
#  'を行う',
#  'に関する',
#  'ではなく',
#  '残',
#  'le',
#  'ロシア',
#  '末',
#  'モデル',
#  'ベル',
#  'いる',
#  '急',
#  '決',
#  '取り',
#  '▁この',
#  'レス',
#  '海軍',
#  '英',
#  '出場',
#  'に対する',
#  '生産',
#  '崎',
#  '配',
#  '根',
#  'エン',
#  '高校',
#  '全国',
#  '特徴',
#  '御',
#  '中に',
#  '▁C',
#  '人物',
#  'ところ',
#  'ぎ',
#  '交',
#  '属',
#  '開催',
#  'させ',
#  '足',
#  '源',
#  '意',
#  'クラブ',
#  '建設',
#  '31',
#  'ロン',
#  '年まで',
#  '企業',
#  '丸',
#  'ハイ',
#  'られている',
#  '当時の',
#  'ふ',
#  '視',
#  '岩',
#  '▁P',
#  '従',
#  '機能',
#  '結果',
#  '角',
#  '巻',
#  '越',
#  'いて',
#  '永',
#  '生活',
#  'といった',
#  '佐',
#  '同じ',
#  '首',
#  'センター',
#  '使',
#  'ーズ',
#  '構造',
#  '以上',
#  '図',
#  '||',
#  'カン',
#  '鉄',
#  '良',
#  '60',
#  '質',
#  '乗',
#  '群',
#  'または',
#  '管理',
#  '主義',
#  'の中で',
#  '守',
#  '列車',
#  '変更',
#  '千',
#  '運動',
#  'させる',
#  '"")',
#  'チェ',
#  '大きな',
#  'ic',
#  'ぐ',
#  '豊',
#  '落',
#  'こう',
#  'ほど',
#  '向け',
#  '際',
#  '非',
#  '製作',
#  '主に',
#  '内容',
#  '部隊',
#  '交通',
#  'ろ',
#  '高等学校',
#  '右',
#  '技',
#  '蔵',
#  '状',
#  'それぞれ',
#  'モン',
#  'v',
#  '転',
#  '端',
#  '格',
#  'エンジン',
#  '結',
#  'とされる',
#  'is',
#  '選',
#  'ニア',
#  '独立',
#  'しく',
#  '決定',
#  'ホーム',
#  '年度',
#  '～',
#  'シングル',
#  '居',
#  'at',
#  'バイ',
#  'km',
#  '園',
#  '称',
#  '声',
#  '送',
#  '株式会社',
#  '契約',
#  '者の',
#  '素',
#  'イタリア',
#  '極',
#  'ジョン',
#  '航空',
#  '港',
#  '森',
#  ...]

# %%
data_clas
# Out:
# TextClasDataBunch;
# Train: LabelList
# y: MultiCategoryList (1920 items)
# [MultiCategory Diarrhea, MultiCategory Headache, MultiCategory , MultiCategory Diarrhea, MultiCategory Cold]...
# Path: data/MedWeb
# x: TextList (1920 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 朝 から 猛 烈 に 腹 が 痛 かった け ど 、 案 の 定 下 <unk> だった 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 軽 い 頭 痛 だ から 、 大 丈 夫 っ しょ 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 下 <unk> って 、 英語 で なん て 言う ?, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ お 腹 が 痛 く て 起きた ら 、 下 <unk> になっていた ・ ・ ・ 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ せ っ かく の スペイン な の に 風 邪 ひ いた ・ ・ ・ 。]...
# Path: data/MedWeb;
# Valid: LabelList
# y: MultiCategoryList (640 items)
# [MultiCategory Influenza;Fever, MultiCategory , MultiCategory , MultiCategory Influenza;Fever, MultiCategory Runnynose]...
# Path: data/MedWeb
# x: TextList (640 items)
# [Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 旅行 に 行った ら 、 土 産 に イン フル も ら ってきた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ き つ い 上 司 、 頭 痛 の 種, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ もう 誰 か 翻訳 し てくれ ない とき つ い 、 宇宙 の 言葉 です か って く らい 通じ なく て 頭 痛 してきた 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ イン フル 感染 の 危機 。, Text ▁ xxbos ▁ xxfld ▁ 1 ▁ 鼻 づ まり が ひ ど い から ス ピー チ は 無 理 だ]...
# Path: data/MedWeb;
# Test: None

# %%
data_clas.train_ds.y.c2i
# Out:
# {'Cold': 0,
#  'Cough': 1,
#  'Diarrhea': 2,
#  'Fever': 3,
#  'Hayfever': 4,
#  'Headache': 5,
#  'Influenza': 6,
#  'Runnynose': 7}
